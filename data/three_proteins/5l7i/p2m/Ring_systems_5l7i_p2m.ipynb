# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob
import molvs
from multiprocessing import Pool, cpu_count
from tqdm.auto import tqdm

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i/p2m
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i

# %% [markdown]
# Reading data from crossdock dataset, add a standardization for small molecule data:

# %%
standardizer = molvs.standardize.Standardizer()

def standardize_mol(mol):
    try:
        mol = standardizer.standardize(mol)
        mol = standardizer.fragment_parent(mol, skip_standardize=True)
        mol = standardizer.tautomer_parent(mol, skip_standardize=True)
        mol = standardizer.isotope_parent(mol, skip_standardize=True)
        mol = standardizer.charge_parent(mol, skip_standardize=True)
        return mol
    except:
        return None

# %%
smi_list = []
with open('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i/p2m/500_generated.smi') as f:
    for smi in f:
        smi_list.append(smi.strip())
standardized_smiles_list = []
for smi in tqdm(smi_list, desc="Standardizing molecules", unit="mol"):
    mol = Chem.MolFromSmiles(smi)
    mol = standardize_mol(mol)
    
    if mol:
        standardized_smiles_list.append(Chem.MolToSmiles(mol))
    else:
        print(f"Skipping molecule {smi}")
        pass

print(len(smi_list))
len(standardized_smiles_list)
# Out:
# Standardizing molecules:   0%|          | 0/522 [00:00<?, ?mol/s]
# 522
# 522

# %% [markdown]
# Set the default image size

# %%
with open('500_generated_standardized.smi', 'w') as f:
    for item in standardized_smiles_list:
        f.write("%s\n" % item)

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(standardized_smiles_list, columns=['SMILES'])
df
# Out:
#                                                 SMILES
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
# [522 rows x 1 columns]

# %% [markdown]
# Remove repeated molecules

# %%
df = df.drop_duplicates(['SMILES'])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                 SMILES
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
# [522 rows x 1 columns]

# %% [markdown]
# Save the smi file for further use

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0                                        [C1=CC=CCC=1]
# 1                                           [c1ccccc1]
# 2                                           [C1=COCC1]
# 3                                            [C1CCOC1]
# 4                                           [c1ccccc1]
#                             ...
# 517              [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518    [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519        [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520                [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521            [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
# Name: ring_sytems, Length: 522, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['C1=CC=CCC=1']), list(['c1ccccc1']), list(['C1=COCC1']),
#        list(['C1CCOC1']), list(['c1ccccc1']), list(['C1CCCCC1']),
#        list(['c1ccccc1']), list(['C1=NCC2=C(C1)CCCC2']),
#        list(['C1CC2CCOC2C1']), list(['C1=CC2=C(CC=NC2)CC1']),
#        list(['C1CCNCC1']), list(['c1ccccc1']), list(['C1=COCC1']),
#        list(['c1ccccc1', 'c1cn[nH]c1']), list(['C1=CC=CC=1', 'c1ccccc1']),
#        list(['C1=CCC2C=CCC2=C1']), list(['O=C1CCCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CC2CCOC2C1']), list(['c1ccccc1', 'C1CCNCC1']),
#        list(['C1CCNCC1', 'c1ccccc1']), list(['c1cn[nH]c1', 'c1ccccc1']),
#        list(['N=c1cc[nH]c(=N)[nH]1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1']), list(['c1ccccc1']),
#        list(['c1ccc2ccccc2c1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1']), list(['C1=CC2CCC=CC2=C1']),
#        list(['c1ccccc1', 'C1CCNC1']), list(['c1ccccc1']),
#        list(['c1ccccc1']), list(['O=C1CCc2ccccc2C1']), list(['c1ccccc1']),
#        list(['O=C1NCCc2ccccc21']), list(['c1ccc2c(c1)CNc1ccccc1-2']),
#        list(['c1ccc2ccccc2c1']), list(['c1ccc2ccccc2c1']),
#        list(['O=C1NCCc2ccccc2N1']), list(['c1ccc2occc2c1']),
#        list(['c1ccc2c(c1)Nc1ccccc1O2']), list(['O=c1[nH]ccc2ccccc12']),
#        list(['C=C1CCCCNC1']), list(['c1ccc2ccccc2c1']),
#        list(['c1ccccc1']), list(['c1ccc2occc2c1']),
#        list(['c1ccccc1', 'c1ccncc1']), list(['c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1']), list(['O=C1NCCc2cc3occc3cc21']),
#        list(['O=c1[nH]ccc2ccccc12']), list(['O=c1[nH]ccc2cc3occc3cc12']),
#        list(['c1cc2ccc3c(c2o1)OCCC3']), list(['O=C1NCCc2cc3occc3cc21']),
#        list(['c1ccc2c(c1)COC1c3ccccc3OC21']),
#        list(['c1ccc2c(c1)CNc1ccccc1-2']),
#        list(['O=c1[nH]ccc2cc3occc3cc12']), list(['C=C1C(=O)NCc2ccccc21']),
#        list(['O=c1cc2ccccc2c[nH]1']), list(['c1cc[nH]c1', 'c1ccccc1']),
#        list(['c1cc2ccc3c(c2o1)OCCC3']), list(['C1=COc2c(ccc3ccoc23)C1']),
#        list(['c1ccccc1']), list(['c1ccccc1']), list(['O=C1CNCc2ccccc21']),
#        list(['O=c1[nH]ccc2ccccc12']), list(['c1ccc2c(c1)CNc1ccccc1-2']),
#        list(['c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['O=c1ccc2ccccc2[nH]1']), list(['O=c1[nH]c2ccccc2c2ccccc12']),
#        list(['C1CC2CCC3CCC1C23']), list(['O=C1CNCc2ccccc21']),
#        list(['O=C1CN2c3ccccc3Oc3cccc(c32)N1']),
#        list(['c1ccc2c(c1)COC1c3ccccc3OC21']),
#        list(['c1ccc2c(c1)Oc1cccc3c1N2CCN3']),
#        list(['O=c1[nH]c2ccccc2c2ccccc12']),
#        list(['O=C1NCCc2cc3occc3cc21']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1CCNC1']),
#        list(['c1ccc2c(c1)COC1c3ccccc3OC21']),
#        list(['O=C1NCCc2cc3occc3cc21']), list(['c1ccc2c(c1)Nc1ccccc1O2']),
#        list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CC1Oc3ccccc3OC21']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1CCNCC1']), list(['C1CCCCC1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)Nc1ccccc1O2']),
#        list(['C1CCNC1', 'O=c1ccc2ccccc2[nH]1']),
#        list(['c1ccc2c(c1)COC1c3ccccc3OC21']),
#        list(['c1ccc2c(c1)CCC1c3ccccc3OC21']),
#        list(['O=c1ccc2ccccc2[nH]1']), list(['C1=CCCCC1']),
#        list(['O=c1ccc2ccccc2[nH]1']),
#        list(['c1ccc2c(c1)Nc1ccccc1O2', 'c1ccncc1']),
#        list(['c1ccc2c(c1)CNC1c3ccccc3OC21']),
#        list(['O=c1ccc2ccccc2[nH]1']),
#        list(['c1ccc2c(c1)CCC1c3ccccc3OC21']),
#        list(['c1ccccc1', 'c1ccccc1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1COCCN1']), list(['C1CCOC1']),
#        list(['O=c1[nH]c2ccccc2c2ccccc12']),
#        list(['c1ccc2c(c1)CCC1c3ccccc3OC21']),
#        list(['O=C1CCCN1', 'c1ccccc1']), list(['C1CCOC1']),
#        list(['O=C1c2ccccc2OC2c3ccccc3CCN12']),
#        list(['c1ccccc1', 'C1CCNC1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1']), list(['C1COCCN1', 'O=c1ccc2ccccc2[nH]1']),
#        list(['C1CCNCC1', 'O=c1ccc2ccccc2[nH]1']),
#        list(['c1ccc2c(c1)Nc1ccccc1O2']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1CCCNCC1']),
#        list(['O=C1COC2CNCC3CCCC(C(=O)N1)C32']),
#        list(['c1ccccc1', 'C1CCCC1']), list(['C1CCNCC1']),
#        list(['C1CNC2CCNCC2C1', 'c1ccccc1']),
#        list(['O=c1ccc2ccccc2[nH]1']),
#        list(['O=C1COC2CNCC3CCCC(C(=O)N1)C32']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cnccn1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1CCCN1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1CNCCOC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['C1=NCc2cccc3c2N1CCO3', 'c1ccccc1']),
#        list(['C1CNC2CCCC2C1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1']), list(['O=C1CCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1']), list(['c1ccncc1', 'C1CCNC1']),
#        list(['c1ccncc1']), list(['c1ccccc1', 'O=c1ccc2ccccc2[nH]1']),
#        list(['O=c1[nH]cc[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CCCC1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'c1ccncc1']),
#        list(['C1=NCc2cccc3c2N1CCO3']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['O=C1COC2CNCC3CCC4=CC=C(N1)C4C32']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1']),
#        list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1']), list(['O=C1CCCCN1', 'C1CCOC1']),
#        list(['c1ccccc1']), list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['C1CNC2CCCC2C1', 'C1=CCCCCC1', 'c1ccccc1']),
#        list(['O=C1OCc2ccccc21']), list(['c1ccccc1', 'C1=Cc2ccccc2CC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNC1']),
#        list(['C1CNC2CCCC2C1', 'C1CCCCCC1', 'c1ccccc1']),
#        list(['C1CNC2CCCC2C1', 'C1=CCCCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['O=C1CCNC1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=c1[nH]cc[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1C=CC=C1', 'c1ccccc1', 'c1ccccc1']), list(['C1CCCC1']),
#        list(['O=C1CCCCO1', 'C1CCOC1']),
#        list(['c1cc[nH]c1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1CCCCC1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'c1ccccc1']),
#        list(['O=C1CCNC1', 'c1ccccc1', 'C1CCCCC1']), list(['C1CCOC1']),
#        list(['C1CNC2CCCC2C1', 'C1=CCCCC=C1', 'c1ccccc1']),
#        list(['C1=NCc2cccc3c2N1CCO3', 'C1CCCCC1']), list(['c1ccccc1']),
#        list(['O=C1CCNC1']), list(['O=C1CCCN1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['O=c1[nH]c(=O)n2c3c(cccc13)OCC2', 'c1ccccc1']),
#        list(['O=C1C=CCCOCOC2CCOC2O1']), list(['C1CN2CCOC2CO1']),
#        list(['O=c1[nH]c(=O)n2c3c(cccc13)OCC2']), list(['C1CCCCC1']),
#        list(['C1=CC2OCCC2OC1']), list(['O=C1CCNC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1CCCCCC1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1=Cc2ccccc2OC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1=CCCCCC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1C=C=CC1']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'C1=CCCCC1']),
#        list(['C1CCNC1', 'c1ccccc1']), list(['c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1=CCCCC1']),
#        list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=C1COC2CNCC3CCCC(CCN1)C32', 'c1ccccc1']),
#        list(['O=C1CCCCOCOC2CCOC2O1']),
#        list(['C1CCCC1', 'C1CCOC1', 'O=c1cc[nH]cc1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CNCCN1']),
#        list(['c1ccccc1']),
#        list(['C1=CCC=C1', 'C1CCC2CNCCC2C1', 'c1ccccc1']),
#        list(['O=C1OCc2ccncc21']), list(['O=C1CCCCO1', 'C1CCOC1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1=CCCCCC1']),
#        list(['C1=CNCN=C1', 'c1ccccc1', 'c1ccccc1']), list(['c1ccccc1']),
#        list(['C1CCNCC1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNC1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C1CCC2CNCCC2C1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1=CCCCC1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ccc2c(c1)CCCO2']),
#        list(['C1CCOC1']), list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1CCCCCC1']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1=CCCCCC1']),
#        list(['C1COC2CCOC2C1']), list(['O=C1CCOC2CCOC12']),
#        list(['O=c1cc[nH]cn1', 'C1CCOC1', 'C1CCCC1']),
#        list(['O=C1CCCCOCOC2CCOC2O1', 'C1COCN1']),
#        list(['C1CCNCC1', 'O=C1OCc2ccccc21']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1=CCCCC1']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'C1CCOCC1']),
#        list(['c1ccccc1', 'C1=CCN=CC1', 'c1ccccc1', 'C1CCNC1']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['O=c1[nH]c(=O)n2c3c(cccc13)OCC2']),
#        list(['O=C1CCCCOCOC2CCOC2O1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CNCCN1']),
#        list(['C1CN2CCOC2CO1']), list(['O=C1CCNC1']),
#        list(['O=C1CCNC1', 'c1ccccc1', 'C1CCOCC1']), list(['c1ccccc1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1CCCCCC1']),
#        list(['C1CCOCC1', 'c1ccccc1', 'O=C1CCCN1']),
#        list(['O=C1COCCOCOC2CCOC2O1']), list(['O=c1cccc2n1CC1CCOC21']),
#        list(['O=c1cc[nH]c(=O)[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCC2CNCCC2C1', 'c1ccccc1']),
#        list(['O=C1c2cccc3c2N(CCO3)C2=NC3CCCCC3N12']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCNC2']), list(['C1=CC2OCCC2OC1']),
#        list(['C1CCOCC1', 'c1ccccc1', 'O=C1CCCN1']), list(['c1ccccc1']),
#        list(['O=C1CCNC1']), list(['c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C1CCNCC1', 'O=C1OCc2ccccc21']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'C1=CCCCC1']),
#        list(['O=C1CCNC1', 'c1ccccc1', 'C1CCOCC1']), list(['c1ccccc1']),
#        list(['C1CCOC1']), list(['C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=C1OC2CCOCc3cccc1c32']),
#        list(['c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'O=C1CCNCC1']),
#        list(['C1COC2CCOC2C1']), list(['O=c1cccc2n1CC1CCOC21']),
#        list(['C=C1CCCCNC1', 'O=C1Cc2ccccc2CN1']),
#        list(['O=C1CCOC2CCOC12']), list(['O=C1CCC=COCOC2CCOC2O1']),
#        list(['c1ccc2c(c1)OCCCO2', 'c1ccccc1']), list(['C1COC2CCOC2C1']),
#        list(['C1=CNC=CC1', 'c1ccccc1']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1']),
#        list(['O=C1C=CCCOCOC2CCOC2O1', 'C1CCNC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']), list(['C1CCOC1']),
#        list(['O=C1CCOCCOCOC2CCOC2O1']), list(['C1=CNCC1', 'c1ccccc1']),
#        list(['C1COC2CCOC2C1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'O=c1[nH]c(=O)n2c3c(cccc13)OCC2']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'O=C1CCCO1']),
#        list(['C=C1CCCCNC1', 'O=c1cc2ccccc2c2n1CCC2']),
#        list(['C1CCC2COCC2CC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']), list(['O=C1CCCN1']),
#        list(['c1ccc2c(c1)OCCCO2', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1=CCCCC1', 'C1CCOC1']),
#        list(['C1CCNC1', 'O=C1CCCCOCOC2CCOC2O1']),
#        list(['O=C1OCc2ccccc21']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CCNC2']),
#        list(['O=C1CCC2CCC3CNCC(OC(=O)CN1)C3C2', 'c1ccccc1']),
#        list(['O=C1CCCO1', 'C1CCNCC1']), list(['O=C1CCCN1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1CNCCN1C2']),
#        list(['O=C1NCC2CCCC3COC1C23']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1']),
#        list(['C=C1CCCCNC1', 'C1=CC2Cc3ccccc3CN2C=C1']),
#        list(['C1COCC2COCC2C1']), list(['O=c1cccc2n1CC1CCOC21']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=C1NC(=O)C2OCC3CCCC1C32']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1CCCCN1C2']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1']),
#        list(['O=C1CCC2CCC3CNCC(OC(=O)CN1)C3C2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C1=CNC=NC1', 'c1ccccc1', 'N=c1ccnc[nH]1']),
#        list(['C1CCNCC1', 'O=C1COCCOCOC2CCOC2O1']),
#        list(['c1ccccc1', 'O=c1nccc[nH]1']),
#        list(['C1CCOC1', 'O=C1CCCN1']),
#        list(['O=c1cccc2n1CC1CCOC21', 'O=C1CCOC1']),
#        list(['O=C1COCCCOCOC2CCOC2O1']),
#        list(['O=C1CCNC1', 'c1ccccc1', 'C1CCOCC1']),
#        list(['O=C1OCCC2CCOC12']),
#        list(['C1=CNCC1', 'c1ccccc1', 'C1CCOCC1']), list(['C1CCOC1']),
#        list(['C=C1CCCCNC1', 'O=C1CC=CN2Cc3ccccc3CC12']),
#        list(['c1ccccc1', 'O=C1CCCOC1']), list(['O=C1COCCCOCOC2CCOC2O1']),
#        list(['c1ccccc1', 'C1=CNC=NC1']),
#        list(['O=C1OCC2CCOCC3CCCCN3C12']),
#        list(['O=C1CCCCOCOC2CCOC2O1', 'C1CCNC1']),
#        list(['C1=CNC=CC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)OCCCO2', 'c1ccccc1']),
#        list(['c1ccc2c(c1)OCCCO2', 'c1ccccc1']),
#        list(['O=C1OC2CCOCc3cccc1c32']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CNCCN1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CN2COCC(C2)N1']),
#        list(['O=C1CCCCOCOC2CCOC2O1', 'C1CCNC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1CCCCCC1']),
#        list(['O=C1CCCO1', 'O=C1CCNC=N1']),
#        list(['C1=CNCCC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CCOC1', 'C1=CCNC=C1']), list(['O=c1cccc2n1CC1CCOC21']),
#        list(['C1=CNCN=C1', 'c1ccccc1', 'C1=CCCCC1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C1=CNC=NC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1OCCCN1C2']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1C=C=CC1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['O=c1cccc2n1CC1CCOC21', 'O=C1CCOC1']),
#        list(['O=C1COCCOCOC2CCOC2O1', 'C1CNCOC1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2OC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=C1CCOC1', 'O=c1cccc2n1CC1CCOC21']),
#        list(['C=C1CCCCNC1', 'O=c1ccn2c(c1)Cc1ccccc1C2']),
#        list(['c1ccccc1', 'O=c1nccc[nH]1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'C1CCCCCC1']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C=C1CCCCNC1', 'O=C1C2COc3cccc(c32)CC2CCCN12']),
#        list(['C1CCCC1', 'C1CCOC1', 'O=c1cccc[nH]1']),
#        list(['O=C1CCN2C(COCCC3COC(=O)C32)C1']),
#        list(['C1=CNCC1', 'c1ccccc1', 'C1CCOCC1']),
#        list(['C1CCCC1', 'C1CCOC1', 'O=c1cccc[nH]1']),
#        list(['O=c1nccc[nH]1', 'c1ccccc1', 'C1=CCCCC1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1OCCCCN1C2']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C=C1CCCCNC1', 'C1=CN2CCc3ccccc3C2CO1']),
#        list(['C1CCOC1', 'C1CC2CCOC2C1']),
#        list(['c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1CCNCC1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1COCCN1']),
#        list(['C1=CNCCC1', 'c1ccccc1', 'N=c1cc[nH]cc1']),
#        list(['C1=CNC=CC1', 'c1ccccc1', 'C1CCCC1']),
#        list(['c1ccccc1', 'C1=CNCN=C1', 'C1=CCNC=C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['O=C1CC2=CC(CC2)OC2=CCNCCNCCOC3COC(O1)C3O2']),
#        list(['O=C1CC2COCCc3occ(c32)C=N1']),
#        list(['O=C1CC2=CC(CC2)OC2CCNCCNCCOC3COC(O1)C3O2']),
#        list(['O=C1OCC2CCOCC3CCCCN3C12']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['O=C1CCOC1', 'O=c1ccn2c(c1)C1OCCC1C2']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCCC2C1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['c1ccccc1', 'C1=CNCN=C1', 'C1=CCNC=C1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C1CCOC1', 'O=c1ccn2c(c1)C1OCCC1C2']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CNC=NC1', 'C1=CCNC=C1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'C1=CNCN=C1', 'c1cc[nH]c1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1CCNCC1']),
#        list(['C1=CCCC=C1', 'c1ccccc1', 'C1=CNCN=C1', 'C1=CCNC=C1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1COCCN1']),
#        list(['C=C1COc2cc3c(cc2C1)OCCCO3', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CNCN=C1', 'c1cc[nH]c1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCCC2C1']),
#        list(['O=C1CCOC2CCOC12']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1OCCCN1C2']),
#        list(['C1=CCCCC1', 'O=c1cccc[nH]1', 'C1CCC2CCC(NC1)O2']),
#        list(['O=C1COC=CCOC2CCNCCNCCOC3COC(O1)C3O2']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['C=C1CCCCNC1', 'O=C1C2COc3cccc(c32)CC2CCCCN12']),
#        list(['C=C1c2cscc2Cc2cc3c(cc21)OCCCO3', 'c1ccccc1']),
#        list(['O=C1COCCCOCOC2CCOC2O1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['c1ccccc1', 'C1CCC2CNCCC2C1', 'C1CCCCC1']),
#        list(['C1CCCC1', 'C1CCOC1', 'O=c1cccc[nH]1']),
#        list(['O=C1COCCCOCOC2CCOC2O1']), list(['C1CCOC1', 'C1CC2CCOC2C1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2OC1']),
#        list(['O=C1COCCOCOC2CCOC2O1', 'C1CC2CNCOC2C1']),
#        list(['c1ccc2c(c1)OCCCO2', 'c1ccccc1']),
#        list(['O=C1CCNCC1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['c1ccc2c(c1)OCCCO2', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'C1=CNCN=C1', 'C1=CCNC=C1']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccccc1', 'O=c1nccc[nH]1', 'c1cc[nH]c1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=CNCN=C1', 'C1=CCNC=C1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CCN1CCOCC21']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=c1c2c(oc3cc4c(cc13)OCCCO4)CCCC2', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'O=C1C2COc3cccc(c32)CC2CCCN12']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'O=c1cc[nH]cn1', 'C1=CCNC=C1']),
#        list(['C=C1CCCCNC1', 'O=C1NCCc2cccc3c2C1CO3']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['C1=CCNCC1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C1CCOC1', 'O=c1ccn2c(c1)C1OCCC1C2']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['C1CCOC1', 'O=c1ccn2c(c1)C1OCCC1C2']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2OC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cc[nH]cn1', 'C1=CCNC=C1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCCC2C1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCCC2C1']),
#        list(['O=C1COC2CNCC3CCCC(NCc4ccccc4N1)C32', 'C1CCCCC1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['O=C1CCOC2CCOC12']),
#        list(['O=C1COCCCOC2CCNCCNCCOC3COC(O1)C3O2']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1OCCC3OCCC2N31']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCOC2C1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1COC2CCCC2C1']),
#        list(['O=c1cccc[nH]1', 'C1=CCCCC1', 'C1CC2OCCC2O1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1']),
#        list(['O=C1COCCCOC2CCNCCNCCOC3COC(O1)C3O2']),
#        list(['O=C1COCCCOCOC2CCOC2O1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CNC=NC1', 'C1=CCNC=C1']),
#        list(['C1=C2c3cc4c(cc3Cc3cccc(c32)CC1)OCCCO4', 'c1ccccc1']),
#        list(['C1CCOC1', 'C1CC2CCOC2C1']),
#        list(['C=C1CCCCNC1', 'O=C1C2COc3cccc(c32)CC2CCCN12']),
#        list(['C1=CCNCC1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['c1ccc2cc3cc4c(cc3cc2c1)OCCCO4', 'c1ccccc1']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'C1=CNCN=C1', 'C1=CNCC1']),
#        list(['c1ccc2c(c1)OCCCO2', 'O=C1CCCCO1', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['c1c2c(cc3c1OCCCO3)CCCC2', 'c1ccccc1']),
#        list(['c1c2c(cc3c1OCCCO3)CCCC2', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1CCNCC1']),
#        list(['O=C1NC2CCCC2Oc2cc3c(cc21)OCCCO3', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1=COC2CCCC2C1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1CCNCC1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['O=C1C=C2OCCCOCC(=O)OC3OCC(OCCNCCN1)C3O2']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'c1cc[nH]c1']),
#        list(['c1c2c(cc3c1OCCCO3)CCCC2', 'c1ccccc1']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CCCC1']),
#        list(['O=C1CCCCN1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['c1c2c(cc3c1OCCCO3)CCCC2', 'c1ccccc1']),
#        list(['N=C1CCC(=O)CC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'C1=CCNC=C1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'c1cc2c3c(c1)Cc1cccc4c1N3C(CO4)OC2']),
#        list(['C=C1CCCCNC1', 'C1=CN2CCc3ccccc3C2CO1']),
#        list(['C=C1c2ccccc2Cc2cc3c(cc21)OCCCO3', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'c1cc2c3c(c1)Cc1cccc4c1N3C(CO4)OC2']),
#        list(['c1ccc2cc3c(cc2c1)OCCCO3', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'C1=CCNC=C1']),
#        list(['C=C1CCCCNC1', 'c1cc2c3c(c1)OCC1COc4cccc(c4N31)C2']),
#        list(['c1ccccc1', 'C1CCC2CNCCC2C1', 'C1CCCCC1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCCC2C1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'c1cc[nH]c1']),
#        list(['C=C1CCCCNC1', 'O=C1NCCc2cccc3c2C1CO3']),
#        list(['C=C1CCCCNC1', 'C1=C2COc3cccc4c3N2c2c(cccc2O1)C4']),
#        list(['C=C1COc2cc3c(cc2C1)OCCCO3', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'C1=CCNC=C1']),
#        list(['C=C1c2cscc2Cc2cc3c(cc21)OCCCO3', 'c1ccccc1']),
#        list(['O=C1CNC(=O)CC2OCCCOCC(=O)OC3OCC(OCCN1)C3O2']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CNC=NC1', 'O=c1cccc[nH]1']),
#        list(['C1=Nc2ccccc2C2COCCc3occ1c32']),
#        list(['C=C1CCCCNC1', 'C1=C2Cc3cccc4c3N3C(CO4)OCC(CC1)C23']),
#        list(['N=C1CCC(=O)CC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'c1cc[nH]c1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'O=c1nccc[nH]1', 'C1=CCNC=C1']),
#        list(['c1ccc2c(c1)OCCCO2', 'O=C1CCCCO1', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['O=C1CCNCN1', 'c1ccccc1', 'c1cc2c(o1)CCNC2']),
#        list(['c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3', 'c1ccccc1']),
#        list(['C1=Cc2ccccc2OC1', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1CCNCC1']),
#        list(['c1ccc2c(c1)CCOC1CCC3CCCN2C31', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'O=C1CCCCN1', 'C1CCNCC1']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'O=c1cc[nH]cn1', 'C1=CNCCC1']),
#        list(['c1ccccc1', 'C1CNC2CCCC2C1', 'c1ccccc1']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'C1=CNCN=C1', 'C1=CNCC1']),
#        list(['c1c2c(cc3c1OCCCO3)CCCC2', 'c1ccccc1']),
#        list(['C=C1CCCCNC1', 'O=C1NCCc2cccc3c2C1CO3']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CCN1CCOCC21']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'O=c1cc[nH]cn1', 'C1=CCNC=C1']),
#        list(['O=C1CC2OCCCOCC(=O)OC3OCC(OCCNCCN1)C3O2']),
#        list(['C=C1CCCCNC1', 'C1=C2CCC=C3Cc4cccc5c4N(C(CO5)O1)C23']),
#        list(['N=c1cc[nH]cc1', 'C1CCC2CNCCC2C1', 'C1CCCCC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cc[nH]cn1', 'C1=CCNC=C1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1CC2CCCC2C1']),
#        list(['C=C1CCCCNC1', 'c1cc2c3c(c1)NOC1COc4cccc(c4N31)C2']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1COC2CCCC2C1']),
#        list(['C1CCC2CNCCC2C1', 'C1CCCCC1', 'N=c1cc[nH]cc1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)Cc1cccc3c1N2CCO3']),
#        list(['O=C1COC2CNCC3CCCC(NC(=O)c4ccccc4N1)C32', 'C1CCCCC1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CC1OCCCN1C2']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'C1=CNCN=C1', 'C1=CNCC1']),
#        list(['c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3', 'c1ccccc1']),
#        list(['c1c2c(cc3c1OCCCO3)CCCC2', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'C1CCOC1', 'C1COC2CCCC2C1'])], dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                            SMILES  Count
# 1                        c1ccccc1    290
# 24                    C=C1CCCCNC1     55
# 3                         C1CCOC1     49
# 57                  O=c1cccc[nH]1     48
# 53                  C1CNC2CCCC2C1     43
# ..                            ...    ...
# 82               c1ccc2c(c1)CCCO2      1
# 80                O=C1OCc2ccncc21      1
# 47   O=C1c2ccccc2OC2c3ccccc3CCN12      1
# 44    c1ccc2c(c1)CNC1c3ccccc3OC21      1
# 100         O=C1CCOCCOCOC2CCOC2O1      1
#
# [177 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup()
res = df.mol.apply(ring_system_lookup.process_mol)

# %%
res
# Out:
# 0                                     [(C1=CC=CCC=1, 0)]
# 1                                  [(c1ccccc1, 2568039)]
# 2                                      [(C1=COCC1, 162)]
# 3                                     [(C1CCOC1, 54820)]
# 4                                  [(c1ccccc1, 2568039)]
#                              ...
# 517      [(C=C1CCCCNC1, 1), (c1ccc2c(c1)CC1OCCCN1C2, 0)]
# 518    [(N=c1cc[nH]cc1, 452), (c1ccccc1, 2568039), (C...
# 519    [(c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, 0), (c1cccc...
# 520    [(c1c2c(cc3c1OCCCO3)CCCC2, 0), (c1ccccc1, 2568...
# 521    [(O=c1cccc[nH]1, 15478), (C1CCOC1, 54820), (C1...
# Name: mol, Length: 522, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
# [522 rows x 5 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#
# [15:40:59] WARNING: Omitted undefined stereo
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq  \
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
#                                                  inchi
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3
# ..                                                 ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...
#
# [522 rows x 6 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq  \
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
#                                                  inchi
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3
# ..                                                 ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...
#
# [522 rows x 6 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# 5                                           CC1CCCCC1O
# ..                                                 ...
# 492  C=CCC=Cc1c(C2CCCC(=O)O2)cc2c(c1O)OC(c1ccccc1)C...
# 496  COc1ccc2c(c1O)OC(O)C(Oc1ccccc1NCCCC(C)=NCC(C)=...
# 500  Cc1c[nH]ccc1=NCCc1ccc(O)c(-c2cc(=O)ncn2CN2C=CC...
# 509  Cc1c(C=O)[nH]ccc1=NC(O)COC1CN(C(=O)C2CCCCC2)CC...
# 514  O=C(COC1CN(C(=O)C2CCCCC2)CC2CCCCC21)N=c1cc[nH]...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e2714caae30>
# ..                                                ...
# 492  <rdkit.Chem.rdchem.Mol object at 0x7e2714c64890>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7e2714c65540>
# 500  <rdkit.Chem.rdchem.Mol object at 0x7e2714c65930>
# 509  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66030>
# 514  <rdkit.Chem.rdchem.Mol object at 0x7e2714c669d0>
#
#                                            ring_sytems         min_ring  \
# 1                                           [c1ccccc1]         c1ccccc1
# 2                                           [C1=COCC1]         C1=COCC1
# 3                                            [C1CCOC1]          C1CCOC1
# 4                                           [c1ccccc1]         c1ccccc1
# 5                                           [C1CCCCC1]         C1CCCCC1
# ..                                                 ...              ...
# 492          [c1ccc2c(c1)OCCCO2, O=C1CCCCO1, c1ccccc1]       O=C1CCCCO1
# 496                        [C1=Cc2ccccc2OC1, c1ccccc1]  C1=Cc2ccccc2OC1
# 500  [N=c1cc[nH]cc1, c1ccccc1, O=c1cc[nH]cn1, C1=CN...        C1=CNCCC1
# 509          [N=c1cc[nH]cc1, C1CCC2CNCCC2C1, C1CCCCC1]   C1CCC2CNCCC2C1
# 514          [C1CCC2CNCCC2C1, C1CCCCC1, N=c1cc[nH]cc1]   C1CCC2CNCCC2C1
#
#     min_freq                                              inchi
# 1    2568039      InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3
# 2        162  InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...
# 3      54820       InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2
# 4    2568039    InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3
# 5      90332  InChI=1S/C7H14O/c1-6-4-2-3-5-7(6)8/h6-8H,2-5H2...
# ..       ...                                                ...
# 492      601  InChI=1S/C25H24F2O5/c1-2-3-5-11-17-18(19-12-8-...
# 496     2793  InChI=1S/C24H28N2O6/c1-15(26-14-16(2)27)7-6-12...
# 500      127  InChI=1S/C24H26FN5O2/c1-17-14-26-8-5-21(17)27-...
# 509      265  InChI=1S/C25H37N3O4/c1-17-21(11-12-26-22(17)15...
# 514      265  InChI=1S/C24H33N3O5/c28-22(26-20-10-11-25-12-1...
#
# [221 rows x 6 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/522 [00:00<?, ?it/s]
#     rule_set_name     description
# 0              ok              ok
# 1              ok              ok
# 2              ok              ok
# 3              ok              ok
# 4              ok              ok
# ..            ...             ...
# 517         PAINS  mannich_A(296)
# 518            ok              ok
# 519            ok              ok
# 520            ok              ok
# 521            ok              ok
#
# [522 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/522 [00:00<?, ?it/s]
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 516  O=C1COC2CN(C(=O)C3CCCCC3)CC3CCCC(NC(=O)c4ccccc...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66b90>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                            ring_sytems  \
# 0                                        [C1=CC=CCC=1]
# 1                                           [c1ccccc1]
# 2                                           [C1=COCC1]
# 3                                            [C1CCOC1]
# 4                                           [c1ccccc1]
# ..                                                 ...
# 516  [O=C1COC2CNCC3CCCC(NC(=O)c4ccccc4N1)C32, C1CCC...
# 518    [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519        [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520                [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521            [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                                    min_ring min_freq  \
# 0                               C1=CC=CCC=1        0
# 1                                  c1ccccc1  2568039
# 2                                  C1=COCC1      162
# 3                                   C1CCOC1    54820
# 4                                  c1ccccc1  2568039
# ..                                      ...      ...
# 516  O=C1COC2CNCC3CCCC(NC(=O)c4ccccc4N1)C32        0
# 518                              C1=CNCN=C1       10
# 519         c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520                 c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                           C1COC2CCCC2C1        1
#
#                                                  inchi rule_set_name  \
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3            ok
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3            ok
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...            ok
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2            ok
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3            ok
# ..                                                 ...           ...
# 516  InChI=1S/C25H33N3O4/c29-22-15-32-21-14-28(25(3...            ok
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...            ok
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...            ok
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...            ok
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...            ok
#
#     description
# 0            ok
# 1            ok
# 2            ok
# 3            ok
# 4            ok
# ..          ...
# 516          ok
# 518          ok
# 519          ok
# 520          ok
# 521          ok
#
# [485 rows x 8 columns]

# %% [markdown]
# Test all filters from rd filters

# %%
rd_filters = ['Glaxo', 'Dundee', 'BMS', 'SureChEMBL', 'MLSMR', 'Inpharmatica', 'LINT']
for filter in rd_filters:
    reos.set_active_rule_sets([filter])
    new_df = reos.pandas_mols(df.mol)
    print(filter, len(new_df[new_df.description == "ok"])/len(new_df), reos.get_active_rule_sets(), len(new_df[new_df.description == "ok"]))
# Out:
#   0%|          | 0/522 [00:00<?, ?it/s]
# Glaxo 0.975095785440613 ['Glaxo'] 509
#   0%|          | 0/522 [00:00<?, ?it/s]
# Dundee 0.5268199233716475 ['Dundee'] 275
#   0%|          | 0/522 [00:00<?, ?it/s]
# BMS 0.8869731800766284 ['BMS'] 463
#   0%|          | 0/522 [00:00<?, ?it/s]
# SureChEMBL 0.7758620689655172 ['SureChEMBL'] 405
#   0%|          | 0/522 [00:00<?, ?it/s]
# MLSMR 0.5804597701149425 ['MLSMR'] 303
#   0%|          | 0/522 [00:00<?, ?it/s]
# Inpharmatica 0.7279693486590039 ['Inpharmatica'] 380
#   0%|          | 0/522 [00:00<?, ?it/s]
# LINT 0.7988505747126436 ['LINT'] 417

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq  \
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
#                                                  inchi  Reymond
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3     True
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True
# ..                                                 ...      ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...     True
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...     True
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...     True
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...     True
#
# [522 rows x 7 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq  \
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
#                                                  inchi  Reymond
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3     True
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True
# ..                                                 ...      ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...     True
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...     True
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...     True
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...     True
#
# [522 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq  \
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
#                                                  inchi  Reymond  Lipinski
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3     True      True
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True      True
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True      True
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True      True
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True      True
# ..                                                 ...      ...       ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...     True      True
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True      True
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...     True      True
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...     True      True
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...     True      True
#
# [522 rows x 8 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring min_freq  \
# 0                        C1=CC=CCC=1        0
# 1                           c1ccccc1  2568039
# 2                           C1=COCC1      162
# 3                            C1CCOC1    54820
# 4                           c1ccccc1  2568039
# ..                               ...      ...
# 517           c1ccc2c(c1)CC1OCCCN1C2        0
# 518                       C1=CNCN=C1       10
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3        0
# 520          c1c2c(cc3c1OCCCO3)CCCC2        0
# 521                    C1COC2CCCC2C1        1
#
#                                                  inchi  Reymond  Lipinski
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3     True      True
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True      True
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True      True
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True      True
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True      True
# ..                                                 ...      ...       ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...     True      True
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True      True
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...     True      True
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...     True      True
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...     True      True
#
# [467 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC22 database druglike molecules

# %%
ring_system_lookup_ZINC22 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC22_rings_system.csv")
res_zinc22 = df.mol.apply(ring_system_lookup_ZINC22.process_mol)
res_zinc22
# Out:
# 0                                     [(C1=CC=CCC=1, 0)]
# 1                              [(c1ccccc1, 21243538754)]
# 2                                [(C1=COCC1, 109924300)]
# 3                                [(C1CCOC1, 4151021098)]
# 4                              [(c1ccccc1, 21243538754)]
#                              ...
# 517      [(C=C1CCCCNC1, 0), (c1ccc2c(c1)CC1OCCCN1C2, 0)]
# 518    [(N=c1cc[nH]cc1, 102355332), (c1ccccc1, 212435...
# 519    [(c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, 0), (c1cccc...
# 520    [(c1c2c(cc3c1OCCCO3)CCCC2, 0), (c1ccccc1, 2124...
# 521    [(O=c1cccc[nH]1, 263027600), (C1CCOC1, 4151021...
# Name: mol, Length: 522, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc22.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring     min_freq  \
# 0                        C1=CC=CCC=1            0
# 1                           c1ccccc1  21243538754
# 2                           C1=COCC1    109924300
# 3                            C1CCOC1   4151021098
# 4                           c1ccccc1  21243538754
# ..                               ...          ...
# 517                      C=C1CCCCNC1            0
# 518                       C1=CNCN=C1           76
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3            0
# 520          c1c2c(cc3c1OCCCO3)CCCC2            0
# 521                    C1COC2CCCC2C1            0
#
#                                                  inchi  Reymond  Lipinski
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3     True      True
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True      True
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True      True
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True      True
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True      True
# ..                                                 ...      ...       ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...     True      True
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True      True
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...     True      True
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...     True      True
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...     True      True
#
# [522 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# 5                                           CC1CCCCC1O
# ..                                                 ...
# 506  Cc1c[nH]ccc1=NCCc1ccc(O)c(-c2cc(=O)ncn2CN2C=CC...
# 509  Cc1c(C=O)[nH]ccc1=NC(O)COC1CN(C(=O)C2CCCCC2)CC...
# 510  Cc1ccccc1NCCc1ccc(O)c(-c2cc(=O)ncn2CN2C=CC(F)=...
# 511  Cc1cc(CO)c(=O)n(C2CC(COCC3CCC4(C(=O)O)CCCC34)O...
# 514  O=C(COC1CN(C(=O)C2CCCCC2)CC2CCCCC21)N=c1cc[nH]...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e2714caae30>
# ..                                                ...
# 506  <rdkit.Chem.rdchem.Mol object at 0x7e2714c661f0>
# 509  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66030>
# 510  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66650>
# 511  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66570>
# 514  <rdkit.Chem.rdchem.Mol object at 0x7e2714c669d0>
#
#                                            ring_sytems        min_ring  \
# 1                                           [c1ccccc1]        c1ccccc1
# 2                                           [C1=COCC1]        C1=COCC1
# 3                                            [C1CCOC1]         C1CCOC1
# 4                                           [c1ccccc1]        c1ccccc1
# 5                                           [C1CCCCC1]        C1CCCCC1
# ..                                                 ...             ...
# 506  [N=c1cc[nH]cc1, c1ccccc1, O=c1cc[nH]cn1, C1=CC...      C1=CCNC=C1
# 509          [N=c1cc[nH]cc1, C1CCC2CNCCC2C1, C1CCCCC1]  C1CCC2CNCCC2C1
# 510    [c1ccccc1, c1ccccc1, O=c1cc[nH]cn1, C1=CCNC=C1]      C1=CCNC=C1
# 511             [O=c1cccc[nH]1, C1CCOC1, C1CC2CCCC2C1]    C1CC2CCCC2C1
# 514          [C1CCC2CNCCC2C1, C1CCCCC1, N=c1cc[nH]cc1]  C1CCC2CNCCC2C1
#
#         min_freq                                              inchi  Reymond  \
# 1    21243538754      InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True
# 2      109924300  InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True
# 3     4151021098       InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True
# 4    21243538754    InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True
# 5     4295567520  InChI=1S/C7H14O/c1-6-4-2-3-5-7(6)8/h6-8H,2-5H2...     True
# ..           ...                                                ...      ...
# 506          132  InChI=1S/C24H24FN5O2/c1-17-14-26-8-5-21(17)27-...     True
# 509        25368  InChI=1S/C25H37N3O4/c1-17-21(11-12-26-22(17)15...     True
# 510          132  InChI=1S/C25H25FN4O2/c1-18-4-2-3-5-22(18)27-11...     True
# 511      9064982  InChI=1S/C23H33NO8/c1-13-7-15(9-25)21(28)24(20...     True
# 514        25368  InChI=1S/C24H33N3O5/c28-22(26-20-10-11-25-12-1...     True
#
#      Lipinski
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# ..        ...
# 506      True
# 509      True
# 510      True
# 511      True
# 514      True
#
# [313 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 0) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# 5                                           CC1CCCCC1O
# ..                                                 ...
# 509  Cc1c(C=O)[nH]ccc1=NC(O)COC1CN(C(=O)C2CCCCC2)CC...
# 510  Cc1ccccc1NCCc1ccc(O)c(-c2cc(=O)ncn2CN2C=CC(F)=...
# 511  Cc1cc(CO)c(=O)n(C2CC(COCC3CCC4(C(=O)O)CCCC34)O...
# 514  O=C(COC1CN(C(=O)C2CCCCC2)CC2CCCCC21)N=c1cc[nH]...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e2714caae30>
# ..                                                ...
# 509  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66030>
# 510  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66650>
# 511  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66570>
# 514  <rdkit.Chem.rdchem.Mol object at 0x7e2714c669d0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
#
#                                          ring_sytems        min_ring  \
# 1                                         [c1ccccc1]        c1ccccc1
# 2                                         [C1=COCC1]        C1=COCC1
# 3                                          [C1CCOC1]         C1CCOC1
# 4                                         [c1ccccc1]        c1ccccc1
# 5                                         [C1CCCCC1]        C1CCCCC1
# ..                                               ...             ...
# 509        [N=c1cc[nH]cc1, C1CCC2CNCCC2C1, C1CCCCC1]  C1CCC2CNCCC2C1
# 510  [c1ccccc1, c1ccccc1, O=c1cc[nH]cn1, C1=CCNC=C1]      C1=CCNC=C1
# 511           [O=c1cccc[nH]1, C1CCOC1, C1CC2CCCC2C1]    C1CC2CCCC2C1
# 514        [C1CCC2CNCCC2C1, C1CCCCC1, N=c1cc[nH]cc1]  C1CCC2CNCCC2C1
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]      C1=CNCN=C1
#
#         min_freq                                              inchi  Reymond  \
# 1    21243538754      InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True
# 2      109924300  InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True
# 3     4151021098       InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True
# 4    21243538754    InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True
# 5     4295567520  InChI=1S/C7H14O/c1-6-4-2-3-5-7(6)8/h6-8H,2-5H2...     True
# ..           ...                                                ...      ...
# 509        25368  InChI=1S/C25H37N3O4/c1-17-21(11-12-26-22(17)15...     True
# 510          132  InChI=1S/C25H25FN4O2/c1-18-4-2-3-5-22(18)27-11...     True
# 511      9064982  InChI=1S/C23H33NO8/c1-13-7-15(9-25)21(28)24(20...     True
# 514        25368  InChI=1S/C24H33N3O5/c28-22(26-20-10-11-25-12-1...     True
# 518           76  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True
#
#      Lipinski
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# ..        ...
# 509      True
# 510      True
# 511      True
# 514      True
# 518      True
#
# [331 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 10) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# 5                                           CC1CCCCC1O
# ..                                                 ...
# 509  Cc1c(C=O)[nH]ccc1=NC(O)COC1CN(C(=O)C2CCCCC2)CC...
# 510  Cc1ccccc1NCCc1ccc(O)c(-c2cc(=O)ncn2CN2C=CC(F)=...
# 511  Cc1cc(CO)c(=O)n(C2CC(COCC3CCC4(C(=O)O)CCCC34)O...
# 514  O=C(COC1CN(C(=O)C2CCCCC2)CC2CCCCC21)N=c1cc[nH]...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e2714caae30>
# ..                                                ...
# 509  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66030>
# 510  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66650>
# 511  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66570>
# 514  <rdkit.Chem.rdchem.Mol object at 0x7e2714c669d0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
#
#                                          ring_sytems        min_ring  \
# 1                                         [c1ccccc1]        c1ccccc1
# 2                                         [C1=COCC1]        C1=COCC1
# 3                                          [C1CCOC1]         C1CCOC1
# 4                                         [c1ccccc1]        c1ccccc1
# 5                                         [C1CCCCC1]        C1CCCCC1
# ..                                               ...             ...
# 509        [N=c1cc[nH]cc1, C1CCC2CNCCC2C1, C1CCCCC1]  C1CCC2CNCCC2C1
# 510  [c1ccccc1, c1ccccc1, O=c1cc[nH]cn1, C1=CCNC=C1]      C1=CCNC=C1
# 511           [O=c1cccc[nH]1, C1CCOC1, C1CC2CCCC2C1]    C1CC2CCCC2C1
# 514        [C1CCC2CNCCC2C1, C1CCCCC1, N=c1cc[nH]cc1]  C1CCC2CNCCC2C1
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]      C1=CNCN=C1
#
#         min_freq                                              inchi  Reymond  \
# 1    21243538754      InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True
# 2      109924300  InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True
# 3     4151021098       InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True
# 4    21243538754    InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True
# 5     4295567520  InChI=1S/C7H14O/c1-6-4-2-3-5-7(6)8/h6-8H,2-5H2...     True
# ..           ...                                                ...      ...
# 509        25368  InChI=1S/C25H37N3O4/c1-17-21(11-12-26-22(17)15...     True
# 510          132  InChI=1S/C25H25FN4O2/c1-18-4-2-3-5-22(18)27-11...     True
# 511      9064982  InChI=1S/C23H33NO8/c1-13-7-15(9-25)21(28)24(20...     True
# 514        25368  InChI=1S/C24H33N3O5/c28-22(26-20-10-11-25-12-1...     True
# 518           76  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True
#
#      Lipinski
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# ..        ...
# 509      True
# 510      True
# 511      True
# 514      True
# 518      True
#
# [328 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC20 database druglike molecules

# %%
ring_system_lookup_ZINC20 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC20_rings_ststem.csv")
res_zinc20 = df.mol.apply(ring_system_lookup_ZINC20.process_mol)
res_zinc20
# Out:
# 0                                     [(C1=CC=CCC=1, 5)]
# 1                                [(c1ccccc1, 503413992)]
# 2                                   [(C1=COCC1, 263133)]
# 3                                  [(C1CCOC1, 34263706)]
# 4                                [(c1ccccc1, 503413992)]
#                              ...
# 517      [(C=C1CCCCNC1, 0), (c1ccc2c(c1)CC1OCCCN1C2, 0)]
# 518    [(N=c1cc[nH]cc1, 1059180), (c1ccccc1, 50341399...
# 519    [(c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, 0), (c1cccc...
# 520    [(c1c2c(cc3c1OCCCO3)CCCC2, 0), (c1ccccc1, 5034...
# 521    [(O=c1cccc[nH]1, 4043767), (C1CCOC1, 34263706)...
# Name: mol, Length: 522, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc20.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0                                         CC1=CC=C=CC1
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# ..                                                 ...
# 517  C=C1CCCCN(C(=O)Nc2cc(F)c3c(c2O)C(CO)N2CC(O)C(C...
# 518  Cc1c[nH]cc(O)c1=NCCc1ccc(O)c(C2=CC=NCN2CN2C=CC...
# 519  O=C(O)c1ccc2c(c1)C(O)c1cc3c(c(O)c1O2)OC(c1cccc...
# 520  CCC1C(O)c2c(cc3c(c2O)OC(c2ccccc2)C(F)(F)CO3)C(...
# 521  Cc1cc(C(=O)O)c(=O)n(C2CC(COCC3CC(O)C4OCCCC34)O...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac00>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# ..                                                ...
# 517  <rdkit.Chem.rdchem.Mol object at 0x7e2714c66ea0>
# 518  <rdkit.Chem.rdchem.Mol object at 0x7e2714c670d0>
# 519  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67060>
# 520  <rdkit.Chem.rdchem.Mol object at 0x7e2714c67290>
# 521  <rdkit.Chem.rdchem.Mol object at 0x7e2714c674c0>
#
#                                          ring_sytems  \
# 0                                      [C1=CC=CCC=1]
# 1                                         [c1ccccc1]
# 2                                         [C1=COCC1]
# 3                                          [C1CCOC1]
# 4                                         [c1ccccc1]
# ..                                               ...
# 517            [C=C1CCCCNC1, c1ccc2c(c1)CC1OCCCN1C2]
# 518  [N=c1cc[nH]cc1, c1ccccc1, C1=CNCN=C1, C1=CNCC1]
# 519      [c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3, c1ccccc1]
# 520              [c1c2c(cc3c1OCCCO3)CCCC2, c1ccccc1]
# 521          [O=c1cccc[nH]1, C1CCOC1, C1COC2CCCC2C1]
#
#                             min_ring   min_freq  \
# 0                        C1=CC=CCC=1          5
# 1                           c1ccccc1  503413992
# 2                           C1=COCC1     263133
# 3                            C1CCOC1   34263706
# 4                           c1ccccc1  503413992
# ..                               ...        ...
# 517                      C=C1CCCCNC1          0
# 518                       C1=CNCN=C1         40
# 519  c1ccc2c(c1)Cc1cc3c(cc1O2)OCCCO3          0
# 520          c1c2c(cc3c1OCCCO3)CCCC2          0
# 521                    C1COC2CCCC2C1          0
#
#                                                  inchi  Reymond  Lipinski
# 0         InChI=1S/C7H8/c1-7-5-3-2-4-6-7/h3-5H,6H2,1H3     True      True
# 1        InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True      True
# 2    InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True      True
# 3         InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True      True
# 4      InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True      True
# ..                                                 ...      ...       ...
# 517  InChI=1S/C22H30FN3O6/c1-12-4-2-3-5-25(8-12)22(...     True      True
# 518  InChI=1S/C23H25F2N5O2/c1-16-11-27-12-21(32)22(...     True      True
# 519  InChI=1S/C23H16F2O7/c24-23(25)10-30-16-9-14-17...     True      True
# 520  InChI=1S/C23H24F2O7/c1-2-12-16(22(29)30)14(9-2...     True      True
# 521  InChI=1S/C22H31NO9/c1-11-5-15(22(28)29)21(27)2...     True      True
#
# [522 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1                                         Cc1ccc(O)cc1
# 2                                        CCC1CC(C)=CO1
# 3                                         OC1COC(O)C1O
# 4                                           CCc1ccccc1
# 5                                           CC1CCCCC1O
# ..                                                 ...
# 480  CC1=CC(C)CCC1NCCc1ccc(O)c(-c2ccnc(=O)n2Cn2ccc(...
# 487  Cc1ccccc1NCCc1ccc(O)c(C2=CCN=CN2Cn2ccc(F)cc2=O)c1
# 492  C=CCC=Cc1c(C2CCCC(=O)O2)cc2c(c1O)OC(c1ccccc1)C...
# 496  COc1ccc2c(c1O)OC(O)C(Oc1ccccc1NCCCC(C)=NCC(C)=...
# 500  Cc1c[nH]ccc1=NCCc1ccc(O)c(-c2cc(=O)ncn2CN2C=CC...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e2714caac70>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e2714caace0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e2714caad50>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e2714caadc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e2714caae30>
# ..                                                ...
# 480  <rdkit.Chem.rdchem.Mol object at 0x7e2714caff40>
# 487  <rdkit.Chem.rdchem.Mol object at 0x7e2714c64660>
# 492  <rdkit.Chem.rdchem.Mol object at 0x7e2714c64890>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7e2714c65540>
# 500  <rdkit.Chem.rdchem.Mol object at 0x7e2714c65930>
#
#                                            ring_sytems         min_ring  \
# 1                                           [c1ccccc1]         c1ccccc1
# 2                                           [C1=COCC1]         C1=COCC1
# 3                                            [C1CCOC1]          C1CCOC1
# 4                                           [c1ccccc1]         c1ccccc1
# 5                                           [C1CCCCC1]         C1CCCCC1
# ..                                                 ...              ...
# 480   [C1=CCCCC1, c1ccccc1, O=c1nccc[nH]1, c1cc[nH]c1]    O=c1nccc[nH]1
# 487    [c1ccccc1, c1ccccc1, C1=CNC=NC1, O=c1cccc[nH]1]       C1=CNC=NC1
# 492          [c1ccc2c(c1)OCCCO2, O=C1CCCCO1, c1ccccc1]       O=C1CCCCO1
# 496                        [C1=Cc2ccccc2OC1, c1ccccc1]  C1=Cc2ccccc2OC1
# 500  [N=c1cc[nH]cc1, c1ccccc1, O=c1cc[nH]cn1, C1=CN...        C1=CNCCC1
#
#       min_freq                                              inchi  Reymond  \
# 1    503413992      InChI=1S/C7H8O/c1-6-2-4-7(8)5-3-6/h2-5,8H,1H3     True
# 2       263133  InChI=1S/C7H12O/c1-3-7-4-6(2)5-8-7/h5,7H,3-4H2...     True
# 3     34263706       InChI=1S/C4H8O4/c5-2-1-8-4(7)3(2)6/h2-7H,1H2     True
# 4    503413992    InChI=1S/C8H10/c1-2-8-6-4-3-5-7-8/h3-7H,2H2,1H3     True
# 5     40360716  InChI=1S/C7H14O/c1-6-4-2-3-5-7(6)8/h6-8H,2-5H2...     True
# ..         ...                                                ...      ...
# 480     586131  InChI=1S/C25H30N4O3/c1-17-3-5-22(18(2)13-17)26...     True
# 487       2053  InChI=1S/C25H25FN4O2/c1-18-4-2-3-5-22(18)28-12...     True
# 492        270  InChI=1S/C25H24F2O5/c1-2-3-5-11-17-18(19-12-8-...     True
# 496     274560  InChI=1S/C24H28N2O6/c1-15(26-14-16(2)27)7-6-12...     True
# 500        158  InChI=1S/C24H26FN5O2/c1-17-14-26-8-5-21(17)27-...     True
#
#      Lipinski
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# ..        ...
# 480      True
# 487      True
# 492     False
# 496      True
# 500      True
#
# [225 rows x 8 columns]
