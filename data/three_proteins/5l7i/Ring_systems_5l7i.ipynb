# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob
import molvs
from multiprocessing import Pool, cpu_count
from tqdm.auto import tqdm

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins

# %% [markdown]
# Reading data from crossdock dataset, add a standardization for small molecule data:

# %%
standardizer = molvs.standardize.Standardizer()

def standardize_mol(mol):
    try:
        mol = standardizer.standardize(mol)
        mol = standardizer.fragment_parent(mol, skip_standardize=True)
        mol = standardizer.tautomer_parent(mol, skip_standardize=True)
        mol = standardizer.isotope_parent(mol, skip_standardize=True)
        mol = standardizer.charge_parent(mol, skip_standardize=True)
        return mol
    except:
        return None

# %%
smi_list = []
with open('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i/5l7i_top500_smiles_cpu.smi') as f:
    for smi in f:
        smi_list.append(smi.strip())
standardized_smiles_list = []
for smi in tqdm(smi_list, desc="Standardizing molecules", unit="mol"):
    mol = Chem.MolFromSmiles(smi)
    mol = standardize_mol(mol)
    
    if mol:
        standardized_smiles_list.append(Chem.MolToSmiles(mol))
    else:
        print(f"Skipping molecule {smi}")
        pass

print(len(smi_list))
len(standardized_smiles_list)
# Out:
# Standardizing molecules:   0%|          | 0/500 [00:00<?, ?mol/s]
# 500
# 500

# %% [markdown]
# Set the default image size

# %%
with open('5l7i_top500_smiles_standardized_cpu.smi', 'w') as f:
    for item in standardized_smiles_list:
        f.write("%s\n" % item)

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(standardized_smiles_list, columns=['SMILES'])
df
# Out:
#                                                 SMILES
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
# [500 rows x 1 columns]

# %% [markdown]
# Remove repeated molecules

# %%
df = df.drop_duplicates(['SMILES'])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                 SMILES
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
# [500 rows x 1 columns]

# %% [markdown]
# Save the smi file for further use

# %%
smi_export_list = df['SMILES'].tolist()
with open('crossdock_ligand_smi.smi', 'w') as f:
    for item in smi_export_list:
        f.write("%s\n" % item)

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0      [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1       [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2      [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3      [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4       [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
#                              ...
# 495    [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                       [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497    [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498    [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499                 [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
# Name: ring_sytems, Length: 500, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['N=c1cc[nH][nH]1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'O=C1NCCN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCC1', 'c1cnc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ncon1', 'O=c1[nH]ncc2ccccc12']),
#        list(['c1ccccc1', 'c1nnc2n1CCCC2', 'N=c1[nH][nH]c2[nH]c(=O)ccc12']),
#        list(['C1CNCCN1', 'c1ccccc1', 'C1CCNCC1', 'c1ccc2[nH]ccc2c1']),
#        list(['O=C1CNc2ccccc2N1', 'c1ccccc1', 'c1n[nH]c2c1CCC2', 'c1ccccc1']),
#        list(['c1ccc2c(c1)ccc1ccoc12', 'O=C1COc2ccccc2N1']),
#        list(['c1nc[nH]n1', 'c1ccccc1', 'c1ncon1', 'O=C1CCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'C1CNC1', 'c1ccc2ncccc2c1']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccccc1', 'c1ccc2[nH]ccc2c1']),
#        list(['C1[C@H]2[C@H]3C[C@H]4[C@@H]1[C@H]1[C@@H]2C[C@@H]3[C@@H]41', 'C1CC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccoc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccc2c(c1)OCCO2']),
#        list(['c1ccncc1', 'c1ccccc1', 'C1CCNCC1', 'c1ccccc1']),
#        list(['N=c1nccc[nH]1', 'c1ccccc1', 'O=c1nc[nH]c2ccccc12']),
#        list(['c1ccc2c(c1)OCCO2', 'C1CCNCC1', 'O=c1ccnc2ccccn12']),
#        list(['c1ccc2c3c([nH]c2c1)CCCC3', 'C1CCNCC1', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2c(c1)CCO2']),
#        list(['N=c1[nH]cnc2ccccc12', 'C1CNCCN1', 'O=c1[nH]c2ccccc2[nH]1', 'C1CCCC1']),
#        list(['O=C1NC(=O)c2ccccc21', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['N=c1cccc[nH]1', 'c1ccc2c(c1)CCO2', 'C1CCNCC1', 'c1ccccc1']),
#        list(['O=C1CNc2ccccc2N1', 'O=C1OCCc2ccccc21', 'c1ccccc1']),
#        list(['N=c1ccc2ccccc2[nH]1', 'c1ccccc1', 'O=c1[nH]c2cccnc2[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1cn[nH]c1', 'c1ccc2[nH]ccc2c1', 'c1ccc2c(c1)CCN2']),
#        list(['c1ccc2c(c1)CCCN2', 'O=C1CCCc2[nH]ccc21']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1CCNCC1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'C1CNCCN1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1cnc2[nH]ncc2c1', 'c1ccccc1', 'C1CCNCC1', 'c1ccc2c(c1)CCN2']),
#        list(['O=c1ccc2ccccc2o1', 'O=c1cc[nH]c2ccnn12', 'c1ccccc1']),
#        list(['N=c1cn[nH]c2ccccc12', 'O=C1c2ccccc2S(=O)(=O)c2ccccc21']),
#        list(['c1cn[nH]c1', 'c1ccncc1', 'C1CNCCN1', 'O=C1CCCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1nc2c(c[nH]1)[C@H]1CC[C@@H](C2)N1', 'c1ccccc1']),
#        list(['O=C1CNC(=O)N1', 'c1ccccc1', 'c1ncon1', 'c1ccc2c3c([nH]c2c1)CCCC3']),
#        list(['O=C1CCCCN1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['N=c1[nH]c(=O)c2cn[nH]c2[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1[nH]nc2c1COCC2']),
#        list(['c1ccc2c(c1)CCNC2', 'O=C1c2ccccc2S(=O)(=O)c2ccccc21']),
#        list(['c1ccoc1', 'c1ccccc1', 'c1ccc2c(c1)CCNC2', 'c1ccc2c(c1)Cc1ccccc1-2']),
#        list(['O=C1N=CCCN1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1[nH]nc2c1CCCC2', 'c1ccccc1', 'c1ccc2c(c1)CCO2']),
#        list(['C1CCNCC1', 'c1ccccc1', 'O=c1[nH]ncc2ccccc12']),
#        list(['c1cnc2c(c1)CCC2', 'C1CCNCC1', 'c1ccc2cnccc2c1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1cn[nH]c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]c(=O)c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['O=C1NC(=O)[C@@]2(CCc3ccccc32)N1', 'c1ccccc1', 'O=c1[nH]nc2ccccn12']),
#        list(['N=c1[nH]c2c(c(=O)[nH]1)CCCC2', 'C1CCNCC1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'O=S1(=O)Cc2ccccc2N1']),
#        list(['c1cn[nH]c1', 'C1CNCCN1', 'c1c[nH]nn1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NCCCN1', 'c1ccccc1', 'c1ncon1']),
#        list(['O=C1NC(=O)c2ccccc21', 'c1ncon1', 'O=c1ccc2c([nH]1)CCCC2', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CNC2', 'c1ccc2c(c1)CC2', 'c1ccc2c(c1)CC2']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'O=c1cccc[nH]1']),
#        list(['c1ccc2sccc2c1', 'C1CNCCN1', 'N=c1[nH]nc2ccccn12']),
#        list(['C1CCNC1', 'c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)CCO2']),
#        list(['c1ccc2c(c1)CCNC2', 'O=c1nc[nH]c2sccc12', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccoc1', 'c1ccccc1', 'c1ccn2cnnc2c1']),
#        list(['N=c1[nH]nn[nH]1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cc2c(o1)CCc1cn[nH]c1-2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'O=c1[nH]cc[nH]1']),
#        list(['O=C1CNC(=O)N1', 'c1ccccc1', 'C1CN[C@H]2CCNC[C@@H]2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1nnco1', 'c1ccccc1', 'c1ccccc1', 'C1CC1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cccc[nH]1', 'O=S1(=O)CCCc2ccccc21']),
#        list(['c1ccc2ncccc2c1', 'c1ccc2c(c1)NCC21CCCC1']),
#        list(['N=c1[nH]cnc2[nH]cnc12', 'c1ccccc1', 'c1ccc2c(c1)CCO2']),
#        list(['C1CCNC1', 'O=C1CCCc2ccccc21', 'O=C1CCCc2ccccc21']),
#        list(['N=c1nccc[nH]1', 'c1ccccc1', 'C1CNCCN1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c3c([nH]c2c1)CCCC3', 'O=c1c2ccccc2[nH]c2ccccc12']),
#        list(['c1ccc2c3c([nH]c2c1)CCCC3', 'C1[C@H]2[C@H]3C[C@H]4[C@@H]1[C@H]1[C@@H]2C[C@@H]3[C@@H]41']),
#        list(['O=c1nc[nH]c2ccccc12', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1nnco1', 'c1ccc2c(c1)OCCO2', 'C1CCNCC1']),
#        list(['N=c1[nH]c(=O)c2ccccc2[nH]1', 'C1CC1', 'c1ccc2ccccc2c1']),
#        list(['c1cnc2[nH]ncc2c1', 'c1ccncc1', 'C1CCNCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1ccc2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccc2[nH]ccc2c1', 'N=c1[nH]ccs1', 'O=C1CCc2ccccc2N1']),
#        list(['N=c1[nH][nH]c2c1CCCC2', 'c1ccc2c(c1)CCN2', 'c1ncc2cn[nH]c2n1']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['N=c1cco[nH]1', 'c1ccccc1', 'c1ccc2ocnc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1[nH]cnc2sccc12', 'c1ccccc1']),
#        list(['C1[C@H]2[C@H]3C[C@H]4[C@@H]1[C@H]1[C@@H]2C[C@@H]3[C@@H]41', 'C1CCNCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1[nH]nc2ccccn12', 'C1CCCC1', 'c1ccccc1']),
#        list(['c1ccn2ccnc2c1', 'c1ncon1', 'c1ccccc1', 'C1CCOC1']),
#        list(['c1ccc2ccccc2c1', 'C1CNCCN1', 'O=c1cccn[nH]1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)oc1ccccc12', 'c1ccccc1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccccc1', 'O=c1ccc2ccccc2[nH]1', 'c1cc2c(s1)CCNC2']),
#        list(['c1ccc2c(c1)CCN2', 'O=c1c2ccccc2[nH]c2ccccc12']),
#        list(['O=c1[nH]c2ccccc2[nH]c1=O', 'C1CNCCN1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)CCO2', 'c1ccccc1', 'O=c1[nH]nc2ccccn12']),
#        list(['c1ccncc1', 'c1ccsc1', 'c1cnc2c(c1)OCCO2']),
#        list(['c1ccncc1', 'c1ccccc1', 'O=C1CCc2ccccc2N1']),
#        list(['C1CCCC1', 'c1c[nH]nn1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cnn2ccnc2c1']),
#        list(['c1ccccc1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['c1cnoc1', 'c1ccccc1', 'c1ccc2c(c1)OCCO2']),
#        list(['O=C1CC[C@@H]2CNc3cccc1c32', 'O=C1NC(=O)c2ccccc21', 'c1ccncc1']),
#        list(['O=c1ccnc2ccccn12', 'O=c1nc[nH]c2sccc12', 'c1ccccc1']),
#        list(['c1cc2c(s1)CCCC2', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'C1CC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC2', 'O=c1[nH]cc[nH]1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)OCO2', 'C1CCNCC1', 'O=c1nc[nH]c2ccccc12']),
#        list(['O=c1[nH]cnc2sccc12', 'c1ccc2c(c1)CCNC2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1c[nH]nn1', 'c1ncon1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'c1nn[nH]n1', 'c1ccncc1', 'c1cnc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'c1ccoc1']),
#        list(['c1c[nH]nn1', 'c1ccncc1', 'c1ccc2c(c1)[nH]c1ccccc12']),
#        list(['C1CC[C@@H]2NCC[C@@H]2C1', 'c1ccccc1', 'C1=CCNCC1', 'c1cnc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]cnc2[nH]ncc12']),
#        list(['c1ccc2c(c1)CCCC2', 'C1CCNC1', 'c1ccc2c(c1)OCCO2']),
#        list(['c1ccc2n[nH]cc2c1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'C1CCNCC1', 'O=S1(=O)N=Cc2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=C1CNC(=O)N1']),
#        list(['c1cscn1', 'c1ccccc1', 'c1ccc2c(c1)oc1ccccc12']),
#        list(['c1ccc2c(c1)OCO2', 'C1CCNCC1', 'c1ccc2[nH]nnc2c1']),
#        list(['c1ccoc1', 'c1ccccc1', 'C1CCNCC1', 'c1ccc2ocnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccc2ncncc2c1']),
#        list(['c1ccc2c(c1)CCNC2', 'O=C1CNC(=O)N1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'O=c1[nH]ccc2ccccc12']),
#        list(['C1CC[C@H]2C[C@H]2C1', 'O=C1c2ccccc2S(=O)(=O)c2ccccc21']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccoc1', 'c1ccc2scnc2c1']),
#        list(['O=c1cccn[nH]1', 'N=c1cc[nH][nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'c1ccccc1', 'c1nn[nH]n1']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'c1ccc2c(c1)CC[C@H]1C[C@@H]21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'O=c1nc2cc[nH]n2c2ccccc12', 'c1cn2cnnc2cn1']),
#        list(['c1ccccc1', 'c1nnc2n1CCNC2', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1cnc2n[nH]cc2c1', 'O=C1CCCc2[nH]c(=O)ccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1ccn2c3c(cccc13)CCC2', 'C1CCNCC1', 'c1c[nH]nn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cnc2[nH]ccc2c1', 'c1cnc2[nH]ccc2c1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1ccccc1', 'O=C1CCCN1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'C1CCNCC1', 'c1ccc2c(c1)CCNC2']),
#        list(['C1CCNCC1', 'c1ccccc1', 'O=c1[nH]nnc2ccccc12']),
#        list(['O=C1CNC(=O)N1', 'c1ccccc1', 'c1ncon1', 'C1=NOCC1', 'c1ccccc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'C1CCNCC1', 'c1ncon1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCCC2', 'c1ncon1', 'C1CCNCC1', 'c1cnn2cnnc2c1']),
#        list(['c1ccccc1', 'c1ncon1', 'c1ccc2cnccc2c1', 'c1ccc2c(c1)CCNC2']),
#        list(['O=c1ccc2c([nH]1)CCCC2', 'c1ncon1', 'O=C1CCCc2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]ncc2ccccc12']),
#        list(['C1CNCCN1', 'O=c1cc[nH]c(=O)[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CCC2CCCCC2N1', 'c1ccccc1', 'c1ncn2c1CCCC2']),
#        list(['c1ccc2c3c([nH]c2c1)CCCC3', 'c1ccccc1', 'C1CC1']),
#        list(['N=c1nc[nH][nH]1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccccc1']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'c1ccccc1', 'O=c1[nH]cc[nH]1']),
#        list(['c1ccc2c(c1)C[C@@H]1C[C@H]21', 'C1CCNCC1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1CCCN1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21']),
#        list(['N=c1[nH]c(=O)c2cn[nH]c2[nH]1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ocnc2c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21']),
#        list(['c1ccccc1', 'O=C1CCCCN1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['N=c1ccn2ncnc2[nH]1', 'O=C1OCCc2ccccc21', 'c1ccccc1']),
#        list(['C=C1N=COC1=O', 'c1ccccc1', 'c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['N=c1[nH]c(=O)c2ccccc2[nH]1', 'c1nc[nH]n1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2[nH]cnc2c1', 'C1CCNCC1', 'O=C1c2ccccc2S(=O)(=O)c2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1ncc2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNC1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['N=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'O=c1[nH]ncc2ccccc12']),
#        list(['c1ccccc1', 'c1nc[nH]n1', 'C1CC1', 'c1[nH]cc2c1[C@@H]1CC[C@H]2O1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccccc1', 'c1ccc2c(c1)OCCO2']),
#        list(['c1ccc2ocnc2c1', 'c1ccc2ccccc2c1', 'O=c1[nH]nc2ccccn12']),
#        list(['N=c1cn[nH][nH]1', 'C1CCNC1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['O=C1COc2ccccc2N1', 'c1ccc2nocc2c1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'c1ncon1', 'C1CC1']),
#        list(['C1COCCN1', 'O=c1nc[nH]c2ccccc12', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNC1', 'c1ccn2cnnc2c1']),
#        list(['C=C1Cc2ccccc2N1', 'O=C1CNC(=O)N1', 'c1ccc2ccccc2c1']),
#        list(['N=c1cccc[nH]1', 'c1ccccc1', 'c1nnco1', 'c1ccccc1']),
#        list(['N=c1nc[nH]c(=N)[nH]1', 'c1ncon1', 'c1ccccc1', 'C1CCOCC1', 'c1ccccc1']),
#        list(['O=C1COc2ccccc2N1', 'C1CCNCC1', 'O=C1CCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'C1=NOCC1', 'c1ccccc1']),
#        list(['O=C1CCCCN1', 'c1ccccc1', 'C1CCOCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1[nH]cn[nH]1', 'c1ccc2[nH]ccc2c1', 'c1ccccc1']),
#        list(['O=c1[nH]ncc2ccccc12', 'C1CNCCN1', 'c1ccc2c(c1)OCCO2']),
#        list(['c1cnc2n[nH]cc2c1', 'C1C[C@H]2CC[C@@H]1N2', 'O=C1NC(=O)c2ccccc21']),
#        list(['O=C1CCCc2ccccc21', 'c1ncon1', 'O=c1cccc[nH]1', 'c1ccncc1']),
#        list(['O=c1[nH]ccc2ccccc12', 'C1CCCC1', 'c1c[nH]nn1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1nc[nH]c2ccccc12', 'N=c1nc[nH][nH]1', 'c1ccccc1']),
#        list(['O=C1CCc2ccccc21', 'C1CCCC1', 'O=C1CCc2ccccc21']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'c1ccccc1', 'c1nnn[nH]1']),
#        list(['c1cnc2occc2c1', 'O=C1CSc2ccccc2N1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1ccc2[nH]ccc2c1', 'c1nnn[nH]1']),
#        list(['O=c1nc[nH]c2n[nH]cc12', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'c1ccccc1', 'c1cncnc1']),
#        list(['O=c1nc[nH]c2ccccc12', 'c1ccc2c(c1)Cc1ccccc1-2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2ncccc2c1']),
#        list(['c1ccc2ncccc2c1', 'C1CCNC1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2cnncc2c1', 'O=c1ccc2ccccc2o1']),
#        list(['c1ccccc1', 'O=c1ccc2c([nH]1)CCC2', 'c1ccc2c(c1)CCCC2']),
#        list(['O=C1CSc2ccccc2N1', 'N=c1[nH]ccs1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCc1cnoc1-2', 'C1CCNCC1', 'c1ccn2cnnc2c1']),
#        list(['c1ccc2ccccc2c1', 'C1CCNCC1', 'c1nc[nH]n1', 'C1CCCCC1']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'c1ccc2c(c1)CCN2']),
#        list(['c1cn[nH]c1', 'c1ccc2c(c1)OCCO2', 'C1CCNCC1', 'c1cnc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1ccccc1', 'c1cocn1']),
#        list(['O=c1ccnc[nH]1', 'c1ccccc1', 'O=C1c2ccccc2S(=O)(=O)c2ccccc21']),
#        list(['N=c1[nH]nc2ccccn12', 'C1COCCN1', 'O=c1nc[nH]c2ccccc12']),
#        list(['c1ccccc1', 'O=S1(=O)CCCN1', 'c1ccc2c(c1)CCCO2']),
#        list(['c1cc2n(n1)CCCC2', 'C1CCNCC1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1[nH][nH]c2ccccc12', 'N=c1[nH][nH]c2ccccc12']),
#        list(['O=c1cc[nH]nc1', 'c1ccc2c(c1)OC1(CCCC1)O2', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NC(=O)C2(CCCC2)N1', 'C1[C@H]2[C@H]3C[C@H]4[C@@H]1[C@H]1[C@@H]2C[C@@H]3[C@@H]41']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1cnoc1', 'c1ccc2ccccc2c1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccc2[nH]cnc2c1', 'C1CCNC1', 'c1cc[nH]c1', 'c1ccc2c(c1)OCCO2']),
#        list(['C1CNCCN1', 'c1ncon1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1COc2ccccc2N1', 'C1CCNCC1', 'c1n[nH]c2c1CCC2', 'c1ccccc1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ncon1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc[nH][nH]1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2occc2c1']),
#        list(['c1ccc2[nH]ccc2c1', 'C1CCNCC1', 'c1cc[nH]c1', 'c1ccc2c(c1)OCCO2']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1NC(=O)C2(CCCC2)N1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1nn[nH]n1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccc2[nH]cnc2c1', 'C1CCNCC1', 'c1nnn[nH]1', 'c1ccccc1']),
#        list(['O=C1c2ccccc2-c2ccccc21', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'O=C1N=CCCN1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]cnc2ccccc12']),
#        list(['O=c1[nH]c(=O)c2cccnc2[nH]1', 'C1CC1', 'C1CCNCC1', 'c1cnc2[nH]ccc2c1']),
#        list(['c1ccncc1', 'c1ccc2c(c1)CCNC2', 'O=c1[nH]c2ncnn2c2ccccc12']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'C1CCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'C1CCNCC1', 'c1ccccc1']),
#        list(['c1cc2c([nH]1)CCCC2', 'C1C[C@@H]2C[C@H]1CN2', 'C1CCCC1']),
#        list(['c1ccccc1', 'C1CCOC1', 'c1ccccc1', 'c1ccc2c(c1)CCO2']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1ncc2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['c1cncnc1', 'c1ccccc1', 'c1ccc2c(c1)CCN2']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCN2', 'C1CNCCN1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'N=c1[nH]c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'O=c1nc[nH]c2sccc12', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1[nH]ccs1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1CCCc2[nH]c(=O)ccc21', 'c1ccc2c(c1)CCCC2']),
#        list(['c1ccc2c(c1)CCN2', 'c1ncc2cn[nH]c2n1', 'O=c1cccc[nH]1', 'c1ccccc1']),
#        list(['c1ccc2[nH]nnc2c1', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCC1', 'c1c[nH]nn1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)Cc1ccccc1-2', 'O=c1[nH]ccc2ccccc12']),
#        list(['C1COCCN1', 'c1ccccc1', 'O=c1[nH]c2cccnc2[nH]1', 'c1ccccc1']),
#        list(['c1cnc2ccnn2c1', 'c1ncon1', 'c1ccccc1', 'c1ccc2c(c1)CCO2']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2cccc3cccc1c23', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'O=c1cccn[nH]1', 'c1ccccc1']),
#        list(['N=c1cc[nH][nH]1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2nonc2c1', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['O=c1[nH]c2ncccc2o1', 'C1CCNCC1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1C2CC3CC1CC(C2)C3', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1cc[nH][nH]1', 'c1ccc2[nH]cnc2c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2occc2c1', 'c1ncon1', 'c1ccccc1', 'C1CCOC1']),
#        list(['O=c1nc[nH]c2ccccc12', 'C1CNCCN1', 'c1ccccc1']),
#        list(['O=C1NC(=O)c2ccccc21', 'c1ccccc1', 'c1nnco1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCC1', 'c1ccn2cnnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCC1', 'O=S1(=O)N=Cc2ccccc21']),
#        list(['c1ccccc1', 'N=c1[nH]ccs1', 'O=c1ccc2ccccc2[nH]1']),
#        list(['O=C1CNc2ccccc2N1', 'c1ccncc1', 'c1ccc2c(c1)CCO2']),
#        list(['c1cnc2ncnn2c1', 'c1ncon1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cscn1', 'c1ccoc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cc[nH]c1', 'C1CCNCC1', 'O=C1COc2ccccc2N1']),
#        list(['C=C1NCCc2ccccc21', 'c1ccccc1', 'C=C1NCCc2ccccc21']),
#        list(['O=c1ccc2ccoc2[nH]1', 'C1CCNCC1', 'c1ncon1', 'c1ccccc1']),
#        list(['c1nnc[nH]1', 'O=c1[nH]ncc2ccccc12', 'C1CCNCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]ccc2c1CNCC2']),
#        list(['c1ccccc1', 'c1nnco1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1nc[nH]n1', 'c1nc[nH]n1']),
#        list(['c1ccccc1', 'C1CCOC1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['c1nc[nH]n1', 'c1ccc2c(c1)CCN2', 'c1ccccc1', 'c1nc[nH]n1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1ncc2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCCC2', 'c1ccccc1', 'O=C1CNC(=O)N1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2n[nH]cc2c1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccccc1', 'O=c1[nH]cc[nH]1']),
#        list(['c1ccccc1', 'c1cc[nH]c1', 'C1CNCCN1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CNC(=O)N1', 'c1ccccc1', 'c1ncon1', 'N=c1cccc[nH]1', 'c1ccccc1']),
#        list(['c1ccc2ncccc2c1', 'c1ccoc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCNC2', 'O=c1c2ccccc2[nH]c2ccccc12']),
#        list(['c1ccccc1', 'c1ccn2ccnc2c1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1C2CC3CC1CC(C2)C3', 'O=C1Nc2ccccc2[C@@]12CCNC2']),
#        list(['O=C1NCC2(CCNCC2)O1', 'C1COCCN1', 'O=c1nc[nH]c2ccccc12']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccc2[nH]ccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccc2c3c([nH]c2c1)CCNC3']),
#        list(['c1ccn2nccc2c1', 'O=c1[nH]c2ccccc2o1', 'C1CCNCC1']),
#        list(['N=c1[nH][nH]c2ccccc12', 'C1CCCCC1', 'N=c1[nH][nH]c2ccccc12']),
#        list(['C1CCNCC1', 'c1ccc2ccccc2c1', 'c1ccc2c(c1)CCCN2']),
#        list(['O=C1CNc2ccccc2N1', 'C1=CCNCC1', 'c1ccc2[nH]ccc2c1']),
#        list(['N=c1cccc[nH]1', 'C1CCNCC1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CNC(=O)N1', 'c1ccccc1', 'C1CCNCC1', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCC1', 'c1cnn2nnnc2c1']),
#        list(['O=C1COc2ccccc2N1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['N=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccc2ncccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CC1', 'c1ccccc1', 'c1ccc2c(c1)OCCO2']),
#        list(['c1ccc2c(c1)CCCN2', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1', 'c1nc[nH]n1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2c(c1)CCCN2']),
#        list(['c1ccc2c(c1)OCc1cncn1-2', 'C1CCNCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2c(c1)CCCC2']),
#        list(['c1ccc2c(c1)CCN2', 'c1ccccc1']),
#        list(['C1=CC2(CCNCC2)Oc2ccccc21', 'O=c1cccc[nH]1']),
#        list(['c1ccccc1', 'c1cc[nH]c1', 'N=c1nc[nH][nH]1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'C1CCNC1', 'N=c1nc[nH]c(=N)[nH]1', 'c1ccccc1']),
#        list(['O=c1c2ccccc2nc2n1CCC2', 'c1ccoc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)oc1ccccc12', 'O=c1[nH]ncc2ccccc12']),
#        list(['O=c1nc[nH]c2sccc12', 'O=c1nc[nH]c2[nH]ncc12', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2[nH]ncc2c1', 'C1CNCCN1', 'O=c1cccn[nH]1']),
#        list(['c1ccc2ccccc2c1', 'N=c1[nH]ccs1', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNC1', 'c1ccccc1']),
#        list(['C1CCOCC1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1c[nH]nn1', 'C1CNC1', 'c1ccc2c(c1)oc1ccccc12']),
#        list(['O=c1ccnc[nH]1', 'c1ccccc1', 'O=c1nc[nH]c2sccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cnc2c(c1)ccc1cccnc12']),
#        list(['c1ccccc1', 'c1ccncc1', 'C1CNCCN1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2occc2c1', 'c1ccccc1', 'O=C1CNC(=O)N1']),
#        list(['O=C1NCc2ccccc21', 'c1ccccc1', 'O=C1NCc2ccccc21']),
#        list(['c1ccn2cnnc2c1', 'c1ncon1', 'c1ccccc1', 'c1ccc2c(c1)CCO2']),
#        list(['O=c1c2ccccc2[nH]c2ccccc12', 'O=C1Nc2ccccc2[C@]12CCNC2']),
#        list(['N=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccccc1', 'O=c1[nH]cc[nH]1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2ccccc2c1', 'C1CNCCN1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['N=c1nc[nH][nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)CCO2']),
#        list(['N=c1cc[nH][nH]1', 'c1ccncc1', 'C1CCNC1', 'c1ccccc1']),
#        list(['O=C1CCc2ccccc2N1', 'N=c1cccc[nH]1', 'c1ccccc1']),
#        list(['c1cc2c3c(cccc3c1)-c1nc3ccccc3nc1-2', 'c1ccccc1']),
#        list(['N=c1[nH][nH]c2c1CCC2', 'c1ccccc1', 'C1CCNCC1', 'c1c[nH]cn1']),
#        list(['O=C1NCc2ccccc2N1', 'N=c1[nH]ccs1', 'c1cnc2c(c1)CCC2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)CCNC2']),
#        list(['c1ccoc1', 'C1CCNCC1', 'C1CCNCC1', 'O=S1(=O)N=Cc2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]ncc2ccccc12']),
#        list(['c1nc[nH]n1', 'C1CCNCC1', 'c1cn[nH]c1', 'c1ccc2ccccc2c1']),
#        list(['N=c1nc[nH][nH]1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1cnc2[nH]ncc2c1', 'c1ccccc1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=C1NS(=O)(=O)c2ccccc21']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCN2', 'O=c1[nH]c(=O)c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['O=c1[nH][nH]c(=O)c2ccccc12', 'C1CNCCN1', 'c1ccc2[nH]ccc2c1']),
#        list(['O=C1CNC(=O)N1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)CCN2']),
#        list(['O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccc2c(c1)oc1ccccc12']),
#        list(['c1ccc2c(c1)CNC2', 'c1n[nH]c2c1CCC2', 'c1ccccc1']),
#        list(['N=c1[nH][nH]c2nnccc12', 'O=C1OCCc2ccccc21', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1nc[nH][nH]1', 'O=C1CNC(=O)N1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'C1C2CC3CC1CC(C2)C3', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)CCCN2']),
#        list(['O=c1[nH]ncc2ccccc12', 'c1ccc2c(c1)CCC[C@]21CCCNC1']),
#        list(['c1ccccc1', 'c1nn[nH]n1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCNC2', 'C1=CCNCC1', 'c1cnc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'C1C2CC3CC1CC(C2)C3', 'O=c1[nH]ncc2ccccc12']),
#        list(['N=c1cc[nH][nH]1', 'c1ccc2ncccc2c1', 'N=c1[nH]cnc2ncccc12']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'C1CCNCC1', 'c1ccc2c(c1)CCN2']),
#        list(['O=c1nc2cc[nH]n2c2ccccc12', 'c1ccc2c(c1)CCN2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)nc1n2CCN1', 'c1ccc2c(c1)nc1n2CCN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]nnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCC1', 'c1nnc2n1CCC2']),
#        list(['c1ccncc1', 'c1ccc2[nH]cnc2c1', 'O=c1nc2cc[nH]n2c2ccccc12']),
#        list(['c1ccccc1', 'N=c1nc[nH]c(=N)[nH]1', 'O=c1ccc2ccccc2o1']),
#        list(['O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CC2(CCN1)CC2', 'c1nnco1', 'c1ccccc1']),
#        list(['c1ccc2c3c([nH]c2c1)CCCC3', 'O=C1NC(=O)C2(CCNCC2)N1']),
#        list(['N=c1cccc[nH]1', 'c1ccc2ccccc2c1', 'c1n[nH]c2c1CCCC2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'O=c1c2ccccc2nc2n1CCC2', 'c1ccccc1']),
#        list(['c1ccc2[nH]ccc2c1', 'c1nn[nH]n1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CCCCN1', 'c1ccccc1', 'c1ccccc1', 'O=c1nc[nH]o1']),
#        list(['c1ccccc1', 'c1ncon1', 'c1ccccc1', 'c1ccc2c(c1)CCO2']),
#        list(['c1ccc2c(c1)CCOC2', 'N=c1cccn[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CCC(=O)NN1', 'c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=c1[nH]cnc2ccccc12', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CCCc2[nH]c(=O)ccc21', 'C1CNCCN1', 'O=c1cccn[nH]1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC2', 'c1ccccc1', 'O=C1Nc2ccccc2[C@]12CCNC2']),
#        list(['c1ccccc1', 'c1ccc2ncccc2c1', 'c1ccc2ncccc2c1']),
#        list(['c1ccncc1', 'c1ccccc1', 'O=C1Nc2ccccc2[C@]12CCNC2']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21']),
#        list(['c1ccccc1', 'O=C1NC(=O)C2(CCCC2)N1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'O=C1c2ccccc2S(=O)(=O)c2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC[C@@H]2NCC[C@@H]2C1', 'c1ccccc1']),
#        list(['O=c1[nH][nH]c(=O)c2ccccc12', 'N=c1[nH]c2c(s1)CNCC2', 'c1ccccc1']),
#        list(['O=c1cc2ccccc2c[nH]1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1[nH]cnc2ccccc12', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1nnn[nH]1', 'c1ccccc1', 'C1CCNCC1', 'c1ccc2[nH]ncc2c1']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'N=c1cc[nH]c2ncnn12', 'c1ccccc1']),
#        list(['O=C1NCCO1', 'c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['C1[C@H]2[C@H]3C[C@H]4[C@@H]1[C@H]1[C@@H]2C[C@@H]3[C@@H]41', 'C1CCNCC1', 'c1ncon1', 'c1ccccc1']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'O=c1ccnc2[nH]c3ccccc3n12']),
#        list(['c1ccc2c(c1)CCCC2', 'C1CCNCC1', 'O=S1(=O)N=Cc2ccccc21']),
#        list(['O=c1c2ccsc2nc2ccccn12', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCNC2', 'O=C1OCCc2ccccc21', 'c1ccccc1']),
#        list(['N=c1nc[nH][nH]1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1cccn[nH]1', 'c1ccccc1', 'O=C1CNc2ccccc2N1']),
#        list(['O=c1[nH][nH]c(=O)c2ccccc12', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCN2', 'O=c1cccc[nH]1', 'c1ccccc1']),
#        list(['c1ccc2c3c([nH]c2c1)CCNC3', 'c1n[nH]c2c1CCC2', 'c1ccccc1']),
#        list(['N=c1nc[nH][nH]1', 'c1ccc2ncccc2c1', 'C1CCNCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'O=c1[nH]ncc2ccccc12']),
#        list(['c1ccccc1', 'N=c1cc[nH][nH]1', 'O=C1NC(=O)[C@]2(CCc3ccccc32)N1']),
#        list(['c1ccccc1', 'c1nc[nH]n1', 'c1ccc2ncccc2c1', 'c1ccccc1', 'O=S1(=O)CCNCC1']),
#        list(['O=c1ccc2ccccc2o1', 'C1CNCCN1', 'c1ccc2ccccc2c1']),
#        list(['O=C1COc2ccccc2N1', 'C1CCNCC1', 'N=c1cccc[nH]1']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'C1CCNCC1', 'c1ccc2c(c1)CCN2']),
#        list(['c1cc[nH]c1', 'c1ccccc1', 'O=c1cccn[nH]1', 'c1ccccc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1cnc2nc[nH]c2c1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccncc1', 'O=c1[nH]c2ccccc2o1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cc[nH][nH]1', 'c1cncnc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1[nH]c(=O)c2ccccc2[nH]1']),
#        list(['O=c1[nH]c(=O)c2cccnc2[nH]1', 'c1ccccc1', 'c1ncn2c1CCCC2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1CC1']),
#        list(['O=C1CNc2ccccc2N1', 'c1ncon1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'c1cocn1', 'C1CCNCC1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CCCCN1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1CCNCC1', 'N=c1ccc2ccccc2[nH]1', 'c1ccc2[nH]ccc2c1']),
#        list(['O=c1[nH]c(=O)c2ccccc2[nH]1', 'C1CCNC1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'O=c1occc2ccccc12', 'O=c1occc2ccccc12']),
#        list(['c1ccccc1', 'O=c1[nH]ncc2ccccc12', 'C1CNCCN1', 'c1cncnc1']),
#        list(['C1CCNCC1', 'c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)Cc1ccccc1-2', 'c1ccc2ccccc2c1']),
#        list(['c1cn[nH]c1', 'c1ccc2c(c1)CCC2', 'c1nn[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ncon1', 'C1CC2(CC2)CO1']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2ccccc2c1', 'c1ccccc1', 'O=c1nc[nH]o1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c3c([nH]c2c1)CCNC3']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'c1nnco1', 'c1ccccc1']),
#        list(['c1ccc2ncccc2c1', 'C1CCNC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2ocnc2c1', 'c1ccccc1', 'c1ccc2c(c1)OCCO2']),
#        list(['O=c1nc2cc[nH]n2c2ccccc12', 'C1CCNCC1', 'c1ccc2c(c1)CCN2']),
#        list(['c1ccccc1', 'N=c1cc[nH][nH]1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1c[nH]nn1', 'C1CCNC1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc[nH][nH]1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCN2', 'O=c1[nH]c(=O)c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1nnco1', 'c1ccccc1', 'c1cocn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1nnn[nH]1', 'O=C1NC(=O)c2ccccc21', 'c1ccncc1']),
#        list(['N=c1[nH]c(=O)c2ccccc2[nH]1', 'C1CCNCC1', 'c1ccc2[nH]ncc2c1']),
#        list(['c1ccccc1', 'O=c1nc2cc[nH]n2c2ccccc12', 'c1ccc2c(c1)CCCC2']),
#        list(['c1ccc2ccccc2c1', 'C1CCNCC1', 'c1ccc2c(c1)CCN2']),
#        list(['c1ccccc1', 'N=c1cc[nH][nH]1', 'O=c1cc[nH]cn1', 'c1ccccc1']),
#        list(['C1CCNCC1', 'c1ccc2c(c1)OCCO2', 'c1ccc2c(c1)CNc1ccccc1-2']),
#        list(['c1cc[nH]c1', 'c1ccccc1', 'C1CNCCN1', 'c1ccc2ccccc2c1']),
#        list(['N=c1ccnc[nH]1', 'N=C1Cc2[nH]c3ccccc3c2C1', 'c1ccncc1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ncon1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1C2CC3CC1CC(C2)C3', 'c1ccc2c(c1)CCN2', 'c1ccccc1']),
#        list(['O=C1CNC(=O)CN1', 'c1ccc2[nH]ccc2c1', 'c1ccc2occc2c1']),
#        list(['c1ccccc1', 'C1CC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC2', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1nc[nH]c2ccccc12', 'C1CNCCN1', 'c1ccc2c(c1)CCC2']),
#        list(['O=C1CNC(=O)N1', 'c1ccc2c(c1)CCC2', 'c1ccc2c3c([nH]c2c1)CCNC3']),
#        list(['C=c1sc2nc(=C3COc4ccccc4O3)[nH]n2c1=O', 'c1ccoc1', 'c1ccccc1']),
#        list(['O=C1COc2ccccc2N1', 'C1CCNCC1', 'O=C1CCc2ccccc2N1']),
#        list(['O=C1NCCc2ccccc21', 'C1CCNCC1', 'c1ncon1', 'c1ccccc1']),
#        list(['O=c1ccnc[nH]1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'O=c1nc[nH]c2sc3c(c12)CCCC3']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['c1cc2cn[nH]c2s1', 'c1ccccc1', 'O=c1ccnc2ccccn12']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ccc2c(c1)CCCC2']),
#        list(['c1ccccc1', 'c1nc[nH]n1', 'C1CCNCC1', 'c1cn[nH]c1', 'c1ccc2c(c1)OCCO2']),
#        list(['O=c1occc2ccccc12', 'c1ccc2c(c1)CCC1(CCNCC1)O2']),
#        list(['C1CCNCC1', 'c1ccn2cnnc2c1', 'c1ccc2n[nH]cc2c1']),
#        list(['N=c1nccc[nH]1', 'c1ccccc1', 'c1ccccc1', 'O=C1CCCN1']),
#        list(['O=c1ccn2c3c(cccc13)OCC2', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2scnc2c1', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ncon1', 'c1ccccc1', 'C1CNCCN1', 'c1ccc2c(c1)ccc1cncnc12']),
#        list(['c1ncon1', 'c1c[nH]nn1', 'c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)CCCN2', 'N=c1c2c1-c1ccccc1CC2']),
#        list(['O=c1nc[nH]c2ccccc12', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['C1CCNCC1', 'c1ccc2c(c1)OCO2', 'c1ccc2ccccc2c1']),
#        list(['O=c1[nH]cnc2c1oc1ccccc12', 'C1C[C@@H]2NC[C@H]1[C@@H]1CNC[C@H]12', 'c1ccccc1']),
#        list(['c1ccc2c(c1)C[C@@H]1C[C@H]21', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'c1ccc2c(c1)CCCN2']),
#        list(['O=c1[nH]c(=O)c2cccnc2[nH]1', 'C1CCNCC1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCNC2', 'c1cc[nH]c1']),
#        list(['N=c1[nH]ccs1', 'c1ccccc1', 'O=C1NC(=O)C2(CCCC2)N1']),
#        list(['c1ccc2[nH]cnc2c1', 'c1ncon1', 'C1CCNCC1', 'c1cnn2nnnc2c1']),
#        list(['c1cnc2ccnn2c1', 'c1ncon1', 'C1CCNCC1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ncon1', 'O=c1[nH]c2ccccc2o1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1ccccc1', 'C1CCNCC1']),
#        list(['c1ccc2c(c1)CCC2', 'O=c1[nH]c2ccccc2o1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'c1ccc2c3c([nH]c2c1)CCNC3', 'c1ccc2c(c1)CCO2']),
#        list(['C1CCNC1', 'c1ccc2ncccc2c1', 'c1ccc2ncccc2c1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'O=c1ccc2ccccc2[nH]1']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cc[nH]c1', 'c1ccc2c(c1)CCCN2']),
#        list(['C1CCCCC1', 'C1CCNC1', 'C1CCCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccccc1', 'c1ccc2c(c1)CCN2']),
#        list(['N=c1[nH]ccs1', 'c1ccc2c(c1)Cc1ccccc1-2', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'C1N[C@@H]2CN[C@H]1C2', 'c1ccc2c3c([nH]c2c1)CCC3']),
#        list(['O=C1NC(=O)c2ccccc21', 'C1CNCCN1', 'c1ccccc1']),
#        list(['O=C1Nc2cccc3cccc1c23', 'N=c1cc[nH][nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['O=C1NC(=O)[C@@]2(CCc3ccccc32)N1', 'C1CNCCN1', 'c1ccc2c(c1)OCCO2']),
#        list(['C1CCNCC1', 'c1ccc2c(c1)CCC2', 'C1CCNC1', 'c1ccn2cnnc2c1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'c1ccc2ccccc2c1'])], dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                            SMILES  Count
# 2                        c1ccccc1    597
# 4                        C1CCNCC1    103
# 24                 c1ccc2ccccc2c1     55
# 11                       C1CNCCN1     49
# 7                         c1ncon1     34
# ..                            ...    ...
# 140                  C=C1N=COC1=O      1
# 143  c1[nH]cc2c1[C@@H]1CC[C@H]2O1      1
# 42             O=C1CCCc2[nH]ccc21      1
# 47             O=c1cc[nH]c2ccnn12      1
# 131           O=c1[nH]nnc2ccccc12      1
#
# [251 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup()
res = df.mol.apply(ring_system_lookup.process_mol)

# %%
res
# Out:
# 0      [(N=c1cc[nH][nH]1, 77), (c1cn[nH]c1, 112133), ...
# 1      [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (C1...
# 2      [(c1ccccc1, 2568039), (c1ccncc1, 275595), (c1n...
# 3      [(c1ccccc1, 2568039), (c1nnc2n1CCCC2, 320), (N...
# 4      [(C1CNCCN1, 161505), (c1ccccc1, 2568039), (C1C...
#                              ...
# 495    [(O=C1Nc2cccc3cccc1c23, 595), (N=c1cc[nH][nH]1...
# 496    [(c1ccccc1, 2568039), (C1CNCCN1, 161505), (c1c...
# 497    [(O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, 27), (C1CNC...
# 498    [(C1CCNCC1, 212367), (c1ccc2c(c1)CCC2, 10459),...
# 499    [(c1ccccc1, 2568039), (C1CCNCC1, 212367), (c1c...
# Name: mol, Length: 500, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
# [500 rows x 5 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Charges were rearranged
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#
# [13:19:20] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [13:19:20] WARNING: Omitted undefined stereo
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...
# ..                                                 ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...
#
# [500 rows x 6 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...
# ..                                                 ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...
#
# [500 rows x 6 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# 5    O=C1CN(C(=O)c2ccc(NC(=O)c3nn(-c4ccccc4)c4c3CCC...
# 6    Cc1c(C(=O)Nc2ccc3c(c2)NC(=O)C(C)O3)oc2c1ccc1cc...
# ..                                                 ...
# 493  O=C(C[C@@H]1CC=CCC1)N1C[C@@H]2C[C@H]1CN2C(=O)c...
# 494  CN1C(=O)c2ccc(C(=O)N3CCN(C(=O)c4ccccc4F)CC3)cc...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x745d407604a0>
# 6    <rdkit.Chem.rdchem.Mol object at 0x745d40761d20>
# ..                                                ...
# 493  <rdkit.Chem.rdchem.Mol object at 0x745d40173c30>
# 494  <rdkit.Chem.rdchem.Mol object at 0x745d401738b0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# 5    [O=C1CNc2ccccc2N1, c1ccccc1, c1n[nH]c2c1CCC2, ...
# 6            [c1ccc2c(c1)ccc1ccoc12, O=C1COc2ccccc2N1]
# ..                                                 ...
# 493  [C1=CCCCC1, C1N[C@@H]2CN[C@H]1C2, c1ccc2c3c([n...
# 494          [O=C1NC(=O)c2ccccc21, C1CNCCN1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                     min_ring min_freq  \
# 1           c1cnc2[nH]ccc2c1     7932
# 2        O=c1[nH]ncc2ccccc12     3852
# 4           c1ccc2[nH]ccc2c1   108866
# 5            c1n[nH]c2c1CCC2      515
# 6      c1ccc2c(c1)ccc1ccoc12      107
# ..                       ...      ...
# 493  c1ccc2c3c([nH]c2c1)CCC3      153
# 494      O=C1NC(=O)c2ccccc21    10649
# 496                 C1CNCCN1   161505
# 498            c1ccn2cnnc2c1     2753
# 499           c1ccc2ccccc2c1    55872
#
#                                                  inchi
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...
# 5    InChI=1S/C28H23N5O3/c34-25-17-32(24-11-5-4-10-...
# 6    InChI=1S/C23H18N2O4/c1-12-16-9-7-14-5-3-4-6-17...
# ..                                                 ...
# 493  InChI=1S/C25H29N3O2/c29-23(12-16-6-2-1-3-7-16)...
# 494  InChI=1S/C21H18FN3O4/c1-23-19(27)14-7-6-13(12-...
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...
#
# [396 rows x 6 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#     rule_set_name description
# 0              ok          ok
# 1              ok          ok
# 2              ok          ok
# 3              ok          ok
# 4              ok          ok
# ..            ...         ...
# 495            ok          ok
# 496            ok          ok
# 497            ok          ok
# 498            ok          ok
# 499            ok          ok
#
# [500 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi rule_set_name  \
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...            ok
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...            ok
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...            ok
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...            ok
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...            ok
# ..                                                 ...           ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...            ok
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...            ok
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...            ok
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...            ok
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...            ok
#
#     description
# 0            ok
# 1            ok
# 2            ok
# 3            ok
# 4            ok
# ..          ...
# 495          ok
# 496          ok
# 497          ok
# 498          ok
# 499          ok
#
# [496 rows x 8 columns]

# %% [markdown]
# Test all filters from rd filters

# %%
rd_filters = ['Glaxo', 'Dundee', 'BMS', 'SureChEMBL', 'MLSMR', 'Inpharmatica', 'LINT']
for filter in rd_filters:
    reos.set_active_rule_sets([filter])
    new_df = reos.pandas_mols(df.mol)
    print(filter, len(new_df[new_df.description == "ok"])/len(new_df), reos.get_active_rule_sets(), len(new_df[new_df.description == "ok"]))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Glaxo 0.97 ['Glaxo'] 485
#   0%|          | 0/500 [00:00<?, ?it/s]
# Dundee 0.796 ['Dundee'] 398
#   0%|          | 0/500 [00:00<?, ?it/s]
# BMS 0.956 ['BMS'] 478
#   0%|          | 0/500 [00:00<?, ?it/s]
# SureChEMBL 0.984 ['SureChEMBL'] 492
#   0%|          | 0/500 [00:00<?, ?it/s]
# MLSMR 0.696 ['MLSMR'] 348
#   0%|          | 0/500 [00:00<?, ?it/s]
# Inpharmatica 0.898 ['Inpharmatica'] 449
#   0%|          | 0/500 [00:00<?, ?it/s]
# LINT 0.84 ['LINT'] 420

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi  Reymond
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...     True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True
# ..                                                 ...      ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True
#
# [500 rows x 7 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi  Reymond
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...     True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True
# ..                                                 ...      ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True
#
# [500 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [500 rows x 8 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring min_freq  \
# 0                    N=c1cc[nH][nH]1       77
# 1                   c1cnc2[nH]ccc2c1     7932
# 2                O=c1[nH]ncc2ccccc12     3852
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12        0
# 4                   c1ccc2[nH]ccc2c1   108866
# ..                               ...      ...
# 495                  N=c1cc[nH][nH]1       77
# 496                         C1CNCCN1   161505
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1       27
# 498                    c1ccn2cnnc2c1     2753
# 499                   c1ccc2ccccc2c1    55872
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [420 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC22 database druglike molecules

# %%
ring_system_lookup_ZINC22 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC22_rings_system.csv")
res_zinc22 = df.mol.apply(ring_system_lookup_ZINC22.process_mol)
res_zinc22
# Out:
# 0      [(N=c1cc[nH][nH]1, 212718130), (c1cn[nH]c1, 80...
# 1      [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 2      [(c1ccccc1, 21243538754), (c1ccncc1, 997562007...
# 3      [(c1ccccc1, 21243538754), (c1nnc2n1CCCC2, 6980...
# 4      [(C1CNCCN1, 2428718326), (c1ccccc1, 2124353875...
#                              ...
# 495    [(O=C1Nc2cccc3cccc1c23, 98188), (N=c1cc[nH][nH...
# 496    [(c1ccccc1, 21243538754), (C1CNCCN1, 242871832...
# 497    [(O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, 101934), (C...
# 498    [(C1CCNCC1, 12225942610), (c1ccc2c(c1)CCC2, 32...
# 499    [(c1ccccc1, 21243538754), (C1CCNCC1, 122259426...
# Name: mol, Length: 500, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc22.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring    min_freq  \
# 0                          O=C1NCCN1   172625460
# 1                   c1cnc2[nH]ccc2c1   128285266
# 2                O=c1[nH]ncc2ccccc12     4325112
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12           0
# 4                   c1ccc2[nH]ccc2c1   616349280
# ..                               ...         ...
# 495             O=C1Nc2cccc3cccc1c23       98188
# 496                         C1CNCCN1  2428718326
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1      101934
# 498                    c1ccn2cnnc2c1    63933346
# 499                   c1ccc2ccccc2c1   152439190
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [500 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# 5    O=C1CN(C(=O)c2ccc(NC(=O)c3nn(-c4ccccc4)c4c3CCC...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x745d407604a0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# 5    [O=C1CNc2ccccc2N1, c1ccccc1, c1n[nH]c2c1CCC2, ...
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring    min_freq  \
# 0                          O=C1NCCN1   172625460
# 1                   c1cnc2[nH]ccc2c1   128285266
# 2                O=c1[nH]ncc2ccccc12     4325112
# 4                   c1ccc2[nH]ccc2c1   616349280
# 5                   O=C1CNc2ccccc2N1     6167784
# ..                               ...         ...
# 495             O=C1Nc2cccc3cccc1c23       98188
# 496                         C1CNCCN1  2428718326
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1      101934
# 498                    c1ccn2cnnc2c1    63933346
# 499                   c1ccc2ccccc2c1   152439190
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# 5    InChI=1S/C28H23N5O3/c34-25-17-32(24-11-5-4-10-...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [491 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 0) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# 5    O=C1CN(C(=O)c2ccc(NC(=O)c3nn(-c4ccccc4)c4c3CCC...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x745d407604a0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# 5    [O=C1CNc2ccccc2N1, c1ccccc1, c1n[nH]c2c1CCC2, ...
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring    min_freq  \
# 0                          O=C1NCCN1   172625460
# 1                   c1cnc2[nH]ccc2c1   128285266
# 2                O=c1[nH]ncc2ccccc12     4325112
# 4                   c1ccc2[nH]ccc2c1   616349280
# 5                   O=C1CNc2ccccc2N1     6167784
# ..                               ...         ...
# 495             O=C1Nc2cccc3cccc1c23       98188
# 496                         C1CNCCN1  2428718326
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1      101934
# 498                    c1ccn2cnnc2c1    63933346
# 499                   c1ccc2ccccc2c1   152439190
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# 5    InChI=1S/C28H23N5O3/c34-25-17-32(24-11-5-4-10-...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [494 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 10) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# 5    O=C1CN(C(=O)c2ccc(NC(=O)c3nn(-c4ccccc4)c4c3CCC...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x745d407604a0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# 5    [O=C1CNc2ccccc2N1, c1ccccc1, c1n[nH]c2c1CCC2, ...
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring    min_freq  \
# 0                          O=C1NCCN1   172625460
# 1                   c1cnc2[nH]ccc2c1   128285266
# 2                O=c1[nH]ncc2ccccc12     4325112
# 4                   c1ccc2[nH]ccc2c1   616349280
# 5                   O=C1CNc2ccccc2N1     6167784
# ..                               ...         ...
# 495             O=C1Nc2cccc3cccc1c23       98188
# 496                         C1CNCCN1  2428718326
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1      101934
# 498                    c1ccn2cnnc2c1    63933346
# 499                   c1ccc2ccccc2c1   152439190
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# 5    InChI=1S/C28H23N5O3/c34-25-17-32(24-11-5-4-10-...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [493 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC20 database druglike molecules

# %%
ring_system_lookup_ZINC20 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC20_rings_ststem.csv")
res_zinc20 = df.mol.apply(ring_system_lookup_ZINC20.process_mol)
res_zinc20
# Out:
# 0      [(N=c1cc[nH][nH]1, 465348), (c1cn[nH]c1, 94875...
# 1      [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 2      [(c1ccccc1, 503413992), (c1ccncc1, 110130832),...
# 3      [(c1ccccc1, 503413992), (c1nnc2n1CCCC2, 715825...
# 4      [(C1CNCCN1, 35074701), (c1ccccc1, 503413992), ...
#                              ...
# 495    [(O=C1Nc2cccc3cccc1c23, 25116), (N=c1cc[nH][nH...
# 496    [(c1ccccc1, 503413992), (C1CNCCN1, 35074701), ...
# 497    [(O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, 31031), (C1...
# 498    [(C1CCNCC1, 150683472), (c1ccc2c(c1)CCC2, 5931...
# 499    [(c1ccccc1, 503413992), (C1CCNCC1, 150683472),...
# Name: mol, Length: 500, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc20.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 3    Cc1cccc(-c2nnc3n2CC(C(=O)N=c2[nH][nH]c4[nH]c(=...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 3    <rdkit.Chem.rdchem.Mol object at 0x745d40763bc0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 3    [c1ccccc1, c1nnc2n1CCCC2, N=c1[nH][nH]c2[nH]c(...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring  min_freq  \
# 0                    N=c1cc[nH][nH]1    465348
# 1                   c1cnc2[nH]ccc2c1   1256279
# 2                O=c1[nH]ncc2ccccc12    454347
# 3       N=c1[nH][nH]c2[nH]c(=O)ccc12         0
# 4                   c1ccc2[nH]ccc2c1   9363320
# ..                               ...       ...
# 495             O=C1Nc2cccc3cccc1c23     25116
# 496                         C1CNCCN1  35074701
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1     31031
# 498                    c1ccn2cnnc2c1   1139742
# 499                   c1ccc2ccccc2c1   4273930
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 3    InChI=1S/C20H19N7O2/c1-11-3-2-4-12(9-11)19-26-...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [500 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0    O=C(N=c1cc(-c2ccn(Cc3ccccc3)n2)[nH][nH]1)c1ccc...
# 1    O=C(Nc1ccccc1Cc1ccccc1)C(=O)N1CCC(c2c[nH]c3ncc...
# 2    Cc1ccc(Oc2cc(-c3noc(-c4n[nH]c(=O)c5ccccc45)n3)...
# 4    CN1CCN(Cc2cccc(C(=O)N3CCC(c4c(O)[nH]c5ccccc45)...
# 5    O=C1CN(C(=O)c2ccc(NC(=O)c3nn(-c4ccccc4)c4c3CCC...
# ..                                                 ...
# 495  O=C1Nc2ccc(S(=O)(=O)N=c3cc(-c4cccc(F)c4F)[nH][...
# 496  Cc1cc(C(F)(F)F)ccc1C(=O)N1CCN(C(=O)c2ccc(F)c(F...
# 497  O=C(CN1C(=O)N[C@]2(CCc3ccccc32)C1=O)N1CCN(C(=O...
# 498  O=C(C1CCN(S(=O)(=O)c2ccc3c(c2)CCC3)CC1)N1CCCC1...
# 499  NS(=O)(=O)c1cccc(NC(=O)C2CCN(C(=O)c3cccc4ccccc...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x745d40760820>
# 1    <rdkit.Chem.rdchem.Mol object at 0x745d407610e0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x745d40762030>
# 4    <rdkit.Chem.rdchem.Mol object at 0x745d40761fc0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x745d407604a0>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x745d40172e30>
# 496  <rdkit.Chem.rdchem.Mol object at 0x745d401731b0>
# 497  <rdkit.Chem.rdchem.Mol object at 0x745d40173a70>
# 498  <rdkit.Chem.rdchem.Mol object at 0x745d40173370>
# 499  <rdkit.Chem.rdchem.Mol object at 0x745d4000fae0>
#
#                                            ring_sytems  \
# 0    [N=c1cc[nH][nH]1, c1cn[nH]c1, c1ccccc1, c1cccc...
# 1     [c1ccccc1, c1ccccc1, C1CCNCC1, c1cnc2[nH]ccc2c1]
# 2    [c1ccccc1, c1ccncc1, c1ncon1, O=c1[nH]ncc2cccc...
# 4     [C1CNCCN1, c1ccccc1, C1CCNCC1, c1ccc2[nH]ccc2c1]
# 5    [O=C1CNc2ccccc2N1, c1ccccc1, c1n[nH]c2c1CCC2, ...
# ..                                                 ...
# 495  [O=C1Nc2cccc3cccc1c23, N=c1cc[nH][nH]1, c1ccccc1]
# 496                     [c1ccccc1, C1CNCCN1, c1ccccc1]
# 497  [O=C1NC(=O)[C@@]2(CCc3ccccc32)N1, C1CNCCN1, c1...
# 498  [C1CCNCC1, c1ccc2c(c1)CCC2, C1CCNC1, c1ccn2cnn...
# 499               [c1ccccc1, C1CCNCC1, c1ccc2ccccc2c1]
#
#                             min_ring  min_freq  \
# 0                    N=c1cc[nH][nH]1    465348
# 1                   c1cnc2[nH]ccc2c1   1256279
# 2                O=c1[nH]ncc2ccccc12    454347
# 4                   c1ccc2[nH]ccc2c1   9363320
# 5                   O=C1CNc2ccccc2N1    260176
# ..                               ...       ...
# 495             O=C1Nc2cccc3cccc1c23     25116
# 496                         C1CNCCN1  35074701
# 497  O=C1NC(=O)[C@@]2(CCc3ccccc32)N1     31031
# 498                    c1ccn2cnnc2c1   1139742
# 499                   c1ccc2ccccc2c1   4273930
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C23H21N7O2/c31-22(17-7-4-8-18(13-17)3...     True      True
# 1    InChI=1S/C27H26N4O2/c32-26(30-24-11-5-4-9-21(2...     True      True
# 2    InChI=1S/C23H17N5O3/c1-13-7-8-16(11-14(13)2)30...     True      True
# 4    InChI=1S/C26H32N4O2/c1-28-13-15-29(16-14-28)18...     True      True
# 5    InChI=1S/C28H23N5O3/c34-25-17-32(24-11-5-4-10-...     True      True
# ..                                                 ...      ...       ...
# 495  InChI=1S/C20H12F2N4O3S/c21-13-6-2-3-10(19(13)2...     True      True
# 496  InChI=1S/C20H17F5N2O2/c1-12-10-14(20(23,24)25)...     True      True
# 497  InChI=1S/C26H26N4O6/c31-22(15-30-24(33)26(27-2...     True      True
# 498  InChI=1S/C25H29N5O3S/c31-25(29-14-4-7-22(29)24...     True      True
# 499  InChI=1S/C23H23N3O4S/c24-31(29,30)19-8-4-7-18(...     True      True
#
# [470 rows x 8 columns]
