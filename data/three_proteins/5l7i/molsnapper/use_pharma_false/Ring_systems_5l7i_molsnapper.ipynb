# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob
import molvs
from multiprocessing import Pool, cpu_count
from tqdm.auto import tqdm

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i/molsnapper/use_pharma_false
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i/molsnapper

# %% [markdown]
# Reading data from crossdock dataset, add a standardization for small molecule data:

# %%
standardizer = molvs.standardize.Standardizer()

def standardize_mol(mol):
    try:
        mol = standardizer.standardize(mol)
        mol = standardizer.fragment_parent(mol, skip_standardize=True)
        mol = standardizer.tautomer_parent(mol, skip_standardize=True)
        mol = standardizer.isotope_parent(mol, skip_standardize=True)
        mol = standardizer.charge_parent(mol, skip_standardize=True)
        return mol
    except:
        return None

# %%
smi_list = []
with open('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/5l7i/molsnapper/use_pharma_false/500_generated.smi') as f:
    for smi in f:
        smi_list.append(smi.strip())
standardized_smiles_list = []
for smi in tqdm(smi_list, desc="Standardizing molecules", unit="mol"):
    mol = Chem.MolFromSmiles(smi)
    mol = standardize_mol(mol)
    
    if mol:
        standardized_smiles_list.append(Chem.MolToSmiles(mol))
    else:
        print(f"Skipping molecule {smi}")
        pass

print(len(smi_list))
len(standardized_smiles_list)
# Out:
# Standardizing molecules:   0%|          | 0/500 [00:00<?, ?mol/s]
# 500
# 500

# %% [markdown]
# Set the default image size

# %%
with open('500_generated_standardized.smi', 'w') as f:
    for item in standardized_smiles_list:
        f.write("%s\n" % item)

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(standardized_smiles_list, columns=['SMILES'])
df
# Out:
#                                                 SMILES
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 495  CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(-c3cc(C)ccn...
# 496  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 497  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 498  C[N+](C)(C)S(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3...
# 499  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
# [500 rows x 1 columns]

# %% [markdown]
# Remove repeated molecules

# %%
df = df.drop_duplicates(['SMILES'])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                 SMILES
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
# [258 rows x 1 columns]

# %% [markdown]
# Save the smi file for further use

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0        [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]
# 1                 [c1ccccc1, c1ccccc1, c1ccncc1]
# 2                 [c1ccccc1, c1ccccc1, c1ccncc1]
# 3                 [c1ccncc1, c1ccccc1, c1ccccc1]
# 4                 [c1ccccc1, c1ccccc1, c1ccncc1]
#                          ...
# 253      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]
# 254               [c1ccccc1, c1ccccc1, c1ccncc1]
# 255    [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]
# 256               [c1ccccc1, c1ccccc1, c1ccncc1]
# 257       [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]
# Name: ring_sytems, Length: 258, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['c1ccccc1', 'N=C1C=CC2C3=C1C32', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=S1(=O)NCCc2ccccc21', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'O=C1CN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1=CC2=CC2C=C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CC=C2C=C2N=C1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1CCCCCCN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'O=S1(=O)CCCN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1=CC2=CC2C=C1', 'c1ccccc1', 'C1C2CC3NC3NC12']),
#        list(['c1ccccc1', 'O=C1N[N+]1=C1CNc2ccccc21', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)N2', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1cc2c3c(n1)C23']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)CCN2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CC2C3C(C1)C23', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1[nH]c2cccnc2c2ccccc12']),
#        list(['O=C1CC2CCCCC2NCN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)N2', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=C1NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1C[NH2+]1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['O=C1Nc2nc3ccccc3n21', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cc[nH]cc1']),
#        list(['c1ccccc1', 'N=c1c2ccccc12', 'O=c1cccncn1']),
#        list(['c1ccncc1', 'c1ccccc1', 'C1CCC2(CC1)CO2']),
#        list(['O=C1NC12CCCCC2', 'N=c1c2ccccc12', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=S1(=O)NCc2ccccc21', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1=NC(=C2C3CCCCC23)C2C3=C2C13']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'O=S1(=O)CCN1']),
#        list(['O=C1NC12CCCCC2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=NC2C3=C2C3=C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CC2C3C(C1)C23', 'c1ccccc1', 'c1cc2c3c(n1)C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1NC2CC3C4C(C12)C34', 'c1ccncc1']),
#        list(['C1CCC2CC2C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=S1(=O)NCCc2ccccc21', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCCNC1']),
#        list(['c1ccccc1', 'O=c1[nH]c2cccnc2c2ccccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'N=c1c2ccccc12', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=c1[nH]c2cccnc2c2ccccc12']),
#        list(['O=C1NC12CCCCC2', 'N=C1C2CCC(=O)CC12', 'c1ccncc1']),
#        list(['C1=CC2=CC2C=C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2NC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC23CC2C2C4CC4CNC2C3C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1c2ncn3c4c(c1-2)c43']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CNC2[NH+]=C2C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1NC=NC2=CC12', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CC2=CC23NC3=N1']),
#        list(['O=C1NC12CCCCC2', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'C1CCC2(CC1)N=[NH+]2', 'c1ccncc1']),
#        list(['C1CC2CC2N2CC2C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCC2OCC2C1', 'c1ccccc1', 'c1cnc2c(c1)C2']),
#        list(['C1CC2CC2C2OC2C1', 'c1ccccc1', 'C1=NC=C2C3=C2C13']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1=CC2=CC23OC2(CCCCC2)C3=N1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCCNC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'O=c1[nH]c2cccnc2c2ccccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccc2c(c1)N2', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NC2NC2C2CC12']),
#        list(['O=C1NC2NC3CCCCC3C12', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1CC2CCCCC2NCN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCC2NC2C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CN2', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2NC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1C2CC3NC3NC12']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2(CC1)CN2', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=S1(=O)NCc2ccccc21', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCC2NC2C1', 'c1ccccc1', 'C1=NC=C2C3=C2C13']),
#        list(['O=C1CCCCC1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=c1[nH]c2cccnc2c2ccccc12']),
#        list(['C1CCC2CC2NC1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=NC2C3=C2C3=C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'O=C1CN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cccncn1']),
#        list(['c1ccccc1', 'N=c1c2ccccc12', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCNCNC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2NC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1=NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'N=C1CCC2CC2C1', 'c1ccncc1']),
#        list(['C1=CN=C2C3=C2C3C=C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cncc[nH]1']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'O=C1NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC23CC2C2C4CC4CNC2C3C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1=CC2=NC2C=C2C=C12', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1cnc2c(c1)OC21C2CCCCC21']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CN2', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2CC2CN1']),
#        list(['C1CCNCNC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NN1', 'C1=CC2C3=C2C3=C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=C1NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccc2c(c1)CN2', 'c1ccccc1']),
#        list(['O=C1CCCC2CC2N1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1NCCc2ccccc21', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'C1CCN2CC2C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'N=C1CCC2CC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CN2', 'O=c1cccncn1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['C1CC2C3C(C1)N23', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CN2', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CNC2[NH+]=C2C1']),
#        list(['O=C1CCCC2CC12', 'c1ccccc1', 'C1=NC=C2C3=C2C13']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1=CC2C3=C2C3=C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCNCC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1C2CC3NC3NC12']),
#        list(['C1=c2ccccc2=N1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2NC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'N=c1cccc[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'O=C1C2CCCCC2C23NCCCC2N13']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2C3C(N1)C23']),
#        list(['c1ccccc1', 'N=C1CCC2C3C1C23', 'c1ncc2c3c1C23']),
#        list(['c1ccccc1', 'C1NC2CC3NCC3CC12', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2NC2C1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)N2', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2[NH+]=C2C1', 'C1NCC2C3C1C23']),
#        list(['C1CCC2CC2NC1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCC2CC2C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NN1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCC2NCC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cccncn1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CCNCNC1', 'c1ccccc1', 'c1ccc2c(c1)N2']),
#        list(['c1ccccc1', 'C1NC2CC3[NH+]=C3CC12', 'c1ccncc1']),
#        list(['O=C1NC12NC1CCCCC12', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1NCC2C3C1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1c2ncn3c4c(c1-2)c43']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1cccncn1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CC2CC2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cc2c(cn1)C2']),
#        list(['c1ccccc1', 'C1CCC2CC2C1', 'c1ccncc1']),
#        list(['C1CCC2NNC2C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1C=NN1', 'c1ccccc1', 'c1cc2c(cn1)C2']),
#        list(['c1ccccc1', 'N=C1C=CC2C3=C1C32', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'O=C1C=NN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1=CC2C3=C2C3=C1', 'c1ccncc1'])], dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                  SMILES  Count
# 0              c1ccccc1    414
# 2              c1ccncc1    176
# 5         C1NCC2C3C1C23     14
# 16        c1ccc2c(c1)N2     12
# 15          C1CCC2CC2C1     11
# ..                  ...    ...
# 9          O=C1CCCCCCN1      1
# 54       C1CCC2(CC1)CN2      1
# 55           O=C1CCCCC1      1
# 58               C1=NN1      1
# 44  C1CCC2(CC1)N=[NH+]2      1
#
# [84 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup()
res = df.mol.apply(ring_system_lookup.process_mol)

# %%
res
# Out:
# 0      [(c1ccccc1, 2568039), (N=C1C=CC2C3=C1C32, 0), ...
# 1      [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
# 2      [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
# 3      [(c1ccncc1, 275595), (c1ccccc1, 2568039), (c1c...
# 4      [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
#                              ...
# 253    [(c1ccccc1, 2568039), (N=C1C=CC2C3=C1C32, 0), ...
# 254    [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
# 255    [(c1ccncc1, 275595), (c1ccccc1, 2568039), (O=C...
# 256    [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
# 257    [(c1ccccc1, 2568039), (C1=CC2C3=C2C3=C1, 0), (...
# Name: mol, Length: 258, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring min_freq
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1   275595
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# ..                                         ...                ...      ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1        0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1        0
#
# [258 rows x 5 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#
# [16:12:02] WARNING: Omitted undefined stereo
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1   275595
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# ..                                         ...                ...      ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1        0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1        0
#
#                                                  inchi
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...
# ..                                                 ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...
#
# [258 rows x 6 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1   275595
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# ..                                         ...                ...      ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1        0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1        0
#
#                                                  inchi
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...
# ..                                                 ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...
#
# [258 rows x 6 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# 5    CNS(=O)(=O)c1ccc(C(=O)Nc2cc(C)c(Cl)c(-c3ccccn3...
# ..                                                 ...
# 249  CNS(=O)(=O)c1cc(Cl)c(NC(=O)Nc2ccc(Cl)c(-c3cccc...
# 250  COc1ccc(N=NC(=O)c2ccc(S(C)(=O)=O)cc2Cl)cc1-c1c...
# 251  Cc1ccnc(-c2cc(NC(=O)c3c(Cl)cc(S(C)(=O)=O)cc3C=...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bf40>
# ..                                                ...
# 249  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a29d0>
# 250  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2a40>
# 251  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ab0>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
#
#                         ring_sytems  min_ring min_freq  \
# 1    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 2    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 3    [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1   275595
# 4    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 5    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# ..                              ...       ...      ...
# 249  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 250  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 251  [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1   275595
# 254  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 256  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
#
#                                                  inchi
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...
# 5    InChI=1S/C20H17Cl2N3O3S/c1-12-9-13(10-16(19(12...
# ..                                                 ...
# 249  InChI=1S/C19H15Cl3N4O3S/c1-23-30(28,29)18-10-1...
# 250  InChI=1S/C20H16ClN3O4S/c1-28-19-9-6-13(11-16(1...
# 251  InChI=1S/C21H16Cl2N2O4S/c1-12-5-6-24-19(7-12)1...
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...
#
# [110 rows x 6 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]
#     rule_set_name description
# 0              ok          ok
# 1              ok          ok
# 2              ok          ok
# 3              ok          ok
# 4              ok          ok
# ..            ...         ...
# 253            ok          ok
# 254            ok          ok
# 255            ok          ok
# 256            ok          ok
# 257            ok          ok
#
# [258 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1   275595
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# ..                                         ...                ...      ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1        0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1        0
#
#                                                  inchi rule_set_name  \
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...            ok
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...            ok
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...            ok
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...            ok
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...            ok
# ..                                                 ...           ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...            ok
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...            ok
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...            ok
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...            ok
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...            ok
#
#     description
# 0            ok
# 1            ok
# 2            ok
# 3            ok
# 4            ok
# ..          ...
# 253          ok
# 254          ok
# 255          ok
# 256          ok
# 257          ok
#
# [254 rows x 8 columns]

# %% [markdown]
# Test all filters from rd filters

# %%
rd_filters = ['Glaxo', 'Dundee', 'BMS', 'SureChEMBL', 'MLSMR', 'Inpharmatica', 'LINT']
for filter in rd_filters:
    reos.set_active_rule_sets([filter])
    new_df = reos.pandas_mols(df.mol)
    print(filter, len(new_df[new_df.description == "ok"])/len(new_df), reos.get_active_rule_sets(), len(new_df[new_df.description == "ok"]))
# Out:
#   0%|          | 0/258 [00:00<?, ?it/s]
# Glaxo 0.7674418604651163 ['Glaxo'] 198
#   0%|          | 0/258 [00:00<?, ?it/s]
# Dundee 0.5775193798449613 ['Dundee'] 149
#   0%|          | 0/258 [00:00<?, ?it/s]
# BMS 0.6976744186046512 ['BMS'] 180
#   0%|          | 0/258 [00:00<?, ?it/s]
# SureChEMBL 0.7403100775193798 ['SureChEMBL'] 191
#   0%|          | 0/258 [00:00<?, ?it/s]
# MLSMR 0.2558139534883721 ['MLSMR'] 66
#   0%|          | 0/258 [00:00<?, ?it/s]
# Inpharmatica 0.7635658914728682 ['Inpharmatica'] 197
#   0%|          | 0/258 [00:00<?, ?it/s]
# LINT 0.7131782945736435 ['LINT'] 184

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1   275595
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# ..                                         ...                ...      ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1        0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1        0
#
#                                                  inchi  Reymond
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...    False
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True
# ..                                                 ...      ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...    False
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...    False
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...    False
#
# [258 rows x 7 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                                 SMILES  \
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# 5    CNS(=O)(=O)c1ccc(C(=O)Nc2cc(C)c(Cl)c(-c3ccccn3...
# ..                                                 ...
# 249  CNS(=O)(=O)c1cc(Cl)c(NC(=O)Nc2ccc(Cl)c(-c3cccc...
# 250  COc1ccc(N=NC(=O)c2ccc(S(C)(=O)=O)cc2Cl)cc1-c1c...
# 251  Cc1ccnc(-c2cc(NC(=O)c3c(Cl)cc(S(C)(=O)=O)cc3C=...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bf40>
# ..                                                ...
# 249  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a29d0>
# 250  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2a40>
# 251  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ab0>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
#
#                         ring_sytems  min_ring min_freq  \
# 1    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 2    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 3    [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1   275595
# 4    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 5    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# ..                              ...       ...      ...
# 249  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 250  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 251  [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1   275595
# 254  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
# 256  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1   275595
#
#                                                  inchi  Reymond
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True
# 5    InChI=1S/C20H17Cl2N3O3S/c1-12-9-13(10-16(19(12...     True
# ..                                                 ...      ...
# 249  InChI=1S/C19H15Cl3N4O3S/c1-23-30(28,29)18-10-1...     True
# 250  InChI=1S/C20H16ClN3O4S/c1-28-19-9-6-13(11-16(1...     True
# 251  InChI=1S/C21H16Cl2N2O4S/c1-12-5-6-24-19(7-12)1...     True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True
#
# [192 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1   275595
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# ..                                         ...                ...      ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32        0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1        0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1   275595
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1        0
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...    False      True
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# ..                                                 ...      ...       ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...    False      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...    False      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...    False      True
#
# [258 rows x 8 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 252  CS(=O)(=O)c1ccc(N2N=C(c3ccc(Cl)c(-c4nccc5c4C5)...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 252  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b20>
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                         ring_sytems           min_ring  \
# 0           [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32
# 1                    [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1
# 2                    [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1
# 3                    [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1
# 4                    [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1
# ..                                              ...                ...
# 252  [c1ccccc1, O=C1C=NN1, c1ccccc1, c1cc2c(cn1)C2]          O=C1C=NN1
# 253         [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32
# 254                  [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1
# 255       [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1
# 257          [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1
#
#     min_freq                                              inchi  Reymond  \
# 0          0  InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...    False
# 1     275595  InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True
# 2     275595  InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True
# 3     275595  InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True
# 4     275595  InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True
# ..       ...                                                ...      ...
# 252        0  InChI=1S/C21H13Cl2N3O3S/c1-30(28,29)13-3-5-18(...    False
# 253        0  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...    False
# 254   275595  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True
# 255        0  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...    False
# 257        0  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...    False
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 252      True
# 253      True
# 254      True
# 255      True
# 257      True
#
# [216 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC22 database druglike molecules

# %%
ring_system_lookup_ZINC22 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC22_rings_system.csv")
res_zinc22 = df.mol.apply(ring_system_lookup_ZINC22.process_mol)
res_zinc22
# Out:
# 0      [(c1ccccc1, 21243538754), (N=C1C=CC2C3=C1C32, ...
# 1      [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 2      [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 3      [(c1ccncc1, 9975620076), (c1ccccc1, 2124353875...
# 4      [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
#                              ...
# 253    [(c1ccccc1, 21243538754), (N=C1C=CC2C3=C1C32, ...
# 254    [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 255    [(c1ccncc1, 9975620076), (c1ccccc1, 2124353875...
# 256    [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 257    [(c1ccccc1, 21243538754), (C1=CC2C3=C2C3=C1, 0...
# Name: mol, Length: 258, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc22.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring    min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32           0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  9975620076
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  9975620076
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1  9975620076
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  9975620076
# ..                                         ...                ...         ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32           0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  9975620076
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1           0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  9975620076
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1           0
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...    False      True
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# ..                                                 ...      ...       ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...    False      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...    False      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...    False      True
#
# [258 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# 5    CNS(=O)(=O)c1ccc(C(=O)Nc2cc(C)c(Cl)c(-c3ccccn3...
# ..                                                 ...
# 249  CNS(=O)(=O)c1cc(Cl)c(NC(=O)Nc2ccc(Cl)c(-c3cccc...
# 250  COc1ccc(N=NC(=O)c2ccc(S(C)(=O)=O)cc2Cl)cc1-c1c...
# 251  Cc1ccnc(-c2cc(NC(=O)c3c(Cl)cc(S(C)(=O)=O)cc3C=...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bf40>
# ..                                                ...
# 249  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a29d0>
# 250  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2a40>
# 251  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ab0>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
#
#                         ring_sytems  min_ring    min_freq  \
# 1    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 2    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 3    [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  9975620076
# 4    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 5    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# ..                              ...       ...         ...
# 249  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 250  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 251  [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  9975620076
# 254  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 256  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
#
#                                                  inchi  Reymond  Lipinski
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# 5    InChI=1S/C20H17Cl2N3O3S/c1-12-9-13(10-16(19(12...     True      True
# ..                                                 ...      ...       ...
# 249  InChI=1S/C19H15Cl3N4O3S/c1-23-30(28,29)18-10-1...     True     False
# 250  InChI=1S/C20H16ClN3O4S/c1-28-19-9-6-13(11-16(1...     True      True
# 251  InChI=1S/C21H16Cl2N2O4S/c1-12-5-6-24-19(7-12)1...     True      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
#
# [124 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 0) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# 5    CNS(=O)(=O)c1ccc(C(=O)Nc2cc(C)c(Cl)c(-c3ccccn3...
# ..                                                 ...
# 249  CNS(=O)(=O)c1cc(Cl)c(NC(=O)Nc2ccc(Cl)c(-c3cccc...
# 250  COc1ccc(N=NC(=O)c2ccc(S(C)(=O)=O)cc2Cl)cc1-c1c...
# 251  Cc1ccnc(-c2cc(NC(=O)c3c(Cl)cc(S(C)(=O)=O)cc3C=...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bf40>
# ..                                                ...
# 249  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a29d0>
# 250  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2a40>
# 251  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ab0>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
#
#                         ring_sytems  min_ring    min_freq  \
# 1    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 2    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 3    [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  9975620076
# 4    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 5    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# ..                              ...       ...         ...
# 249  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 250  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 251  [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  9975620076
# 254  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 256  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
#
#                                                  inchi  Reymond  Lipinski
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# 5    InChI=1S/C20H17Cl2N3O3S/c1-12-9-13(10-16(19(12...     True      True
# ..                                                 ...      ...       ...
# 249  InChI=1S/C19H15Cl3N4O3S/c1-23-30(28,29)18-10-1...     True     False
# 250  InChI=1S/C20H16ClN3O4S/c1-28-19-9-6-13(11-16(1...     True      True
# 251  InChI=1S/C21H16Cl2N2O4S/c1-12-5-6-24-19(7-12)1...     True      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
#
# [137 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 10) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# 5    CNS(=O)(=O)c1ccc(C(=O)Nc2cc(C)c(Cl)c(-c3ccccn3...
# ..                                                 ...
# 249  CNS(=O)(=O)c1cc(Cl)c(NC(=O)Nc2ccc(Cl)c(-c3cccc...
# 250  COc1ccc(N=NC(=O)c2ccc(S(C)(=O)=O)cc2Cl)cc1-c1c...
# 251  Cc1ccnc(-c2cc(NC(=O)c3c(Cl)cc(S(C)(=O)=O)cc3C=...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bf40>
# ..                                                ...
# 249  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a29d0>
# 250  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2a40>
# 251  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ab0>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
#
#                         ring_sytems  min_ring    min_freq  \
# 1    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 2    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 3    [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  9975620076
# 4    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 5    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# ..                              ...       ...         ...
# 249  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 250  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 251  [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  9975620076
# 254  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
# 256  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  9975620076
#
#                                                  inchi  Reymond  Lipinski
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# 5    InChI=1S/C20H17Cl2N3O3S/c1-12-9-13(10-16(19(12...     True      True
# ..                                                 ...      ...       ...
# 249  InChI=1S/C19H15Cl3N4O3S/c1-23-30(28,29)18-10-1...     True     False
# 250  InChI=1S/C20H16ClN3O4S/c1-28-19-9-6-13(11-16(1...     True      True
# 251  InChI=1S/C21H16Cl2N2O4S/c1-12-5-6-24-19(7-12)1...     True      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
#
# [130 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC20 database druglike molecules

# %%
ring_system_lookup_ZINC20 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC20_rings_ststem.csv")
res_zinc20 = df.mol.apply(ring_system_lookup_ZINC20.process_mol)
res_zinc20
# Out:
# 0      [(c1ccccc1, 503413992), (N=C1C=CC2C3=C1C32, 0)...
# 1      [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 2      [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 3      [(c1ccncc1, 110130832), (c1ccccc1, 503413992),...
# 4      [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
#                              ...
# 253    [(c1ccccc1, 503413992), (N=C1C=CC2C3=C1C32, 0)...
# 254    [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 255    [(c1ccncc1, 110130832), (c1ccccc1, 503413992),...
# 256    [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 257    [(c1ccccc1, 503413992), (C1=CC2C3=C2C3=C1, 0),...
# Name: mol, Length: 258, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc20.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    CNS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccccn3)C3(Cl)C...
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# ..                                                 ...
# 253  CS(=O)(=O)c1ccc(C(=O)N=C2C=C(c3ccc(C=O)cn3)C3(...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 255  Cc1ccnc(-c2cc(C3=NN(c4ccc(S(=O)(=O)N(C)C)cc4Cl...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
# 257  CNS(=O)(=O)c1ccc(C(=O)NC23C=C(c4ncccc4O)C(Cl)=...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd10>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# ..                                                ...
# 253  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2b90>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 255  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c70>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
# 257  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2d50>
#
#                                    ring_sytems           min_ring   min_freq  \
# 0      [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32          0
# 1               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  110130832
# 2               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  110130832
# 3               [c1ccncc1, c1ccccc1, c1ccccc1]           c1ccncc1  110130832
# 4               [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  110130832
# ..                                         ...                ...        ...
# 253    [c1ccccc1, N=C1C=CC2C3=C1C32, c1ccncc1]  N=C1C=CC2C3=C1C32          0
# 254             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  110130832
# 255  [c1ccncc1, c1ccccc1, O=C1C=NN1, c1ccccc1]          O=C1C=NN1          0
# 256             [c1ccccc1, c1ccccc1, c1ccncc1]           c1ccncc1  110130832
# 257     [c1ccccc1, C1=CC2C3=C2C3=C1, c1ccncc1]   C1=CC2C3=C2C3=C1          0
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C20H13Cl2N3O3S/c1-23-29(27,28)10-5-6-...    False      True
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# ..                                                 ...      ...       ...
# 253  InChI=1S/C21H12Cl2N2O4S/c1-30(28,29)11-3-4-12(...    False      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 255  InChI=1S/C22H18Cl2N4O3S/c1-13-8-9-25-19(10-13)...    False      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
# 257  InChI=1S/C20H13Cl2N3O4S/c1-23-30(28,29)9-4-5-1...    False      True
#
# [258 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 1    CNS(=O)(=O)c1ccc(NC(=O)Nc2ccc(Cl)c(Oc3ccccn3)c...
# 2    CNS(=O)(=O)c1cc(C)c(NC(=O)Nc2ccc(Cl)c(-c3ccccn...
# 3    Cc1ccc(-c2cc(NC(=O)c3ccc(OS(=O)(=O)N(C)C)cc3Cl...
# 4    CNS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(-c3ccc(F)cn3...
# 5    CNS(=O)(=O)c1ccc(C(=O)Nc2cc(C)c(Cl)c(-c3ccccn3...
# ..                                                 ...
# 249  CNS(=O)(=O)c1cc(Cl)c(NC(=O)Nc2ccc(Cl)c(-c3cccc...
# 250  COc1ccc(N=NC(=O)c2ccc(S(C)(=O)=O)cc2Cl)cc1-c1c...
# 251  Cc1ccnc(-c2cc(NC(=O)c3c(Cl)cc(S(C)(=O)=O)cc3C=...
# 254  CS(=O)(=O)c1ccc(C(=O)C(=O)Nc2ccc(Cl)c(-c3ccccn...
# 256  CN(C)S(=O)(=O)c1cc(Cl)c(C(=O)Nc2ccc(Cl)c(-c3cc...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bd80>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bdf0>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048be60>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bed0>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7e4f0048bf40>
# ..                                                ...
# 249  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a29d0>
# 250  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2a40>
# 251  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ab0>
# 254  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2c00>
# 256  <rdkit.Chem.rdchem.Mol object at 0x7e4f004a2ce0>
#
#                         ring_sytems  min_ring   min_freq  \
# 1    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# 2    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# 3    [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  110130832
# 4    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# 5    [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# ..                              ...       ...        ...
# 249  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# 250  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# 251  [c1ccncc1, c1ccccc1, c1ccccc1]  c1ccncc1  110130832
# 254  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
# 256  [c1ccccc1, c1ccccc1, c1ccncc1]  c1ccncc1  110130832
#
#                                                  inchi  Reymond  Lipinski
# 1    InChI=1S/C19H16Cl2N4O4S/c1-22-30(27,28)13-6-8-...     True      True
# 2    InChI=1S/C20H18Cl2N4O3S/c1-12-9-14(30(28,29)23...     True      True
# 3    InChI=1S/C21H19Cl2N3O4S/c1-13-4-9-20(24-12-13)...     True      True
# 4    InChI=1S/C19H14Cl2FN3O3S/c1-23-29(27,28)13-4-5...     True      True
# 5    InChI=1S/C20H17Cl2N3O3S/c1-12-9-13(10-16(19(12...     True      True
# ..                                                 ...      ...       ...
# 249  InChI=1S/C19H15Cl3N4O3S/c1-23-30(28,29)18-10-1...     True     False
# 250  InChI=1S/C20H16ClN3O4S/c1-28-19-9-6-13(11-16(1...     True      True
# 251  InChI=1S/C21H16Cl2N2O4S/c1-12-5-6-24-19(7-12)1...     True      True
# 254  InChI=1S/C20H14Cl2N2O4S/c1-29(27,28)13-6-7-14(...     True      True
# 256  InChI=1S/C20H16Cl3N3O3S/c1-26(2)30(28,29)19-11...     True     False
#
# [104 rows x 8 columns]
