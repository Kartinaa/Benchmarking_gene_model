# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob
import molvs
from multiprocessing import Pool, cpu_count
from tqdm.auto import tqdm

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/7wf5/p2m
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/7wf5

# %% [markdown]
# Reading data from crossdock dataset, add a standardization for small molecule data:

# %%
standardizer = molvs.standardize.Standardizer()

def standardize_mol(mol):
    try:
        mol = standardizer.standardize(mol)
        mol = standardizer.fragment_parent(mol, skip_standardize=True)
        mol = standardizer.tautomer_parent(mol, skip_standardize=True)
        mol = standardizer.isotope_parent(mol, skip_standardize=True)
        mol = standardizer.charge_parent(mol, skip_standardize=True)
        return mol
    except:
        return None

# %%
smi_list = []
with open('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/7wf5/p2m/500_generated.smi') as f:
    for smi in f:
        smi_list.append(smi.strip())
standardized_smiles_list = []
for smi in tqdm(smi_list, desc="Standardizing molecules", unit="mol"):
    mol = Chem.MolFromSmiles(smi)
    mol = standardize_mol(mol)
    
    if mol:
        standardized_smiles_list.append(Chem.MolToSmiles(mol))
    else:
        print(f"Skipping molecule {smi}")
        pass

print(len(smi_list))
len(standardized_smiles_list)
# Out:
# Standardizing molecules:   0%|          | 0/522 [00:00<?, ?mol/s]
# 522
# 522

# %% [markdown]
# Set the default image size

# %%
with open('500_generated_standardized.smi', 'w') as f:
    for item in standardized_smiles_list:
        f.write("%s\n" % item)

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(standardized_smiles_list, columns=['SMILES'])
df
# Out:
#                                                 SMILES
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 517  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 518  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 519  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 520  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 521  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
# [522 rows x 1 columns]

# %% [markdown]
# Remove repeated molecules

# %%
df = df.drop_duplicates(['SMILES'])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                 SMILES
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
# [521 rows x 1 columns]

# %% [markdown]
# Save the smi file for further use

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0                                             [c1ccncc1]
# 1                                             [c1ccccc1]
# 2                                             [c1ccccc1]
# 3                                             [c1ccncc1]
# 4                                             [c1ccccc1]
#                              ...
# 516    [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...
# 517    [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...
# 518    [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...
# 519    [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...
# 520    [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...
# Name: ring_sytems, Length: 521, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['c1ccncc1']), list(['c1ccccc1']), list(['c1ccccc1']),
#        list(['c1ccncc1']), list(['c1ccccc1']), list(['c1ccc2cnccc2c1']),
#        list(['N=c1cc[nH]c2sccc12']), list(['c1ccccc1']),
#        list(['c1ccccc1']), list(['c1ccccc1']), list(['c1ccc2ccccc2c1']),
#        list(['c1ccncc1']), list(['c1cnc2ccncc2c1']),
#        list(['c1ccc2ccccc2c1']), list(['C1CCC2CCCCC2C1']),
#        list(['N=c1cc[nH]c2ccccc12']), list(['C=C1C=CC=N1', 'c1nnn[nH]1']),
#        list(['c1ccncc1', 'c1nnn[nH]1']), list(['N=c1cc2ccccc2c[nH]1']),
#        list(['c1ccc2ccccc2c1']), list(['C1=CC2N=CC=C2N=C1']),
#        list(['c1ccncc1', 'c1nnc[nH]1']), list(['N=c1nc2ccccc2c[nH]1']),
#        list(['c1ccccc1']), list(['c1ccc2ccccc2c1']),
#        list(['C1=CCC2CCOCCC2C1']), list(['c1ccc2nnccc2c1']),
#        list(['c1ccc2ncccc2c1']), list(['c1ccccc1', 'c1ncnnn1']),
#        list(['O=C1N=Nc2ccccc21']), list(['N=c1[nH]c(=N)c2ccccc2[nH]1']),
#        list(['c1ccc2cnccc2c1']), list(['C=c1nccc2c1=NC=CC2']),
#        list(['c1ccccc1']), list(['c1ccc2ccccc2c1']),
#        list(['O=c1[nH]ccc2ccccc12']), list(['c1ccccc1']),
#        list(['c1ccc2ccccc2c1']), list(['c1ccccc1']),
#        list(['O=C1NCCc2ccccc21']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['C1CCC2CCOCCC2C1']), list(['O=C1NCCc2ccccc21']),
#        list(['O=C1CC2C=CSC2N1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)sc1ccccc12']),
#        list(['O=C1CC2C=CSC2N1', 'c1ccncc1']),
#        list(['O=C1CC2C=CC=CC2N1', 'c1ccncc1']),
#        list(['O=C1NCCc2ccc3ncccc3c21']),
#        list(['N=c1ccc2ccc3ccccc3c2[nH]1']), list(['c1ccccc1']),
#        list(['c1ccccc1']), list(['c1cn[nH]c1', 'O=C1CCc2ccccc2N1']),
#        list(['N=c1ccc2c3c(ccc2[nH]1)CCNC3=O']), list(['c1ccccc1']),
#        list(['c1ccccc1']), list(['c1ccc2[nH]ccc2c1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)ccc1ccccc12']), list(['c1ccccc1']),
#        list(['c1ccc2c(c1)ccc1ccccc12']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccccc1']),
#        list(['c1ccc2nnccc2c1', 'c1ccccc1']),
#        list(['C1=CC2Cc3cccc4c3C(CCC4)N2C=C1']),
#        list(['c1ccccc1', 'c1ccccc1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1']), list(['C1CCOC1', 'c1ccc2ncccc2c1']),
#        list(['C1CCCCC1', 'c1ccccc1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['O=C1Cc2ccccc2CN1', 'c1ccccc1']),
#        list(['C1CCCC1', 'c1ccccc1']), list(['C1CCOC1', 'c1ccc2ncccc2c1']),
#        list(['c1ccc2cscc2c1', 'N=c1nc[nH][nH]1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1[nH]ccs1', 'c1ccccc1']),
#        list(['C1CCNC1', 'c1ccccc1']), list(['c1ccccc1', 'c1ccccc1']),
#        list(['C1CCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['C1CCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1']),
#        list(['C1CCCC1', 'c1ccc2ccccc2c1']),
#        list(['N=c1[nH]c2ccccc2[nH]1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1c[nH]cn1', 'c1ccc2c(c1)CCC21CCCC1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['C1CCOC1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)ccc1ccccc12', 'c1ccccc1']),
#        list(['C=C1OC=Cc2cccnc21', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1cnoc1']),
#        list(['c1ccccc1', 'c1ccccc1']), list(['C1CCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCC2CCCCC2C1']),
#        list(['C1OC2COCC2O1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1[nH]ccs1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1[nH]cc[nH]1', 'c1ccccc1']),
#        list(['C1CC2CCCC2C1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CCCN1', 'c1c[nH]cn1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1COCCO1', 'c1ccccc1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1']),
#        list(['C1COC2OCCC2O1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'C1CCCC1']),
#        list(['O=C1CCCN1', 'c1c[nH]cn1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCOC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['N=c1[nH]c2ccccc2[nH]1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CCC2SCC=C12', 'c1ccccc1']),
#        list(['C1CC2CCCC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=CCC2=CCC=CC2=C1']),
#        list(['C1CC2CCCC2C1', 'c1ccc2ccccc2c1']),
#        list(['C1OC2COCC2O1', 'c1ccccc1', 'C1=CCC=C1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccoc1']),
#        list(['C1=CCc2ccccc2C1', 'N=c1[nH]ccs1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2cscc2c1', 'N=c1nc[nH][nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CC2CCCC2C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['C1CC2CCCN2C1', 'c1ccc2ccccc2c1']),
#        list(['O=C1NCCc2ccccc21', 'C1=NCCC1']),
#        list(['N=c1cc[nH]cn1', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CC2CCC3CCCC23C1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CCCN1', 'c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccsc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C=c1ccc(=C)nc1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CC2CCCC2C1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1NCCc2ccccc21', 'C1=NCCC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1']),
#        list(['C1=CNc2ccccc2C1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CCCN1', 'c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'c1ccccc1']),
#        list(['C1=Cc2cccc3cccc(c23)C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1']),
#        list(['C=c1nnc(=C)[nH]1', 'c1ccccc1', 'c1cnoc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'O=C1COCCN1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['C1COCO1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1c[nH]cn1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1=Cc2cccc3cccc(c23)C1', 'c1ccccc1']),
#        list(['C1=Cc2cccc3cccc(c23)C1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'c1ccccc1']),
#        list(['C=c1nnc(=C)[nH]1', 'c1ccccc1', 'c1cnoc1']),
#        list(['c1cc[nH]c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['C1=CCC2=C3CCCCC3=CC2=C1', 'c1ccccc1']),
#        list(['c1cc2c(c3c1CCCC3)CCCO2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'C1=CCC=C1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['N=C1Cc2ccccc2C1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'N=c1[nH]cnc2ccncc12']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CC1CCOCC21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1=CC2(CCC1)CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=CCC2(C=C1)CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['N=c1ccc2c([nH]1)CCCC2', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['C1=Cc2ccc3c4c(ccc(c24)C1)N=CO3', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['C1=CCC2=C3CC=CC4=CCC(=C43)SC2=C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cc[nH]c1', 'N=c1nc[nH]c2ccncc12']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1', 'C1COCCN1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1nc[nH]n1', 'c1ccccc1', 'c1cnoc1']),
#        list(['C1=CCC2=C3CCCCC3=CC2=C1', 'c1ccccc1']),
#        list(['O=C1CCc2c(ccc3c2CCCN3)C1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1cncnc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2CC1', 'C1=NCCC1']),
#        list(['c1ccccc1', 'O=C1CCN2CCCC2=N1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cn[nH]c1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=C2CCCN2CCC1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1CCN2CCCC2C1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['c1cc2c(c3c1CCCC3)CCCO2', 'c1ccccc1']),
#        list(['C1=Cc2cccc3nc4c(c(c23)C1)NCC4', 'c1ccccc1']),
#        list(['c1c[nH]nn1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1ccc2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1ccccc1', 'N=c1cc2ccccc2n[nH]1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccc2c(c1)Cc1cocc1CN2']),
#        list(['c1ccccc1', 'O=c1cccc2n1CCC2', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1cccc2n1CCC2', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'C1COCOC1']),
#        list(['c1ccccc1', 'O=C1CCN2CCC=C2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1c[nH]nn1']),
#        list(['O=C1C=CC2(CC1)CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccc2c(c1)CC1CCCCc3cccc-2c3O1']),
#        list(['c1ccccc1', 'O=C1CCc2c3c(cc4cccc1c24)NCCC3']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=Cc2cccc3c2C(C1)C1NCCC1=N3', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['C1=NCCC1', 'C1=c2ccccc2=CCC1', 'c1ccccc1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'C1#CCCc2cccc(c2)-c2ccccc2CCC1']),
#        list(['c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1cc2cc(c1)-c1ccccc1CCCCCCCC2']),
#        list(['c1ccc2ccccc2c1', 'c1cncnc1', 'c1ccccc1']),
#        list(['C=C1CC2=C(CNCC2)S1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1=NNNC1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'C1=NCCCCCc2cccc(c2)-c2ccccc2C1']),
#        list(['c1cc2c3c4c(ccc3c1)CCN4CCO2', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'C1=CCCc2ccccc2-c2cccc(c2)CCCC1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'C1=NCCCCCCc2cccc(c2)-c2ccccc21']),
#        list(['c1ccc2c(c1)OCCC21CCC2CCCCN21', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'C1CCOCC1']),
#        list(['c1ccc2c(c1)CCCC21CCC2CCCCN21', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'N=c1cc[nH]cc1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1c[nH]nn1']),
#        list(['c1ccc2c(c1)CCC1=C2NCCC1', 'C1CCOCC1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1cc2cc(c1)-c1ccccc1CCCOCCCC2']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['C=C1c2ccccc2Cc2cccc3c2N1CC3', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)CCCC21CCC2CCCCN21', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=CCC2C(C1)c1cccc3c1C2c1c[nH]nc1CC3']),
#        list(['C1=NNCC(=c2ccc3c(c2)NC=c2ccccc2=3)N1', 'C1=CCC=C1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1cc2cc(c1)Cc1ccccc1-c1cccc(c1)CC2']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccc2c(c1)Cc1cccc3c1-c1c(cccc1-2)CC3']),
#        list(['c1ccc2c(c1)CCc1cccc3c1N2CC3', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['C1=c2ccccc2=NCC1', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['C=C1C=C2C=CCC(=C3C=Cc4ccccc43)C2=C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCCC1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2ncccc2c1', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)Cc1cocc1CN2']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2c(c1)CCCC21CCC2CCCCN21', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['O=C1NC2CCCC=C2c2ccccc21', 'C=C1CC=CC1', 'c1cncnc1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1', 'C1CCNC1', 'C1=NCNC1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCCC1']),
#        list(['C1=Nc2ccccc2CC1', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)Cc1cocc1CN2']),
#        list(['C1=Cc2ccccc2C1', 'c1ccccc1', 'C1=Cc2ccccc2C1']),
#        list(['c1ccccc1', 'O=c1cc2ccc3c(c4c5c(c(c1)c24)CC=CC5)CNN3']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C=C1c2ccccc2Cc2cccc3c2N1CC3', 'c1ccc2ccccc2c1']),
#        list(['C1=Cc2cccc3c2C(C1)C1=NCNC1C3', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=C2c3ccccc3Cc3cccc4c3N2C(CCCC1)C4', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1cc2c3c(c1)Cc1cccc4cccc(c14)N3CC2', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1', 'C1CCNC1']),
#        list(['c1ccc2c(c1)CCNC2', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['C1=Cc2cccc3cc4c(c(c23)C1)NCCC4', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=Nc2ccccc2CC1', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1c[nH]cn1']),
#        list(['C1CCNC1', 'c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1', 'C1CNCCN1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCCC1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)Cc1cocc1CN2']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1CNCCNC1', 'c1ccc2c(c1)CCNC2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1', 'C1CNCCN1']),
#        list(['c1ccc2c(c1)CCNC2', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['N=C1Cc2ccccc2C1', 'c1ccc2cnccc2c1', 'c1ccncc1']),
#        list(['C1=C2c3ccccc3Cc3cccc4c3N2C(CCCC1)C4', 'c1ccc2ccccc2c1']),
#        list(['c1cc2c(c3c1=NCCC3)CCCN=2', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['C1=Nc2ccccc2CC1', 'c1ccc2c(c1)CCC1=C2NCCC1']),
#        list(['c1ccccc1', 'C1CCCCC1', 'N=c1ccc2ncccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['C1=C2c3ccccc3Cc3cccc4c3N2C(CCCC1)C4', 'c1ccc2ccccc2c1']),
#        list(['C1=C2c3ccccc3Cc3cccc4c3N2C(CCCOC1)C4', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'O=C1CCCN1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'C1CCCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nc[nH]n1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['O=C1CCCNCC1', 'c1ccc2c(c1)CCNC2', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNCC1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['O=C1CNCCN1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=Cc2ccccc2CC1', 'c1ccccc1', 'C1=CCCN=C1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1', 'C1CNCCN1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'C1=NCc2ccccc2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nc[nH]n1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1', 'O=C1CCCNCC1']),
#        list(['C1=CCC2=C3CC=CC4=CCC(=C43)CC2=C1', 'c1ccccc1', 'O=C1CNCC=N1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['C1=c2ccccc2=CC1', 'c1nc[nH]n1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=c2ccccc2=CC1', 'c1nc[nH]n1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1COCN1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1', 'C1CCCNCC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCN2CCCCC2C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCN2CCCCC2C1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1CN2CCC(C2)N1']),
#        list(['c1ccccc1', 'C1=Cc2ccccc2C1', 'c1nc[nH]n1', 'c1ccccc1', 'c1ccc2c(c1)CCN2']),
#        list(['O=C1CCOC=N1', 'O=C1NC2CC=CCC2c2ccccc21', 'C=C1CC=CC1']),
#        list(['C1CCNC1', 'C=C1C=CCCC12CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C=C1C=CCCC12CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'C1=NCCN1']),
#        list(['C=C1C=CCCC12CCC1CCC=CN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['O=C1CCCN1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'O=C1CCCCN1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'C1CCNCC1']),
#        list(['c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1=CCC=CC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=CN2CCCC2CC1', 'c1ccccc1', 'C1CNCCN1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNCC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2[nH]cnc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1', 'O=C1CCCN1']),
#        list(['O=C1NC2CCCC=C2c2ccccc21', 'C1=CCC=C1', 'C1=CCc2ocnc2C1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['C=C1C=CCCC12CCC1CCC=CN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1CCCC1', 'c1cc2c3c(cccc3c1)OCCN2', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['C1=CC=CCC=1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['C1=CC=CCC=1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'C1=CCC=CC1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C=C1C=CCCC12CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'c1cncnc1']),
#        list(['C=C1CCCCNC1', 'c1ccc2c(c1)CCNC2', 'c1ccccc1']),
#        list(['C1=CCC=CC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['N=c1ccnc[nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nc[nH]n1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1CC2CN(C1)CCN2']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['O=C1NC2CCC=CC2c2ccccc21', 'c1ccc2ocnc2c1', 'C1=CCC=C1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1', 'C1CCCNCC1']),
#        list(['C1=COCC1', 'c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=CCC=CC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1CCCCC1', 'C=C1C=CCCC12CCC1CCCCN12', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['C1CCOC1', 'c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=NCc2ccccc2C1', 'c1ccccc1', 'O=C1CCC2C=CNCCN12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2nc3sccc3cc2c1', 'C1=NCCN1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1cn[nH]c1', 'c1ccccc1', 'O=C1CNCCN1']),
#        list(['C=C1C=CCCC12CCC1CCC=CN12', 'c1c[nH]cn1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['c1ccccc1', 'C1CCCCC1', 'N=c1ccc2ncccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['C=C1C=CCCC12CCC1CCC=CN12', 'c1c[nH]cn1', 'c1ccccc1', 'C1CCCC1']),
#        list(['c1ccc2c(c1)Cc1ccsc1N2', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=CCC=CC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=CCC=CC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'C1=CC2CCCC2O1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CNCN1']),
#        list(['C1CCOC1', 'c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=CCCCC1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccc2nc3[nH]ccc3cc2c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCCC2', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'C1=CCC=CC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1', 'C1CCNC1']),
#        list(['c1ccc2c(c1)Cc1ccsc1N2', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1CCNCC1']),
#        list(['C1=CC=CCC=1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nnc[nH]1', 'c1ccsc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'C1=C2CNCCN2CCC1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'C1=NCCOc2ccccc21', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1cc2c3c(cccc3c1)OCCN2', 'C1CCCC1', 'C1CCNCC1', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1=CCNCC1']),
#        list(['c1ccccc1', 'C1CCCCC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)Cc1ccsc1N2', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)Cc1ccsc1N2', 'c1nc[nH]n1']),
#        list(['c1ccc2ccccc2c1', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)Cc1ccsc1N2', 'c1cncnc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nnc2n1CC1CCN=C1C2']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nnc2n1CC1=C(CCC1)C2']),
#        list(['C1=NCNC1', 'c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)Cc1ccsc1N2', 'c1cn[nH]c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1CCNCC1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccncc1']),
#        list(['c1ccncc1', 'c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1cc2c(s1)Cc1cncn1C2']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1nnc[nH]1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'C1CC2OCOCC2O1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1', 'O=C1CCCN1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccncc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'C1=CC2OCOCC2O1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['O=C1CNCCCN1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'C1CCC2CNCCN2CC1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1c[nH]cn1', 'C1=CC2CCCC2O1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['N=C1Cc2ccccc2C1', 'c1ccc2cnccc2c1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['N=C1C=C2CC3=c4c(cccc4=CC3)C2CC1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'O=C1CNCCCN1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccncc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['N=C1C=C2CC3=c4c(cccc4=CC3)C2CC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['c1nc[nH]n1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'C1=NNC2Cc3sccc3CN12']),
#        list(['C1=Cc2ccccc2CC1', 'c1ccccc1', 'c1ccncc1', 'C1CCNCC1']),
#        list(['C1CCNCC1', 'C1CCCC1', 'c1cc2c3c(cccc3c1)OCCN2', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)Cc1ccsc1N2', 'O=c1nc[nH][nH]1']),
#        list(['C1CCOCC1', 'c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C1=CCNCC1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccncc1']),
#        list(['C1=CC2CN=c3c(cc4cccc5c4c3CCC=5)N2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1', 'c1ccsc1']),
#        list(['c1ccc2ccccc2c1', 'N=c1nc2c(ccc3cc[nH]cc32)[nH]1', 'c1ccccc1']),
#        list(['O=c1cncc[nH]1', 'c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=CCNCC1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'C1=NCC2Cc3sccc3CN12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1=CCNCC1', 'c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccncc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['N=c1ccc2ncccc2[nH]1', 'c1ccc2c(c1)CCc1ccccc1-2', 'C1CCCCC1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccc2ccccc2c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['N=C1Cc2ccccc2C1', 'c1ccc2cnccc2c1', 'C1CCNC1', 'c1ccncc1']),
#        list(['C1CCNC1', 'c1ccccc1', 'c1cn[nH]c1', 'c1ccncc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C1=CCNCC1', 'c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['N=C1Cc2ccccc2C1', 'c1ccc2cnccc2c1', 'c1ccncc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['C=C1C=CC=CC1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1COCCN1', 'c1c[nH]cn1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C=C1C=C2C=CC=C=C2CC1']),
#        list(['c1ccc2cnccc2c1', 'N=C1Cc2ccccc2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccc2ccccc2c1']),
#        list(['c1ccccc1', 'C1CCN2CCCC2C1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1c[nH]cn1', 'C1CCCC1', 'c1ccccc1', 'c1cn[nH]c1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['N=C1Cc2ccccc2C1', 'c1ccc2cnccc2c1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1', 'C=C1CCc2ccccc2C1'])],
#       dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                            SMILES  Count
# 1                        c1ccccc1    688
# 0                        c1ccncc1    122
# 43                     c1c[nH]cn1     95
# 4                  c1ccc2ccccc2c1     91
# 29                     c1cn[nH]c1     57
# ..                            ...    ...
# 21            O=c1[nH]ccc2ccccc12      1
# 23                C1CCC2CCOCCC2C1      1
# 96            N=c1ccc2ccccc2[nH]1      1
# 99                       C1COCOC1      1
# 94  C1=Cc2cccc3nc4c(c(c23)C1)NCC4      1
#
# [202 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup()
res = df.mol.apply(ring_system_lookup.process_mol)

# %%
res
# Out:
# 0                                   [(c1ccncc1, 275595)]
# 1                                  [(c1ccccc1, 2568039)]
# 2                                  [(c1ccccc1, 2568039)]
# 3                                   [(c1ccncc1, 275595)]
# 4                                  [(c1ccccc1, 2568039)]
#                              ...
# 516    [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
# 517    [(c1cn[nH]c1, 112133), (c1ccccc1, 2568039), (c...
# 518    [(c1c[nH]cn1, 78586), (C1CCCC1, 38317), (c1ccc...
# 519    [(N=C1Cc2ccccc2C1, 3), (c1ccc2cnccc2c1, 7830),...
# 520    [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (c1...
# Name: mol, Length: 521, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq
# 0     275595
# 1    2568039
# 2    2568039
# 3     275595
# 4    2568039
# ..       ...
# 516   100599
# 517    78586
# 518    38317
# 519        3
# 520        2
#
# [521 rows x 5 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [16:06:21] WARNING: Charges were rearranged
#
# [16:06:21] WARNING: Omitted undefined stereo
#
# [16:06:21] WARNING: Omitted undefined stereo
#
# [16:06:21] WARNING: Omitted undefined stereo
#
# [16:06:21] WARNING: Omitted undefined stereo
#
# [16:06:21] WARNING: Omitted undefined stereo
#
# [16:06:21] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Charges were rearranged
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#
# [16:06:22] WARNING: Omitted undefined stereo
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq                                              inchi
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...
# ..       ...                                                ...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...
# 519        3  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...
# 520        2  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...
#
# [521 rows x 6 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq                                              inchi
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...
# ..       ...                                                ...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...
# 519        3  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...
# 520        2  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...
#
# [521 rows x 6 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 511  OCC1COC(Cn2ccnc2-c2ccc(-n3cc(C(O)C(F)(F)F)c(-c...
# 514  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)Cc4c...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 511  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad310>
# 514  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac120>
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
#
#                                            ring_sytems        min_ring  \
# 0                                           [c1ccncc1]        c1ccncc1
# 1                                           [c1ccccc1]        c1ccccc1
# 2                                           [c1ccccc1]        c1ccccc1
# 3                                           [c1ccncc1]        c1ccncc1
# 4                                           [c1ccccc1]        c1ccccc1
# ..                                                 ...             ...
# 511  [C1COCCN1, c1c[nH]cn1, c1ccccc1, c1cn[nH]c1, c...      c1c[nH]cn1
# 514  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...  c1ccc2ccccc2c1
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...        c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...      c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...         C1CCCC1
#
#     min_freq                                              inchi
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...
# ..       ...                                                ...
# 511    78586  InChI=1S/C29H27F4N7O3/c30-19-2-1-3-22(10-19)39...
# 514    55872  InChI=1S/C38H34N4O/c1-27-8-2-5-15-35(27)32-12-...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...
#
# [293 rows x 6 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/521 [00:00<?, ?it/s]
#     rule_set_name description
# 0              ok          ok
# 1              ok          ok
# 2              ok          ok
# 3              ok          ok
# 4              ok          ok
# ..            ...         ...
# 516            ok          ok
# 517            ok          ok
# 518            ok          ok
# 519            ok          ok
# 520            ok          ok
#
# [521 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/521 [00:00<?, ?it/s]
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq                                              inchi rule_set_name  \
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3            ok
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...            ok
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3            ok
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...            ok
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...            ok
# ..       ...                                                ...           ...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...            ok
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...            ok
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...            ok
# 519        3  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...            ok
# 520        2  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...            ok
#
#     description
# 0            ok
# 1            ok
# 2            ok
# 3            ok
# 4            ok
# ..          ...
# 516          ok
# 517          ok
# 518          ok
# 519          ok
# 520          ok
#
# [512 rows x 8 columns]

# %% [markdown]
# Test all filters from rd filters

# %%
rd_filters = ['Glaxo', 'Dundee', 'BMS', 'SureChEMBL', 'MLSMR', 'Inpharmatica', 'LINT']
for filter in rd_filters:
    reos.set_active_rule_sets([filter])
    new_df = reos.pandas_mols(df.mol)
    print(filter, len(new_df[new_df.description == "ok"])/len(new_df), reos.get_active_rule_sets(), len(new_df[new_df.description == "ok"]))
# Out:
#   0%|          | 0/521 [00:00<?, ?it/s]
# Glaxo 0.963531669865643 ['Glaxo'] 502
#   0%|          | 0/521 [00:00<?, ?it/s]
# Dundee 0.54510556621881 ['Dundee'] 284
#   0%|          | 0/521 [00:00<?, ?it/s]
# BMS 0.9289827255278311 ['BMS'] 484
#   0%|          | 0/521 [00:00<?, ?it/s]
# SureChEMBL 0.7984644913627639 ['SureChEMBL'] 416
#   0%|          | 0/521 [00:00<?, ?it/s]
# MLSMR 0.5393474088291746 ['MLSMR'] 281
#   0%|          | 0/521 [00:00<?, ?it/s]
# Inpharmatica 0.9232245681381958 ['Inpharmatica'] 481
#   0%|          | 0/521 [00:00<?, ?it/s]
# LINT 0.6391554702495201 ['LINT'] 333

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq                                              inchi  Reymond
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..       ...                                                ...      ...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519        3  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
# 520        2  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...     True
#
# [521 rows x 7 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq                                              inchi  Reymond
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..       ...                                                ...      ...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519        3  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
# 520        2  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...     True
#
# [521 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...           C1CCCC1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#     min_freq                                              inchi  Reymond  \
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..       ...                                                ...      ...
# 516   100599  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517    78586  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518    38317  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519        3  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
# 520        2  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 516     False
# 517     False
# 518     False
# 519     False
# 520     False
#
# [521 rows x 8 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 332  O=c1ccccn1-c1cc(CCO)cc(C2CC(c3cn(-c4ccccc4)cn3...
# 336  Cc1ccccc1CCC(=O)Cc1cc(C)c(CC(N)=O)nc1-c1ccc(-c...
# 340  O=c1ccccn1-c1cc(CCO)cc(C2CC(c3cn(-c4ccccc4)cn3...
# 344  Cc1cccc2c1=C(c1ncn(-c3ccc(F)cc3)n1)CC=2c1ccc(C...
# 346  Cc1cccc2c1=C(c1ncn(-c3ccc(F)cc3)n1)CC=2c1ccc(C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 332  <rdkit.Chem.rdchem.Mol object at 0x79cadbd787b0>
# 336  <rdkit.Chem.rdchem.Mol object at 0x79cadbd7b220>
# 340  <rdkit.Chem.rdchem.Mol object at 0x79cadbd79bd0>
# 344  <rdkit.Chem.rdchem.Mol object at 0x79cadbd794d0>
# 346  <rdkit.Chem.rdchem.Mol object at 0x79cadbd79070>
#
#                                            ring_sytems         min_ring  \
# 0                                           [c1ccncc1]         c1ccncc1
# 1                                           [c1ccccc1]         c1ccccc1
# 2                                           [c1ccccc1]         c1ccccc1
# 3                                           [c1ccncc1]         c1ccncc1
# 4                                           [c1ccccc1]         c1ccccc1
# ..                                                 ...              ...
# 332  [O=c1cccc[nH]1, c1ccccc1, C1CCN2CCCC2C1, c1c[n...    C1CCN2CCCC2C1
# 336         [c1ccccc1, c1ccncc1, c1ccccc1, c1nc[nH]n1]       c1nc[nH]n1
# 340  [O=c1cccc[nH]1, c1ccccc1, C1CCN2CCCC2C1, c1c[n...    C1CCN2CCCC2C1
# 344  [C1=c2ccccc2=CC1, c1nc[nH]n1, c1ccccc1, c1ccccc1]  C1=c2ccccc2=CC1
# 346  [C1=c2ccccc2=CC1, c1nc[nH]n1, c1ccccc1, c1ccccc1]  C1=c2ccccc2=CC1
#
#     min_freq                                              inchi  Reymond  \
# 0     275595    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    2568039  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    2568039  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     275595  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    2568039  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..       ...                                                ...      ...
# 332       77  InChI=1S/C30H31FN4O2/c31-30-24(16-21(12-15-36)...     True
# 336    43596  InChI=1S/C29H31N5O3/c1-18-5-3-4-6-20(18)11-12-...     True
# 340       77  InChI=1S/C30H32N4O3/c35-15-12-21-16-24(30(37)2...     True
# 344        0  InChI=1S/C30H30FN5O/c1-20-6-5-7-25-26(21-8-10-...     True
# 346        0  InChI=1S/C30H29FN4O2/c1-20-6-5-7-25-26(21-8-10...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 332      True
# 336      True
# 340      True
# 344      True
# 346      True
#
# [248 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC22 database druglike molecules

# %%
ring_system_lookup_ZINC22 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC22_rings_system.csv")
res_zinc22 = df.mol.apply(ring_system_lookup_ZINC22.process_mol)
res_zinc22
# Out:
# 0                               [(c1ccncc1, 9975620076)]
# 1                              [(c1ccccc1, 21243538754)]
# 2                              [(c1ccccc1, 21243538754)]
# 3                               [(c1ccncc1, 9975620076)]
# 4                              [(c1ccccc1, 21243538754)]
#                              ...
# 516    [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 517    [(c1cn[nH]c1, 8081544476), (c1ccccc1, 21243538...
# 518    [(c1c[nH]cn1, 2706690320), (C1CCCC1, 531721769...
# 519    [(N=C1Cc2ccccc2C1, 296), (c1ccc2cnccc2c1, 1382...
# 520    [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# Name: mol, Length: 521, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc22.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...        c1c[nH]cn1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#         min_freq                                              inchi  Reymond  \
# 0     9975620076    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    21243538754  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    21243538754  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     9975620076  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    21243538754  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..           ...                                                ...      ...
# 516   2861731550  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517   2706690320  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518   2706690320  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519          296  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
# 520            4  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 516     False
# 517     False
# 518     False
# 519     False
# 520     False
#
# [521 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 515  NCCCCNCC(=O)N(CCO)c1cc(CCO)cc(C2CC(c3cn(-c4ccc...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 515  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acf90>
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
#
#                                            ring_sytems         min_ring  \
# 0                                           [c1ccncc1]         c1ccncc1
# 1                                           [c1ccccc1]         c1ccccc1
# 2                                           [c1ccccc1]         c1ccccc1
# 3                                           [c1ccncc1]         c1ccncc1
# 4                                           [c1ccccc1]         c1ccccc1
# ..                                                 ...              ...
# 515    [c1ccccc1, C1CCN2CCCC2C1, c1c[nH]cn1, c1ccccc1]    C1CCN2CCCC2C1
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...         c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...       c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...       c1c[nH]cn1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...  N=C1Cc2ccccc2C1
#
#         min_freq                                              inchi  Reymond  \
# 0     9975620076    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    21243538754  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    21243538754  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     9975620076  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    21243538754  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..           ...                                                ...      ...
# 515       128926  InChI=1S/C33H46N6O4/c34-12-5-6-13-35-21-32(42)...     True
# 516   2861731550  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517   2706690320  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518   2706690320  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519          296  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 515     False
# 516     False
# 517     False
# 518     False
# 519     False
#
# [348 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 0) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...        c1c[nH]cn1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#         min_freq                                              inchi  Reymond  \
# 0     9975620076    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    21243538754  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    21243538754  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     9975620076  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    21243538754  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..           ...                                                ...      ...
# 516   2861731550  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517   2706690320  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518   2706690320  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519          296  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
# 520            4  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 516     False
# 517     False
# 518     False
# 519     False
# 520     False
#
# [369 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 10) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 515  NCCCCNCC(=O)N(CCO)c1cc(CCO)cc(C2CC(c3cn(-c4ccc...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 515  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acf90>
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
#
#                                            ring_sytems         min_ring  \
# 0                                           [c1ccncc1]         c1ccncc1
# 1                                           [c1ccccc1]         c1ccccc1
# 2                                           [c1ccccc1]         c1ccccc1
# 3                                           [c1ccncc1]         c1ccncc1
# 4                                           [c1ccccc1]         c1ccccc1
# ..                                                 ...              ...
# 515    [c1ccccc1, C1CCN2CCCC2C1, c1c[nH]cn1, c1ccccc1]    C1CCN2CCCC2C1
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...         c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...       c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...       c1c[nH]cn1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...  N=C1Cc2ccccc2C1
#
#         min_freq                                              inchi  Reymond  \
# 0     9975620076    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    21243538754  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    21243538754  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3     9975620076  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    21243538754  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..           ...                                                ...      ...
# 515       128926  InChI=1S/C33H46N6O4/c34-12-5-6-13-35-21-32(42)...     True
# 516   2861731550  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517   2706690320  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518   2706690320  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519          296  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 515     False
# 516     False
# 517     False
# 518     False
# 519     False
#
# [351 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC20 database druglike molecules

# %%
ring_system_lookup_ZINC20 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC20_rings_ststem.csv")
res_zinc20 = df.mol.apply(ring_system_lookup_ZINC20.process_mol)
res_zinc20
# Out:
# 0                                [(c1ccncc1, 110130832)]
# 1                                [(c1ccccc1, 503413992)]
# 2                                [(c1ccccc1, 503413992)]
# 3                                [(c1ccncc1, 110130832)]
# 4                                [(c1ccccc1, 503413992)]
#                              ...
# 516    [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 517    [(c1cn[nH]c1, 94875952), (c1ccccc1, 503413992)...
# 518    [(c1c[nH]cn1, 26014852), (C1CCCC1, 34084223), ...
# 519    [(N=C1Cc2ccccc2C1, 348), (c1ccc2cnccc2c1, 1540...
# 520    [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# Name: mol, Length: 521, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc20.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
# 520  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)C=C4...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
# 520  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ace40>
#
#                                            ring_sytems          min_ring  \
# 0                                           [c1ccncc1]          c1ccncc1
# 1                                           [c1ccccc1]          c1ccccc1
# 2                                           [c1ccccc1]          c1ccccc1
# 3                                           [c1ccncc1]          c1ccncc1
# 4                                           [c1ccccc1]          c1ccccc1
# ..                                                 ...               ...
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...          c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...        c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...        c1c[nH]cn1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...   N=C1Cc2ccccc2C1
# 520  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, C=C1C...  C=C1CCc2ccccc2C1
#
#       min_freq                                              inchi  Reymond  \
# 0    110130832    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    503413992  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    503413992  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3    110130832  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    503413992  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..         ...                                                ...      ...
# 516   30067373  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517   26014852  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518   26014852  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519        348  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
# 520          6  InChI=1S/C38H36N4O/c1-27-8-2-5-15-35(27)32-12-...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 516     False
# 517     False
# 518     False
# 519     False
# 520     False
#
# [521 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 0                                           CCc1cccnc1
# 1                                          CCc1ccccc1N
# 2                                        CCc1cccc(F)c1
# 3                                        CCc1cncc(C)c1
# 4                                       CCc1cccc(F)c1C
# ..                                                 ...
# 514  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCNC(=O)Cc4c...
# 516  Cc1ccccc1-c1cccc(Cc2nccc(-c3cccc(NCCN(C)c4ccc(...
# 517  CC=CCCCCc1cn(-c2ccc(C(=O)NCCc3ccc(C=O)cc3)cc2)...
# 518  Cc1cn(CCNC2CCCC2)c(-c2ccc(-n3cc(C(O)C(F)(F)F)c...
# 519  CCCNC(=O)C1C(=Nc2ccc3cncc(Cc4ccccc4)c3c2)C(CNN...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x79cadbd285f0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x79cadbd283c0>
# 2    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28510>
# 3    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28430>
# 4    <rdkit.Chem.rdchem.Mol object at 0x79cadbd28200>
# ..                                                ...
# 514  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac120>
# 516  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ad000>
# 517  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac890>
# 518  <rdkit.Chem.rdchem.Mol object at 0x79cadc0ac740>
# 519  <rdkit.Chem.rdchem.Mol object at 0x79cadc0acc10>
#
#                                            ring_sytems         min_ring  \
# 0                                           [c1ccncc1]         c1ccncc1
# 1                                           [c1ccccc1]         c1ccccc1
# 2                                           [c1ccccc1]         c1ccccc1
# 3                                           [c1ccncc1]         c1ccncc1
# 4                                           [c1ccccc1]         c1ccccc1
# ..                                                 ...              ...
# 514  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...   c1ccc2ccccc2c1
# 516  [c1ccccc1, c1ccccc1, c1cncnc1, c1ccccc1, c1ccc...         c1cncnc1
# 517  [c1cn[nH]c1, c1ccccc1, c1ccccc1, c1c[nH]cn1, c...       c1c[nH]cn1
# 518  [c1c[nH]cn1, C1CCCC1, c1ccccc1, c1cn[nH]c1, c1...       c1c[nH]cn1
# 519  [N=C1Cc2ccccc2C1, c1ccc2cnccc2c1, c1ccccc1, c1...  N=C1Cc2ccccc2C1
#
#       min_freq                                              inchi  Reymond  \
# 0    110130832    InChI=1S/C7H9N/c1-2-7-4-3-5-8-6-7/h3-6H,2H2,1H3     True
# 1    503413992  InChI=1S/C8H11N/c1-2-7-5-3-4-6-8(7)9/h3-6H,2,9...     True
# 2    503413992  InChI=1S/C8H9F/c1-2-7-4-3-5-8(9)6-7/h3-6H,2H2,1H3     True
# 3    110130832  InChI=1S/C8H11N/c1-3-8-4-7(2)5-9-6-8/h4-6H,3H2...     True
# 4    503413992  InChI=1S/C9H11F/c1-3-8-5-4-6-9(10)7(8)2/h4-6H,...     True
# ..         ...                                                ...      ...
# 514    4273930  InChI=1S/C38H34N4O/c1-27-8-2-5-15-35(27)32-12-...     True
# 516   30067373  InChI=1S/C39H36N4/c1-29-10-6-7-17-37(29)33-14-...     True
# 517   26014852  InChI=1S/C35H34FN5O2/c1-2-3-4-5-6-8-29-22-41(3...     True
# 518   26014852  InChI=1S/C31H31F4N7O/c1-20-16-40(14-13-36-23-6...     True
# 519        348  InChI=1S/C36H34N6O/c1-2-16-39-36(43)34-31-13-7...     True
#
#      Lipinski
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 514     False
# 516     False
# 517     False
# 518     False
# 519     False
#
# [314 rows x 8 columns]
