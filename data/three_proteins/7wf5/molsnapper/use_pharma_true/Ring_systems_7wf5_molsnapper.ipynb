# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob
import molvs
from multiprocessing import Pool, cpu_count
from tqdm.auto import tqdm

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/7wf5/molsnapper/ues_pharma_true
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/7wf5/molsnapper

# %% [markdown]
# Reading data from crossdock dataset, add a standardization for small molecule data:

# %%
standardizer = molvs.standardize.Standardizer()

def standardize_mol(mol):
    try:
        mol = standardizer.standardize(mol)
        mol = standardizer.fragment_parent(mol, skip_standardize=True)
        mol = standardizer.tautomer_parent(mol, skip_standardize=True)
        mol = standardizer.isotope_parent(mol, skip_standardize=True)
        mol = standardizer.charge_parent(mol, skip_standardize=True)
        return mol
    except:
        return None

# %%
smi_list = []
with open('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/three_proteins/7wf5/molsnapper/ues_pharma_true/500_generated.smi') as f:
    for smi in f:
        smi_list.append(smi.strip())
standardized_smiles_list = []
for smi in tqdm(smi_list, desc="Standardizing molecules", unit="mol"):
    mol = Chem.MolFromSmiles(smi)
    mol = standardize_mol(mol)
    
    if mol:
        standardized_smiles_list.append(Chem.MolToSmiles(mol))
    else:
        print(f"Skipping molecule {smi}")
        pass

print(len(smi_list))
len(standardized_smiles_list)
# Out:
# Standardizing molecules:   0%|          | 0/500 [00:00<?, ?mol/s]
# [16:40:24] Can't kekulize mol.  Unkekulized atoms: 7 8 9 37 38
# [16:40:24] Can't kekulize mol.  Unkekulized atoms: 7 8 9 37 38
# [16:40:24] Can't kekulize mol.  Unkekulized atoms: 7 8 9 37 38
# [16:40:24] Can't kekulize mol.  Unkekulized atoms: 7 8 9 37 38
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:42] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:40:43] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17
# [16:41:56] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:56] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:56] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:56] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:56] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:56] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:41:57] Can't kekulize mol.  Unkekulized atoms: 32 33 34 35 36
# [16:42:14] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18 36 37
# [16:42:14] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18 36 37
# [16:42:14] Can't kekulize mol.  Unkekulized atoms: 14 15 16 17 18 36 37
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:42:43] Can't kekulize mol.  Unkekulized atoms: 2 3 4 13 14 15 40 41 42
# [16:43:12] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7
# [16:43:13] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7
# [16:43:13] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7
# [16:44:14] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7 8 10 11 12 14 18
# [16:44:20] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7 8 10 11 12 14 18
# [16:44:20] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7 8 10 11 12 14 18
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:29] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:30] Can't kekulize mol.  Unkekulized atoms: 1 2 3 37 38
# [16:45:41] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7 8 10 11 12 14 18
# [16:45:41] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7 8 10 11 12 14 18
# [16:45:41] Can't kekulize mol.  Unkekulized atoms: 0 2 3 4 5 6 7 8 10 11 12 14 18
# 500
# 500

# %% [markdown]
# Set the default image size

# %%
with open('500_generated_standardized.smi', 'w') as f:
    for item in standardized_smiles_list:
        f.write("%s\n" % item)

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(standardized_smiles_list, columns=['SMILES'])
df
# Out:
#                                                 SMILES
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
# [500 rows x 1 columns]

# %% [markdown]
# Remove repeated molecules

# %%
df = df.drop_duplicates(['SMILES'])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                 SMILES
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
# [500 rows x 1 columns]

# %% [markdown]
# Save the smi file for further use

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0      [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1      [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2      [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3      [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4      [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
#                              ...
# 495    [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496    [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497    [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498    [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499    [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
# Name: ring_sytems, Length: 500, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'C1CCC2N=C2C1', 'c1ccncc1']),
#        list(['N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43', 'C=C1CCCCC2CCCCC12']),
#        list(['N=c1cncc[nH]1', 'O=C1c2ccccc2C2CNCCN12', 'c1ccccc1', 'C1CNCN1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'C1CCC2C(C1)NCNC1NC3CCCCC3N12']),
#        list(['c1ccccc1', 'O=C1NC(=O)c2ncccc21', 'c1ccccc1', 'C1CCC2C(C1)NC1CCCNC12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1']),
#        list(['N=c1[nH][nH]c2ccccc12', 'c1ccccc1', 'O=C1NC23CC24C2CC5C3C5C124', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'C1CNC2CCCCC2NC1']),
#        list(['C1CCC2NC3CCCCC3NCC2C1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2cnncc2c1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'C1CCC2C(C1)NC1NCNC3NCNC3N12']),
#        list(['C1CCNCC1', 'O=C1CNC2CCCCC2C1', 'c1ccncc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['C1NCC2NCNC2N1', 'c1ccccc1', 'c1ccccc1', 'O=c1[nH]c(=O)c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CNc1ccccc1-2', 'c1cnccn1']),
#        list(['C1CCC2NC3NC4CCCCC4N3C2CC1', 'O=c1nc2ccccc2nc2ccccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1cnoc1', 'c1ccncc1']),
#        list(['c1ccsc1', 'c1ccccc1', 'c1ccccc1', 'N=c1nc2cc[nH]n2c(=N)[nH]1', 'c1ccccc1']),
#        list(['N=c1c2ccccc2[nH]c2ccccc12', 'c1ccccc1', 'c1ccc2[nH]ccc2c1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'O=C1NS(=O)(=O)c2ccccc21', '[NH2+]=C1CCCC2NC12']),
#        list(['N=C1C=c2ncccc2=NCC1', 'c1ccccc1', 'c1ccccc1', 'C1=CC2(C=C1)NC21C=CN=CN=C1']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'c1ccccc1', 'O=C1CNc2ccccc2N1']),
#        list(['C1CCC2C(C1)NNC1CCCCC12', 'c1ccccc1', 'c1cnc2cccnc2c1']),
#        list(['N=c1cno[nH]1', 'O=c1cc2c(c3ccnn13)=CC=C2', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCC2C(C1)CN1NCNC21', 'c1ccccc1', 'c1ccccc1', 'c1cnc2[nH]cnc2c1']),
#        list(['c1ccc2ccccc2c1', 'c1ccccc1', 'c1ncc2nncnc2n1']),
#        list(['c1cc[nH]c1', 'c1ccccc1', 'c1ccc2c(c1)c1ccccc1n1nnnc21']),
#        list(['c1cc[nH]c1', 'c1ccccc1', 'C1CCC2C(C1)C1NCNN1C1C3CCCCC3N21']),
#        list(['C1CNCCN1', 'c1ccncc1', 'c1ccc2[nH+]cccc2c1', 'C1CCC2NCCNC2CC1']),
#        list(['O=C1OC23CC4CC(C2)C3C(C4)c2ccccc21', 'c1ccc2c(c1)CCNCC2', 'c1ccccc1']),
#        list(['O=C1C2CCCCC2NC2CCCCCN12', 'c1ccccc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'C=c1ccn2c3ccccc3[n+](=C)c2c1']),
#        list(['C1CCC2C(C1)NC1CCNN12', 'O=c1ccc2ccccc2o1', 'O=C1CCCCC1']),
#        list(['c1ccccc1', 'c1ccc2c[nH]cc2c1', '[NH2+]=C1C=CCC2NC12', 'C1=CC2=NC2C=C1']),
#        list(['C1CCC2C(C1)CCC1CCCN12', 'c1ccccc1', 'c1ccccc1', 'c1ncon1']),
#        list(['c1ccccc1', 'c1ccoc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccsc1']),
#        list(['C1CCC2NCCNC2C1', 'c1ccccc1', 'C=c1[nH]c2ccccc3c4ccc(=N)cc4n([nH]1)c23']),
#        list(['N=c1ccc2c(c1)c1nc(=N)nc3[nH][nH]c2n31', 'C1=CC2C3C4NC5CC4C1C5C23', 'c1ccc2c(c1)N2']),
#        list(['c1ccccc1', 'C1CCC2C(C1)CNC1C3CCCCC3N21', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCC2NC2C1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'N=c1ccc2c3c4c(cc[nH]c4nc2c1)CCC3']),
#        list(['c1ccccc1', 'C=c1[nH]c2cccc3c4ccccc4n1c23', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'c1ccncc1', 'O=c1cnc2ccccc2[nH]1', 'C1CCC2NCCCC2NC1']),
#        list(['c1ccccc1', 'c1ccccc1', '[NH2+]=C1CCC2NC2C1', 'C1CNCN1', 'c1nncs1']),
#        list(['N=c1nc2ncncn2[nH]1', 'c1ccccc1', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccncc1', 'O=c1cn[nH]c2nc3ccccc3n12', 'c1ccncc1']),
#        list(['O=c1c2ccccc2n2n1CCNCC2', 'c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CCCNCC1', 'c1ccncc1', 'C1CNCCN1', 'C1CSCNN1']),
#        list(['c1ccccc1', 'O=C1CC2(NN1)NC2=O', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1Nc2ccccc21', 'c1ccc2c(c1)NCC[NH+]1CC21', 'c1ccncc1']),
#        list(['c1ccc2c(c1)NCCO2', 'O=C1NC2C3CC45C6C7NC4C54C2C42C7C12C36', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccc2c(c1)ncc1scnc12']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccc2c(c1)[nH]c1ccccc12', 'O=C1CCNN1']),
#        list(['C1CCNC1', 'c1ccc2ncccc2c1', 'C1CNCCN1', 'C1CCC2C(C1)NC1SCCC12']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)CCCN2', 'c1ccncc1']),
#        list(['c1ccc2[nH]cnc2c1', 'C1CCCNCC1', 'C1CCNCC1', 'C1#[N+]C12CCCCC2']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1[nH]c2ccccc2c2c1CCCCC2', 'N=c1nc[nH]cn1']),
#        list(['c1ccccc1', 'C1CCC2NCC3NCNC(C1)C23', 'c1ccccc1']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1NNNN1']),
#        list(['c1ccccc1', 'O=C1NC2CCCCC2N2CNCCC12', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['N=c1[nH]c2ccccc2c2ccccc12', 'C1CCC2C(C1)NN1C3CCCCC3NC21']),
#        list(['O=C1C2CCCCC2NC2CNCNC12', 'c1ccccc1', 'N=c1cn[nH][nH]1']),
#        list(['c1ccccc1', 'N=c1c2ccccc2[nH]c2ccccc12', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1', 'O=C1NC2C3CC4CCCC2C4CC13']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'C1CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2ncccc2c1']),
#        list(['C1CCC2C(C1)NCC1CCCC12', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'c1ccccc1', 'c1ccc2c3c(cnc2c1)CCC3']),
#        list(['O=c1nc2ccccc2nc2ccccc12', 'c1ccccc1', 'C1CC2NCCN3C(C1)C23']),
#        list(['c1ccccc1', 'C1=S=CCC1', 'c1ccccc1', 'N=c1[nH][nH]c2ccccc12']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)cnc1ccccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCNC2CCCC3C4CNCNC4N1C23']),
#        list(['c1ccccc1', 'C1=CN=C2NC=CN=C2C=C1', 'c1ccncc1', 'C1CCC2C(C1)NC1CCCNC12']),
#        list(['c1ccccc1', 'c1ccc2[nH]cnc2c1', 'O=c1[nH]c2ccccc2[nH]1', 'C1CCN2CCCNCC2C1']),
#        list(['C1CNCCN1', 'c1ccncc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccc2scnc2c1']),
#        list(['O=c1ccc2ccccc2[nH]1', 'O=c1ncncc2c1[nH]c1ccccc12']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1cnc2c(c1)nc1n2CCNCC1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'O=c1[nH]c2ccccc2c2ccccc12', 'C1=CC2=CC2=CC1']),
#        list(['c1ccccc1', 'O=c1nc[nH]c2ccccc12', 'O=c1c2ccccc2nc2ccccn12', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1', 'C1CC2CCNC2C1']),
#        list(['O=c1[nH]c2ccccc2c2nc3ccccc3nc12', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'c1cnc2c3c(ccc2c1)N1CCC2(CNCNC2)C1CC3']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)CCCN2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'O=c1ccc2ccccc2[nH]1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)CCN2', 'C1CN2CCC1C2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)CCNN2', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'O=C1Nc2ccccc21', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCNC1', 'c1ccncc1', 'c1ccccc1', 'C1CC2NCCN3C(C1)C23']),
#        list(['N=c1cncc[nH]1', 'c1ccccc1', 'c1ccc2c(c1)-c1cccc3ncnc-2c13', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1NCCCN1', 'c1ccccc1', 'O=C1CCNN1']),
#        list(['O=C1CCCCc2cccn21', 'c1cnccn1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C=c1ncn2c1nc1ccccc12']),
#        list(['c1ccccc1', 'c1ccc2c(c1)ncc1nncn12', 'c1ccccc1']),
#        list(['O=C1CN2CCCCC2N1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'N=c1cccc[nH]c1=O']),
#        list(['N=c1ccc2cccnc2[nH]1', 'c1ccccc1', 'c1ccccc1', 'c1cnccn1']),
#        list(['O=c1cccn[nH]1', 'c1ccccc1', 'c1ccccc1', 'O=c1cnc2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)nc1n2CCCN1', 'c1cncnc1', 'C1CCC2NCCNC2CC1']),
#        list(['c1ccccc1', 'c1ccc2nccnc2c1', 'O=C1COC2NCCN3C4CCCCC4N1C23']),
#        list(['c1ccccc1', 'O=C1CCCC2NC3CCCCC3C(=O)N12', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['C1CNCNC1', 'c1ccccc1', 'C1=NC2C3C(CCCC3N3CCCNC23)N1']),
#        list(['C1=NC1', 'C1C2C3NCC45C2C2C6C1C61C3C41C25', 'c1ccccc1', 'C1CNCCN1']),
#        list(['c1ccccc1', 'C1CCNCC1', 'C1CCNC2C(CC1)NC1CCCCC12']),
#        list(['C1CSCN1', 'O=C1NCCC23C1C1CC4C5C1C5C2C43', 'c1ccccc1', 'C1CNCCNC1']),
#        list(['c1ccccc1', 'O=C1CNC2CCCCC2N1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['c1ccccc1', 'O=C1NCNC2NCNC12', 'O=C1N=c2cccc3c2=[N+]1C=N3']),
#        list(['c1cc2cc[nH]c2[nH]1', 'c1ccccc1', 'O=c1cnc2ccccc2[nH]1', 'c1ccc2c(c1)CCN2']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'N=c1nc2ccc3ccccc3n2[nH]1', 'N=c1cno[nH]1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1cc2c3c(nccc3c1)CCN2', 'C1CNC2CCNC2C1']),
#        list(['c1ccccc1', 'C1CCC2C(C1)C1CCCC3CNCN2C31', 'O=c1cnc2ccccc2[nH]1']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1ccccc1', 'O=C1CCc2ccccc2N1']),
#        list(['c1ccc2c(c1)cnc1nc3ccccc3n12', 'O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['O=c1c2ccccc2[nH]c2oc3ccccc3[n+]12', 'C1CCC2C(C1)NC1CCCCC12']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1CCC2CCCCC2N1', 'c1ccccc1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['C1CCC2C(C1)NC1CCCCC12', 'O=c1c2ccccc2nc2n1-c1ccccc1-2']),
#        list(['C1CCC2CCC3CCCCC3C2NC1', 'O=C1NC2C3CC4CC3C1C42', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2c(c1)CN1CCNCC21', 'c1cncnc1', 'c1ccccc1', 'C1CCC2NCNC2C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'N=c1cccc[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)CCNC2', 'c1ccncc1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccccc1', 'c1ccccc1', 'O=c1ocnc2ccccc12']),
#        list(['c1ccccc1', 'O=c1ccnc2ccccc2n1', 'c1ccncc1', 'O=C1Nc2ccccc21']),
#        list(['O=C1CNC2CCCCN12', 'c1ccccc1', 'O=c1nc2ccccc2nc2c1C=CC1(C=C2)CN1']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1ccccc1', 'O=C1CNCC(=O)N1', 'c1cncnc1']),
#        list(['c1ccc2ncccc2c1', '[NH2+]=C1CCCC2NC12', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CCC2NCNCC2C1', 'c1ccccc1', 'O=c1[nH]c2ccccc2c2[nH]ccc12', 'N=c1cc[nH]cc1']),
#        list(['N=c1[nH][nH]c2ccccc12', 'c1ccccc1', 'O=C1CNC2CCCCC2N1', 'O=C1Nc2ccccc21']),
#        list(['O=C1NNC2CCCCC12', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'c1ccc2nonc2c1']),
#        list(['O=C1Nc2ccccc21', 'c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)Cn1c(cnc3ncnc1-3)O2', 'c1ccccc1', 'C1NNNN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1cncnc1', 'c1ccccc1']),
#        list(['C1CCC2C(C1)NC1CCCCC12', 'c1ccc2c(c1)-c1cccc3ccc[n+]-2c13', 'O=c1nncn[nH]1']),
#        list(['c1ccc2c(c1)CNc1ccccc1-2', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['C1CCC2NC3CC3CC2C1', 'c1ccccc1', 'c1cnc2ncncc2c1', 'c1ccccc1']),
#        list(['N=c1[nH][nH]c2ccccc12', 'c1ccccc1', 'c1ccc2ncccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCN1', 'c1ccccc1', 'c1ccccc1', 'C1CC2NCCC3C2N3C1']),
#        list(['O=C1Nc2cccc3c2N(CC3)c2ccccc21', 'O=C1c2ccccc2C23CC2CCN13']),
#        list(['O=C1Nc2ccccc2N2CCNCC12', 'O=C1NC2CCCCC2NC2CCC3NCCNC3CC12']),
#        list(['N=c1cc[nH][nH]1', 'O=c1c2ccccc2nc2ccccn12', 'O=C1c2ccccc2C2=CC=CC=C3N[N+]132']),
#        list(['c1ccccc1', 'N=C1CCNCC1', 'c1ccc2c(c1)ccn1nccc21', 'c1ccccc1']),
#        list(['C1=C2Nc3ccccc3C3=C2C(=CC1)OCO3', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)cnc1ccccc12', 'c1ccccc1', 'c1ccc2nccnc2c1']),
#        list(['O=C1CCNCN1', 'c1ccccc1', 'O=C1NNCC2CCCCC12', 'c1ccncc1']),
#        list(['O=C1NCC2NCNCC12', 'c1ccc2ccccc2c1', 'c1ccc2c(c1)oc1ccccc12', 'c1nn[nH]n1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CNNNC1', 'c1ccncc1', 'c1ccccc1']),
#        list(['O=C1C2CCCCC2C(=O)N2CCCCC12', 'O=c1cnc2ccccc2[nH]1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)oc1ccccc12', 'C1CCC2C(C1)C1CCCCC1N1CCNCC21']),
#        list(['N=C1NCc2ccccc21', 'c1ccccc1', 'c1ccc2c(c1)cnc1ccccc12', 'c1cc2c(cn1)N2']),
#        list(['O=c1[nH][nH]c2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1ccc2nccc-2nc1']),
#        list(['N=c1nc2[nH]ccc(=N)n2[nH]1', 'c1ccccc1', 'c1ccc2c(c1)CCN2', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2c(c1)oc1cc3nccnc3cc12', 'c1ccccc1', 'O=c1[nH]c(=O)n2n1Cc1ccccc1-2']),
#        list(['C1CCC2NCNC2C1', 'c1ccccc1', 'c1ccccc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['C1=NCCCC1', 'c1ccccc1', 'c1ccc2c(c1)ccc1ccnn12']),
#        list(['C1CCNC1', 'C1CNCCN1', 'c1cncnc1', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'N=C1CCNc2[nH]ccc(=O)c21', 'c1ccc2c(c1)OCO2', 'C1CNCCNC1']),
#        list(['O=C1NC(=O)C2C1NC1CCCCC12', 'c1ccncc1', 'c1ccc2c(c1)ccc1[n+]2CCC1', 'c1ccncc1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccncc1', 'c1ccccc1', 'c1ccc2[nH]ncc2c1', 'C1CCCC1']),
#        list(['O=c1[nH]c(=O)[n+]2c3n(c4ccccc4n13)CC2', 'O=c1cc[nH]c2ccccc12']),
#        list(['N=c1cc[nH]cc1', 'c1ccccc1', 'c1ccc2ccccc2c1', 'c1ccccc1']),
#        list(['N=c1ccccc2nc3ccccc3nc12', 'c1ccc2c(c1)[nH]c1ccccc12', 'C1NNNN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1CCC2NC3CCCC3NC2C1']),
#        list(['c1cncnc1', 'C1CNCCNC1', 'c1ccccc1', 'c1ccc2c(c1)CCN2', 'C1CNC2NCNC2N1']),
#        list(['c1ccc2c(c1)CNc1ccccc1-2', 'C1=CCc2ccccc2C=C1']),
#        list(['C1CCC2C3CCCCC3C3NNCNC3C2CC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'c1ccccc1', 'C1=NNCN1']),
#        list(['c1ccccc1', 'c1ccc2nccnc2c1', 'c1ccccc1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccccc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1']),
#        list(['c1ccn2ccnc2c1', 'c1ccccc1', 'c1ccc2c(c1)CCN2', '[NH2+]=C1CCC2NC2C1']),
#        list(['O=c1nc2ccccc2nc2ccccc12', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'O=c1ccccc2ccccc12', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1=CC2(N=C1)NC1CCCCC12', 'C1CNCCN1']),
#        list(['N=c1[nH]n2c3cccccc-3c2c2ccccc12', 'c1ccc2ncccc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCNN1', 'c1ccccc1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccccc1', 'c1ccncc1', 'O=C1CC[NH+]2CC2N1', 'c1ccccc1']),
#        list(['N=c1nc2[nH]ccc2c[nH]1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1cn[nH]c1']),
#        list(['C1CCC2NC3CCCCC3NC2C1', 'O=C1c2ccccc2C2=NC3(CCC3)CCN12']),
#        list(['c1ccc2c(c1)nc1c3ccccc3[nH]n21', 'c1ccccc1', 'c1ccc2c(c1)[NH2+]2']),
#        list(['c1ccccc1', 'c1ccncc1', 'O=C1CNC2CCCCC2N1', 'c1ccnnc1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccccc1', 'O=C1CC2CCCC[N+]2=[N+]2c3ccccc3N12']),
#        list(['c1ccc2c(c1)nc1cn[nH]n12', 'c1ccc2ocnc2c1', 'c1ccccc1', 'C1CCC2NNNC2C1']),
#        list(['N=c1cc[nH]c(=N)[nH]1', 'c1ccccc1', 'C1CCCCCC1', 'O=C1NNCC2CCCCC12']),
#        list(['O=C1Nc2ccccc21', 'c1ccncc1', 'N=c1ccc2nc3ccc4[nH]cccc4n3c(=O)c2c1']),
#        list(['c1ccc2c(c1)CNCCN2', 'c1ccncc1', 'O=c1ccnc2ccccc2n1', 'c1cc2c(cn1)N2']),
#        list(['c1ccc2nc3ccccc3nc2c1', 'C1CNCCNC1', 'c1cnoc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'C1CNNN1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'c1ccccc1', 'c1ccccc1', 'O=C1CCNN1']),
#        list(['N=c1[nH]c2ccccc2[nH]ccs1', 'c1ccc2c(c1)[nH]c1ccccc12', '[NH2+]=C1CCCC2NC12']),
#        list(['C1CNCCN1', 'C1CCC2C(C1)OC1NCCC12', 'c1ccncc1', 'c1cnc2c(n1)CCNCC2']),
#        list(['C1CCC2C(C1)CN1CN21', 'c1ccccc1', 'c1ccccc1', 'N=C1CCC2NC2C1']),
#        list(['N=c1ncc2nonc2[nH]1', 'c1ccccc1', 'O=c1occc2ccccc12', 'c1ccc2c(c1)[NH2+]2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1c[nH]cn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1CCC2NCCCC2NC1']),
#        list(['c1ccc2cnncc2c1', 'c1ccccc1', 'O=C1C2CCCCC2NC2Cc3[nH]ccc3CC12']),
#        list(['c1ccc2c(c1)C1CC3C4C[NH+]3CC1C24', 'C1CCC2CCCCC2CC1', 'N=c1cn[nH][nH]1']),
#        list(['N=c1[nH]c(=N)c2ccccc2[nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['C1=C[N+]2(CC1)CCc1nc3ccccc3nc12', 'c1ccc2c(c1)-c1cccc3cccc-2c13']),
#        list(['C=C1CCC2C(=NNC3CCCCC32)C1', 'c1ccc2c(c1)[NH2+]c1ccccc1-2']),
#        list(['N=C1CCN2CNC3CCC4CCCCC4C3C2N1', 'c1ccc2c(c1)[nH]c1ccccc12', 'c1ccncc1']),
#        list(['c1ccccc1', 'C1CC2NCCN3C(C1)C23', 'c1ccccc1', 'c1ccncc1']),
#        list(['O=C1Nc2ccccc21', 'c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)c1ccccc1n1cnnc21']),
#        list(['c1ccc2[nH]cnc2c1', 'O=C1Nc2ccccc21', 'c1ccccc1', 'C1CCC2NCNC2C1']),
#        list(['c1ccc2c(c1)oc1ccccc12', 'c1ccncc1', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'O=c1cnc2ccccc2[nH]1', 'c1ccccc1', 'C1CCC2NCCNC2C1']),
#        list(['O=c1[nH][nH]c2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1ccoc1', 'c1ccncc1']),
#        list(['O=C1c2ccccc2-c2nc3ccccc3n21', 'c1ccc2ncccc2c1', 'c1ccnnc1', 'C1COCCN1']),
#        list(['C1CCC2C(C1)CNC1C3CCCCC3N21', 'O=C1c2ccccc2C2CNCCN12', 'c1cc[nH]c1']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'c1ccccc1', 'C1CCC2NCNCC2C1', 'N=c1nn[nH][nH]1']),
#        list(['O=c1[nH]c2ccccc2c(=O)c2ncccc12', 'c1ccccc1', 'c1ccc2c(c1)N2']),
#        list(['c1cc2cccc3nc4nccc(c1)c4=c23', 'C1CCC2C(C1)NC1CCCC3NNC2C31']),
#        list(['c1ccn2ccnc2c1', 'c1ccc2c(c1)cnc1ccccc12', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1cc[nH]cn1', 'O=C1NC(=O)N1', 'c1ccccc1']),
#        list(['c1ccc2cnncc2c1', 'c1ccccc1', 'C1CCC2NCCC2C1', 'N=c1cc[nH]cc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CNCCN1', 'c1ccncc1', 'C1CCCNCC1']),
#        list(['N=c1ccc2c3c4c([nH]c(=N)[nH]c4nc2c1)NCC3', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccncc1', 'c1ccccc1', 'C1CCC2C(C1)NC1CCCCC12']),
#        list(['O=C1c2ccccc2NN=C2CC3CCC3N12', 'O=C1NC(=O)c2ccccc21', 'c1ccccc1']),
#        list(['N=c1cno[nH]1', 'O=C1C=Nc2cccc3cccc1c23', 'c1ccc2c(c1)[nH]c1ccccc12']),
#        list(['N=c1ncc2ccccc2[nH]1', 'c1ccncc1', 'c1ccc2c(c1)[nH]c1[n+]2C12CCCNC2', 'c1ccccc1']),
#        list(['c1ccnnc1', 'c1ccccc1', 'C1CCC2NC3CCCCC3NC2C1']),
#        list(['O=C1NCCC2CCCCC2N1', 'c1ccccc1', 'c1ccc2c(c1)N2', 'c1ccncc1']),
#        list(['c1ccc2nnccc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)N2']),
#        list(['C1CN2[NH+]=C2CN1', 'c1ccccc1', 'C1=Cc2ccccc2N2C(=C1)[N+]21CCNCC1']),
#        list(['O=C1CCCC2CCCCC2O1', 'C1CCC2C(C1)NC1OC3CCCCC3N12']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccc2c(c1)CCCN2', 'N=c1cc2[n+](c[nH]1)N2']),
#        list(['c1ccc2c(c1)Nc1ccccc1-c1ccccc1-2', 'C1CCC2C(C1)OCC1NCCCN12']),
#        list(['c1ccccc1', 'O=C1NNC2CCCCC12', 'c1ccccc1', 'O=c1cnc2ccccc2[nH]1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccccc1', 'N=c1cc[nH]c(=N)[nH]1']),
#        list(['O=C1Nc2ccccc21', 'O=C1CNC2CCCCC2N1', 'c1ccccc1', 'c1ccc2c(c1)nc1[nH]ncn12']),
#        list(['c1ccc2c(c1)[NH2+]2', 'O=C1N=CNC23CC4CCC12C31CC41', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CCC2NC3NNC4(CCN4)N3CC2C1', 'O=c1[nH]c2ccccc2[nH]1', 'c1ccc2c(c1)CN2']),
#        list(['c1ccc2c(c1)nc1ccccn12', 'C1=CNCCC1', 'c1ccccc1', 'C1CCC2NCNC2C1']),
#        list(['c1ccc2c(c1)CCN2', 'c1ccccc1', 'c1ccc2[nH]cnc2c1', 'N=c1nccc[nH]1']),
#        list(['c1ccc2c(c1)CCNc1ccccc1-2', 'C1CCC2C(C1)NC1CCCC3CNCCN3C12']),
#        list(['O=C1NC2CCCCC2N1', 'c1ccccc1', 'c1ccc2c(c1)[nH]c1sccc12', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2ccccc2c1', 'N=c1nccc[nH]1']),
#        list(['c1cnc2ncnn2c1', 'c1ccccc1', 'c1ccc2c(c1)CN1CCNCC21', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'c1ccc2c(c1)CNc1ccccc1-2', 'C1=NONC1']),
#        list(['c1ccccc1', 'c1cnc2c(c1)CCCN2', 'N=c1nc2n([nH]1)c1cccc3c4ccccc4n2c31']),
#        list(['N=c1ccnc[nH]1', 'c1ccccc1', 'c1cnoc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCCCN1', 'O=C1Nc2ccccc21']),
#        list(['O=C1CCNCN1', 'c1ccccc1', 'C1CCC2NCCNC2C1', 'O=C1Nc2ccccc21']),
#        list(['N=c1c2ccccc2[nH]c2ccccc12', 'C1CCC2NCCNC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=C1NCc2cccc3c2N1c1ccccc1O3', 'c1cnccn1']),
#        list(['O=C1Nc2cccc3cccc(c23)N1', 'N=c1nc2sc3[nH]c4ccccc4c3n2[nH]1']),
#        list(['N=c1cn[nH][nH]1', 'c1ccc2c3c(cnc2c1)CCC3', 'c1ccccc1', 'N=c1[nH][nH]c2ccccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'N=c1[nH]ccs1', 'c1ccncc1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccc2nccnc2c1', 'c1ccncc1', 'O=[n+]1c2ccccc21']),
#        list(['N=C1CCC2NC2C1', 'c1ccncc1', 'O=C1C2NNC3CCCCC3N12', 'c1ccncc1']),
#        list(['c1ccc2c(c1)NCCc1nccnc1-2', 'c1ccccc1', 'C1CCC2NCNCC2C1']),
#        list(['C1CCC2C(C1)CNC1C3CCCCC3N21', 'C1CNCCNC1', 'O=c1cnc2ccccc2[nH]1']),
#        list(['c1ccc2c(c1)nn1cccnc21', 'C=C1C(=O)N2C3CCCC(C32)N2CCCC12']),
#        list(['C1=Cc2ccccc2NC1', 'c1ccccc1', 'O=C1CCNC2CN1c1ccccc12', 'c1ccncc1']),
#        list(['c1ccc2c3n(cc2c1)CCNC3', 'O=C1NC(=O)C2=CCC=C12', 'O=C1Nc2ccccc21']),
#        list(['O=C1Nc2ccccc21', 'c1ccccc1', 'c1ccccc1', 'C1CCC2CNCN3C2N3CC1']),
#        list(['c1ccc2c(c1)CNCCO2', 'O=C1NC(=O)c2ncccc21', 'O=C1NC2CCCCC2N1']),
#        list(['C1=NC2CCCC3C4CCCCC4CC(C1)C23', 'c1ccccc1', 'C1CNCCN1']),
#        list(['c1ccc2nccnc2c1', 'c1ccccc1', 'O=C1NCCNCc2ccccc21']),
#        list(['c1ccncc1', 'N=c1[nH]c2ccccc2[nH]1', 'C1CCC2C(C1)CC1CCCN12']),
#        list(['N=C1NNN2NCC12', 'c1ccccc1', 'c1ccccc1', 'C1CCC2C(C1)NC1C3C(CCCC23)NC2NCNN21']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CCC2CCCC3C4CCCC4N1C23']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1CCC2C(C1)NC[N+]1=[NH+]C21']),
#        list(['c1ccncc1', 'C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['N=c1[nH][nH]c2ncncc12', 'c1ccccc1', 'c1ccccc1', 'c1nnn[nH]1', 'c1ccccc1']),
#        list(['O=c1[nH][nH]c2ccccc12', 'c1ccccc1', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['N=c1ccc2c3c4c([nH]c(=N)[nH]c4nc2c1)NCCC3', 'C1CNCCN1', 'c1ccncc1', 'C1=NCN1']),
#        list(['N=c1ccc2ccccc2[nH]1', 'c1ccccn#1', 'c1ccncc1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)oc1ccccc12', 'C1CCC2C(C1)NN1C3CCCCC3NC21']),
#        list(['c1ccccc1', 'c1ccc2[nH]ccc2c1', 'C1CCC2C(C1)NC1NNNN12', 'c1ccncc1']),
#        list(['O=c1cccc[nH]1', 'c1ccccc1', 'C1CCC2C(C1)CC1OC3CCCCC3N12']),
#        list(['C1CCC2NNNCC2C1', 'c1ccccc1', 'c1ccncc1', 'O=S1(=O)Nc2ccccc21']),
#        list(['C1CN2NCC2CN1', 'c1ccccc1', 'O=c1ccc2cccc3c2n1CC3', 'O=c1cc[nH][nH]1']),
#        list(['O=c1nc2ccccc2nc2ccccc12', 'c1ccccc1', 'c1ccccc1', 'C1CCNCC1']),
#        list(['c1ccncc1', 'C1CNCCN1', 'c1ccncc1', 'O=C1NCNC2CCCCC12', 'c1ccccc1']),
#        list(['c1ccc2c(c1)NC1CC[NH+]3C(C1)C23', 'c1ccccc1', 'N=c1c2ccccc2[nH]c2ccccc12']),
#        list(['C1CCC2C3CCCCC3N3NNNC3C2CC1', 'c1ccccc1', 'O=c1cnc2ccccc2[nH]1']),
#        list(['N=c1nc2[nH]ccc2c[nH]1', 'c1ccccc1', 'c1ccc2ocnc2c1', 'N=c1nc2ccccc2c[nH]1']),
#        list(['c1ccc2ccccc2c1', 'c1ccc2[nH]ccc2c1', 'c1ccccc1', 'N=c1nn[nH][nH]1']),
#        list(['c1ccccc1', 'C1CNCCNC1', 'c1ccncc1', 'c1ccc2ncccc2c1', 'c1ccncc1']),
#        list(['C1CNCCN1', 'c1ccc2ccccc2c1', 'c1ccccc1', 'c1ccc2nccnc2c1']),
#        list(['N=c1cc2c3c(cccc3[nH]1)C1C3CC3CCN1C2=O', 'c1ccccc1', 'c1cnc2cccnc2c1']),
#        list(['N=c1ncc2nc(=O)c3ccccc3nc2[nH]1', 'C1CNCCN1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccc2c(c1)CCN2', 'N=c1cc[nH]cn1', 'C1CCC2NC3CCCCC3CCC2C1']),
#        list(['c1ccc2c(c1)[nH]c1nccnc12', 'c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=C1NCNC2CCCCC12', 'c1ccc2[nH]ccc2c1', 'c1ccsc1']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'c1ccccc1', 'c1cncnc1', 'O=C1Nc2cccnc21']),
#        list(['c1ccc2c(c1)c1cccc3c1n2CCC3', 'c1ccc2c(c1)CNc1ccccc1-2']),
#        list(['c1ccc2[nH]cnc2c1', 'c1ccc2[nH]ccc2c1', 'c1ccccc1', 'C1CCC2NC2C1']),
#        list(['C1CNCCN1', 'c1ccc2ncccc2c1', 'c1ccccc1', 'O=C1CCCC(=O)N1', 'N=c1cccc[nH]1']),
#        list(['N=C1NC2NC3CCCCC3NC3CCCC1C32', 'c1ccccc1', 'c1ccc2c(c1)N2']),
#        list(['c1ccc2c(c1)CCCN2', 'O=C1NC2NCNN2C2NC3CCCCC3CC12', 'c1ccccc1']),
#        list(['N=c1nc2ccccc2n[nH]1', 'c1ccccc1', 'c1ccc2c(c1)CCN2', 'c1ccccc1']),
#        list(['C1CNCCNC1', 'c1ccccc1', 'O=c1[nH]c2ccccc2c2ccccc12', 'c1ccncc1']),
#        list(['C1CCC2NCNC2C1', 'O=c1ccc2ccccc2[nH]1', 'c1cnc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=c1ocnc2ccccc12', 'O=C1CNC2CCCCC2N1']),
#        list(['c1ccccc1', 'O=C1N=CN=CCN1', 'c1ccc2c(c1)[nH]c1ccccc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]ccc2c1']),
#        list(['O=c1[nH]c2ccccc2s1', 'c1ccc2[nH]ccc2c1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1o[nH]c2ccccc12', 'c1ccccc1', 'c1ccccc1', 'C1CNNC1']),
#        list(['C1=CC=C2N=Cc3ccsc3N2C=C1', 'O=C1CNC2CCCCC2N1', 'c1ccc2[nH]ccc2c1']),
#        list(['c1ccc2nccnc2c1', 'c1ccccc1', 'c1ccccc1', 'C1CCC2NCCC2C1']),
#        list(['c1ccc2c(c1)[nH]cc[nH]c1ccccc12', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2nc3cc4c(cc3nc2c1)oc1ccccc14']),
#        list(['O=c1[nH]cc[nH]1', 'c1ccccc1', 'c1ccncc1', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'C1CCC2C(C1)NC1CCCCC12', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['c1cn[nH]c1', 'c1ccccc1', 'c1ccccc1', 'O=c1cnc2ccccc2[nH]1']),
#        list(['O=C1CCNC(=O)N1', 'c1ccccc1', 'c1ccc2c(c1)O2', 'C1CNCCN1', 'c1cncnc1']),
#        list(['c1ccc2c(c1)ccc1ccccc12', '[NH2+]=C1CCCC2C3N1CC1CCCCC1N23']),
#        list(['C1CCC2C(C1)CNC1CCCCC12', 'c1ccccc1', 'O=c1cc[nH]c2ccccc12']),
#        list(['c1ccccc1', 'O=c1[nH]c2ccccc2[n+](=O)c2ncccc12', 'O=C1Nc2ccccc21']),
#        list(['C1CCC1', 'c1ccccc1', 'O=C1CCNCCN1', 'c1ccc2nc3ccccc3nc2c1']),
#        list(['c1ccc2ncccc2c1', 'c1ccc2c(c1)[NH2+]2', 'c1ccc2c(c1)NCCN2']),
#        list(['O=C1NC2CCCCC2N1', 'C1CCCNCC1', 'c1ccc2ncccc2c1', 'c1ccncc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'O=c1[nH]c(=O)c2ccccc2[nH]1', 'O=C1CNC2CCCCC2N1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1NC12CCCCC2', 'C1CCNC1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)nc1ccccn12', 'C1CNCCN1', 'c1ccccc1']),
#        list(['N=c1nc[nH]c(=N)[nH]1', 'c1ccccc1', 'c1ccncc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['N=C1NC(=O)c2ccccc21', 'c1ccccc1', 'c1ccccc1', 'C1CCC2NC2C1']),
#        list(['O=C1CC=N1', 'N=C1CC23CCC4C5=CC6CC1C52C643', 'C1CC2CCCC3NCC(C1)C23']),
#        list(['O=C1c2ccccc2Cn2c1nc1ccccc12', 'c1ccccc1', '[NH2+]=C1CCCC2NC12']),
#        list(['C1CNCCN1', 'O=c1cc[nH]c2ccccc12', 'c1ccccc1', 'C1CCC2NCNC2C1']),
#        list(['c1ccccc1', 'C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'N=c1cc[nH]c(=N)[nH]1']),
#        list(['O=c1cnc2ccccc2o1', 'c1ccccc1', 'O=C1CNc2ccccc2N1']),
#        list(['c1ccccc1', 'c1ccncc1', 'c1ccccc1', 'O=c1[nH]cnc2ccccc12']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'C1CCC2NCCCC2C1', 'c1ccccc1']),
#        list(['O=C1CCCN1', 'O=c1c2ccccc2[nH]c2nccn12', 'c1ccccc1']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccccc1', 'C1CN2CNCCC2CN1', 'c1ccc2scnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1Nc2ccccc2O[N+](=O)c2ccccc21']),
#        list(['c1ccccc1', 'O=C1NC2CCCC3C4CCCCC4N1C23', 'O=C1Nc2ccccc21']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'C1CCC2C(C1)NC1CCCCC12']),
#        list(['C1=NCCNC1', 'O=c1nc[nH]c2c1CCCC2', 'c1ccccc1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1=NCC2c3ccnnc3-c3cccc(c32)N1', 'N=c1[nH]c2ccccc2n2cnnc12']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2occc2c1', 'N=c1cccc[nH]1']),
#        list(['[NH2+]=C1CNC2NCCCCC2C1', 'c1ccccc1', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2c(c1)N2', 'c1ccccc1', 'C1CCC2C(C1)CCCC21C2NCCCN21']),
#        list(['C1CCNCC1', 'O=C1CCNC2CCCCC12', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['C=C1N=CC=N1', 'N=c1cccc[nH]1', 'c1ccccc1', 'N=c1nccc[nH]1', 'c1ccccc1']),
#        list(['c1ccncc1', 'c1ccccc1', 'c1ccncc1', 'O=C1Nc2ccccc21']),
#        list(['N=c1cccc[nH]1', 'c1ccccc1', 'c1ccccc1', 'O=c1cn[nH]c2ccccc12']),
#        list(['c1ccc2ccccc2c1', 'O=C1NCNC2NC3C(CCC4CCCCC43)CC12', 'N=c1cccc[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'N=c1nc2[nH]ccn2[nH]1']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccncc1']),
#        list(['O=C1NCC2CC1CCN2', 'c1ccncc1', 'C1C[NH+]2CC2N1', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['c1ccc2c(c1)cnc1ccccc12', 'c1ccccc1', 'O=C1CNC2CCCCC2N1']),
#        list(['c1ccc2[nH]cnc2c1', 'O=C1NC(=O)c2ccccc21', 'c1ccncc1', '[NH2+]=C1CCCC2NC12']),
#        list(['O=c1cncn[nH]1', 'c1ccccc1', 'c1ccncc1', 'c1ccc2ccccc2c1']),
#        list(['O=C1CCN1', 'c1ccccc1', 'c1ccc2c(c1)OCO2', 'O=c1nc2ccccc2nc2ccccc12']),
#        list(['N=c1nc2n([nH]1)CCC(=O)N2', 'c1ccccc1', 'c1ccccc1', 'c1ccc2nccnc2c1']),
#        list(['C1CCC2NC3NCCCC3NC2C1', 'c1ccccc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['O=c1c2ccccc2c#nc2ccccc12', 'c1ccc2c(c1)O2', 'O=C1Nc2ccccc21']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccc2c(c1)[nH]c1ccccc12', 'N=c1cc[nH]cc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)CCN2', 'c1ccccc1', 'c1ccc2nccnc2c1']),
#        list(['C=c1cc2c3c(ccn3c1=O)CCC2', 'c1ccccc1', 'O=C1CCc2cncnc2N1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1NC(=O)c2ncccc21', 'O=C1Nc2ccccc21']),
#        list(['C1CCC2CNC3CCCC(C1)C23', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1', 'c1ccccc1']),
#        list(['O=C1CCNC2CN12', 'c1ccccc1', 'N=C1CCCCC1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCC2C(C1)NC1N3CCNC3C3CCCCC3N21', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1ccccc1', 'C1#[N+]C12CCCCC2']),
#        list(['c1ccccc1', 'C1CCNC1', 'c1ccccc1', 'C1C[NH+]2CC2N1', 'c1ccncc1']),
#        list(['O=C1NNC2CCCCC12', 'c1ccccc1', 'N=c1[nH]c2ccccc2c2ccccc12']),
#        list(['C1CCC2NCNC2C1', 'c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['C1CCC2NCCC2C1', 'c1ccc2ncncc2c1', 'O=c1cc[nH][nH]1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1']),
#        list(['c1ccc2[nH][nH]cc[nH]c2c1', 'C=C=C1CCCC2NC3CCC(=O)C4CCC1C2C34']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'c1ccccc1', 'O=C1CCNC2CCCNC12']),
#        list(['N=c1[nH]nc2[nH]c3ccccc3n12', 'c1ccccc1', 'c1ccc2c(c1)C1CNCCCN21', 'c1ccncc1']),
#        list(['c1cscn1', 'C1CNCCN1', 'c1ccncc1', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['N=c1cccc[nH]1', 'c1ccccc1', 'O=C1NNC2C3C(CCCC13)OC1CCC3CCCCC3C12']),
#        list(['c1ccc2c(c1)-c1cccc3cccc-2c13', 'c1ccccc1', 'O=C1NC(=O)N2CCC1CC2=O']),
#        list(['N=c1nc2n([nH]1)NC(=O)CC2', 'c1ccccc1', 'c1ccc2ccccc2c1', 'c1cnccn1']),
#        list(['c1ccc2ccccc2c1', 'C1CCC2NCNC2C1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2[nH]ccc2c1', 'C1CNCCN1', 'O=C1CNC2CCCCC2N1']),
#        list(['O=c1nc[nH]c2c1Cc1ccccc1O2', 'c1ccc2c(c1)[nH]c1ccccc12', 'c1ccccc1']),
#        list(['c1ccncc1', 'O=c1[nH]c2ccccc2o1', 'c1ccccc1', 'C1CCN2NCCC2NC1']),
#        list(['C=C1c2ccccc2C23C4C5OC5C25C1C5C43', 'c1ccccc1', 'N=c1nc[nH]cn1']),
#        list(['c1ccccc1', 'C1CCC2NC3CNCCCC3NC2C1', 'c1ccncc1']),
#        list(['c1ccc2[nH]ncc2c1', 'c1ccccc1', 'c1ccncc1', 'c1ccc2c(c1)N2', 'C1=NN=N1']),
#        list(['c1ccc2nccnc2c1', 'c1ccncc1', 'c1ccc2c(c1)nc1c3ccccc3[nH]n21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2nccnc2c1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1oc2ccccc2c2ccccc12', 'c1cncnc1']),
#        list(['c1ccccc1', 'O=c1cnc2ccccc2[nH]1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CNCCNC1', 'c1ccncc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['c1ccc2ncccc2c1', 'c1ccccc1', 'N=c1nc2ccccc2c2n1N2', 'c1cscn1']),
#        list(['c1ccc2ncncc2c1', 'c1ccccc1', 'c1cnccn1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1cnc2[nH]cnc2c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1COCC[NH2+]1', 'c1cscn1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1=CN2c3cccc(c32)N=C1']),
#        list(['N=c1cccc[nH]1', 'O=C1CNC2CCCCC2N1', 'c1ccccc1', 'O=C1NNC2CCCCC12']),
#        list(['N=c1ccc2nc3ccccc3nc2[nH]1', 'O=C1c2ccccc2C2CCNCCN12', 'C1NCN2NC2N1']),
#        list(['c1ccncc1', 'c1ccccc1', 'O=c1cc2ccccc2c2[nH]c3ccccc3c(=O)n12']),
#        list(['c1ccc2c(c1)[nH]c1ccccc12', 'c1ccccc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccncc1', 'c1ccccc1', 'C1=Nc2ccccc2N=CC1']),
#        list(['c1cc2c(c3c1N3)[NH2+]2', 'c1ccccc1', 'C1CNNC1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1ccoc1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=c1cccn[nH]1']),
#        list(['c1ccc2[nH]cnc2c1', 'c1ccccc1', 'N=c1cc[nH]c(=N)[nH]1']),
#        list(['c1ccc2ncncc2c1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1', 'O=C1Nc2ccccc21']),
#        list(['N=c1ccc2nc3c(nc2c1)[nH]cc1ccccc13', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['O=C1Nc2ccccc2C2CNCCN12', 'c1ccccc1', 'c1ccccc1', 'O=c1[nH]c2ccccc2[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)[nH]c1ccccc12']),
#        list(['c1ccc2c(c1)Nc1ccccc1S2', 'O=C1CCNC2C3CCCCC3NN12']),
#        list(['c1ccc2nc3cc4[s+]c5cccnn5c4cc3cc2c1', 'C1CCC2C(C1)NC1CCCCC12']),
#        list(['O=C1NC(=O)c2cccc3cccc1c23', 'c1ccccc1', '[NH2+]=C1CCCCNC1']),
#        list(['c1ccccc1', 'O=c1cnc2ccccc2[nH]1', 'c1ccc2c(c1)cnc1ccccc12']),
#        list(['c1ccc2ncncc2c1', 'c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1']),
#        list(['O=C1Nc2ccccc21', 'O=C1Nc2ccccc21', 'c1ccccc1', 'C1CNCCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccc2c(c1)NC1CC21', 'c1ccccc1', 'c1ccc2[nH]ncc2c1']),
#        list(['c1ccc2c3n(cc2c1)CCCC3', 'c1ccc2c3n(cc2c1)CCNC3', 'c1ccncc1']),
#        list(['c1ccc2[nH]ccc2c1', 'N=C1CC(=O)N1', 'c1ccccc1', 'c1ccccc1', 'C1CNCCN1']),
#        list(['C1CCC2NNNC2C1', 'C1CCCCCC1', 'O=c1[nH]c2ccccc2c2ccccc12', 'c1cncnc1']),
#        list(['N=c1cc[nH]cn1', 'O=c1ccc2ccccc2[nH]1', 'c1ccccc1', 'C1#[N+]C12CCCCC2']),
#        list(['c1ccccc1', 'c1ccc2nccnc2c1', 'C1NC2NNCN2N1', 'c1ccccc1']),
#        list(['C1CN2CC2CN1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2nccnc2c1']),
#        list(['c1ccccc1', 'C1CC2CCCC3CCCC(C1)C23', 'N=c1cno[nH]1', 'C1CNCCN1']),
#        list(['c1ccc2nc3occc3cc2c1', 'c1ccncc1', 'C1CNCCN1', 'c1ccncc1']),
#        list(['O=C1CNC2CCCCC2N1', 'C1CCCNCC1', 'c1ccccc1', 'C1CNCN1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=S1(=O)c2ccccc2N=C2C=CCN21', 'N=c1nc[nH][nH]1', 'c1cnccn1']),
#        list(['N=c1[nH]n2c3ccccc3nc2c2ccccc12', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2nccnc2c1', 'C1CNC2NCNC2C1']),
#        list(['C1=CCC23C4=C(CCNC4)C4CCC2(C1)C3C4', 'C1CCc2c([nH]c3c2CCCC3)C1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2c3n(cc2c1)CCNC3', 'c1ccc2c(c1)NCCO2', 'C1CCC2NC2C1']),
#        list(['c1ccccc1', 'C1CCC2C(C1)CC1NC3NCCCN3C12', 'c1ccccc1']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'c1ccccc1', 'C1CC2CNC(CN1)C2']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2ncccc2c1', 'C1=[NH+]C2NN2CN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1cn[nH]n1', 'O=C1Nc2ccccc21']),
#        list(['N=c1ccnc[nH]1', 'C1CCC2CCCCC2CC1', 'O=c1[nH]c2ccccc2[n+](=O)c2ncccc12']),
#        list(['C=c1[nH]c2c3ccccc3nc3cccc(o1)c32', 'c1ccccc1', 'C1CCNC1', 'c1cncnc1']),
#        list(['C1CCNCC1', 'c1ccccc1', 'N=C1CCO1', 'O=c1[nH]c2ccccc2[nH]1', 'O=C1Nc2ccccc21']),
#        list(['N=c1cncc[nH]1', 'c1ccc2ccccc2c1', 'N=c1ccc2nc3c4c(=O)cccc4c4n[nH][nH]n4c3nc2c1']),
#        list(['c1ccccc1', 'N=C1OC2CC3C4=CCC=[N+]4c4ccccc4C3[N+]3(C2)C(=O)C13']),
#        list(['c1ccc2[nH]cnc2c1', 'c1ccccc1', 'C1CCC2NNNCC2C1', 'O=C1Nc2ccccc21']),
#        list(['C1CCC2C(C1)NC1CCCCC1C1CCCCC21', 'N=c1[nH]c2cccc3c2n1Cc1ccccc1-3']),
#        list(['C1CCC2C(C1)NC1CCCC3NNC2C31', 'c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['c1ccc2nccnc2c1', '[NH2+]=C1CCCCC1=O', 'O=C1CN2C3CCCC(N1)C32']),
#        list(['c1ccc2[nH]cnc2c1', 'c1ccccc1', 'C1CNC2C(C1)NC1CC3C(CC12)OC1CCCCC13']),
#        list(['C1CCC2C(C1)NCN1C3C2CNCN31', 'c1ccccc1', 'c1ccc2c(c1)cnc1ccccc12']),
#        list(['C=C1CCC2C(CNC3CCCCC32)C1', 'c1ccccc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['N=c1[nH]c2ccccc2c2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1cncnc1']),
#        list(['c1ccc2c(c1)nc1ccccn12', 'C1CCC2C(C1)NC1CCCC3NCCC2C31']),
#        list(['C1CNCCN1', 'c1ccoc1', 'O=C1NS(=O)(=O)c2ccccc21', 'c1ccc2nccnc2c1']),
#        list(['c1ccccc1', 'O=c1cc[nH]cn1', 'c1ccccc1', 'O=c1cccc[nH]1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccncc1', 'c1ccccc1']),
#        list(['O=C1N=c2ccccc2=NC1=O', 'C1CCNCC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccc2ncccc2c1', 'c1ccncc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'C1CCC2C(C1)NC1CCCC3CNCCN2C31', 'c1ccccc1']),
#        list(['O=c1[nH]ncc2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]cnc2c1']),
#        list(['O=c1[nH]ncc2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1ccc2[nH]ccc2c1']),
#        list(['O=C1N=c2ccccc2=N1', 'c1ccccc1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccc2ncccc2c1', 'C1CNCCN1']),
#        list(['c1ccccc1', 'c1ccc2nccnc2c1', 'c1ccncc1', 'C1CCC2NCCC2C1']),
#        list(['O=C1CNC2CCCCC2N1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'O=c1c2ccccc2nc2ccccn12', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'C=c1ccc2cc3n(c2c1)C=CC=NC=3', '[NH2+]=C1CCCCNC1']),
#        list(['c1ccccc1', 'O=C1NNCN2C1NC1CCCCC12', 'c1ccccc1']),
#        list(['O=C1Nc2ccccc21', 'c1ccccc1', 'S=c1[nH]c2ccccc2[nH]1', 'c1ccccc1']),
#        list(['N=c1[nH]c2c3ccccc3cn2c2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1cn[nH]c1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['O=c1[nH]c2ccccc2[nH]1', 'c1ccccc1', 'C1CCC2C(C1)NC1CCCCC12']),
#        list(['C1CCNCC1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1CNCCN1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccc2c(c1)[NH2+]2']),
#        list(['C=c1ccc2c(c1)Oc1ccccc1N=2', 'c1ccccc1', 'C1CNC2CCCCC2NC1']),
#        list(['C1=NC2C3CCCCC3C3CCCC(C1)C32', 'c1ccc2c(c1)[nH]c1ccccc12', 'c1cnccn1']),
#        list(['O=C1CCCNC(=O)N1', 'c1ccccc1', 'c1ccncc1', 'C1CNCCN1', 'c1cncnc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'C1NNNN1']),
#        list(['c1ccccc1', 'c1cn[nH]c1', 'c1ccncc1', 'c1ccccc1', 'O=C1CC2(CNC3CCCNC3C2)C(=O)N1']),
#        list(['c1ccc2c(c1)Sc1cccc3c1[NH+]23', 'c1ccc2c(c1)C1CNCCN21', 'c1ccncc1']),
#        list(['C1CNCCN1', 'c1ccc2ccccc2c1', 'c1ccccc1', 'N=c1cc[nH]c(=N)[nH]1']),
#        list(['O=c1cccc2[nH]c3ccccc3n12', 'c1ccccc1', 'c1ccc2c(c1)CO2']),
#        list(['c1cnc2ncnn2c1', 'c1ccccc1', 'c1ccccc1', 'O=C1CCc2ccccc2N1']),
#        list(['O=C1NC2CCCCC2NC2NCCCCC12', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['c1ccc2c(c1)CNCCN2', 'c1ccncc1', 'C1CCC2C(C1)NN1C3CCCCC3NC21']),
#        list(['N=c1cno[nH]1', 'C1CCC2NCC3CCCC(C1)C32', 'O=c1c2ccccc2[nH]c2ncnn12']),
#        list(['N=c1[nH][nH]c(=N)[nH]1', 'C1CCC2NCNC2C1', 'c1ccccc1', 'O=C1CNc2ccccc2N1']),
#        list(['N=c1nc2ncncc2n[nH]1', 'c1ccccc1', 'c1ccc2c(c1)CCN2', 'c1ccccc1']),
#        list(['C1CNCCN1', 'c1ccccc1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1CNC2CCCCC2N1']),
#        list(['c1ccccc1', 'C1CCC2NCCC2C1', 'c1ccccc1', 'c1ccncc1']),
#        list(['c1ccc2c(c1)ncn1c3ncccc3nc21', 'c1ccccc1', 'O=C1Nc2ccccc21']),
#        list(['N=c1cc[nH][nH]1', 'c1ccccc1', 'C1CCC2C(C1)NC1C3CCCCC3N21']),
#        list(['C1=[N+]2C34CCCCC3C3CCCCC3[N+]124', 'c1ccccc1', 'c1ccc2c(c1)[NH2+]2']),
#        list(['O=C1Nc2ccccc2C(=O)N2C1CCC1CC12', 'c1ccccc1', 'c1ccccc1']),
#        list(['N=c1cc[nH][nH]1', 'c1ccccc1', 'c1ccccc1', 'c1nnn[nH]1', 'c1ccccc1']),
#        list(['C1CCC2NC2C1', 'c1ccccc1', 'O=C1NC(=O)c2ccccc21', 'c1ccncc1']),
#        list(['c1ccccc1', 'c1ccccc1', 'c1ccccc1', 'O=c1[nH]cnc2ccccc12']),
#        list(['c1ccccc1', 'c1ccoc1', 'c1ccc2ocnc2c1', 'c1ccccc1']),
#        list(['N=c1[nH]cnc2ccccc12', 'c1ccccc1', 'c1ccccc1', 'c1cnc2c(c1)nc1n2CNC1']),
#        list(['C1CNC2NCNC2C1', 'c1ccccc1', 'c1ccc2c(c1)C1CNCCN21', 'c1cncnc1']),
#        list(['C1=Nc2ccccc2C=Nc2ccccc21', 'c1ccncc1', 'O=C1Nc2ccccc21']),
#        list(['c1ccccc1', 'c1ccccc1', 'O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O', 'c1cscn1']),
#        list(['c1ccccc1', 'c1cc2c3c(ccnc3c1)CN2', 'c1ccncc1', 'c1ncncn1']),
#        list(['c1cnc2ncnn2c1', 'c1ccccc1', 'C1CC2C3C1C1CC4C3C43C1C23', 'c1ccccc1']),
#        list(['c1cncnc1', 'c1ccccc1', 'c1ccccc1', 'N=C1C=CC2N=C2C1', 'C1CCNC1'])],
#       dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                              SMILES  Count
# 0                          c1ccccc1    671
# 3                          c1ccncc1    114
# 24                         C1CNCCN1     62
# 15                   O=C1Nc2ccccc21     43
# 25                         c1cncnc1     26
# ..                              ...    ...
# 200                 O=C1NCC2NCNCC12      1
# 197  C1=C2Nc3ccccc3C3=C2C(=CC1)OCO3      1
# 196           c1ccc2c(c1)ccn1nccc21      1
# 195                      N=C1CCNCC1      1
# 212    O=c1[nH]c(=O)n2n1Cc1ccccc1-2      1
#
# [511 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup()
res = df.mol.apply(ring_system_lookup.process_mol)

# %%
res
# Out:
# 0      [(c1ccccc1, 2568039), (O=C1NC(=O)c2ccccc21, 10...
# 1      [(N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, 0),...
# 2      [(N=c1cncc[nH]1, 2), (O=C1c2ccccc2C2CNCCN12, 1...
# 3      [(c1ccccc1, 2568039), (c1ccncc1, 275595), (C1C...
# 4      [(c1ccccc1, 2568039), (O=C1NC(=O)c2ncccc21, 15...
#                              ...
# 495    [(C1=Nc2ccccc2C=Nc2ccccc21, 3), (c1ccncc1, 275...
# 496    [(c1ccccc1, 2568039), (c1ccccc1, 2568039), (O=...
# 497    [(c1ccccc1, 2568039), (c1cc2c3c(ccnc3c1)CN2, 0...
# 498    [(c1cnc2ncnn2c1, 3690), (c1ccccc1, 2568039), (...
# 499    [(c1cncnc1, 100599), (c1ccccc1, 2568039), (c1c...
# Name: mol, Length: 500, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
# [500 rows x 5 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Proton(s) added/removed
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:12] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Accepted unusual valence(s): N(4)
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Accepted unusual valence(s): N(4)
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Proton(s) added/removed
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#
# [16:47:13] WARNING: Omitted undefined stereo
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...
# ..                                                 ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...
#
# [500 rows x 6 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...
# ..                                                 ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...
#
# [500 rows x 6 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 9    NCCc1nnc(-c2ccc(NC(=O)c3ccc(-n4c(O)cc5cc(C(N)C...
# 13   CCCC(N)C(=O)Nc1cccc(C=NNC(=O)c2ccc3c(c2)N(CC)C...
# 15   NC(=O)c1ccc(N(C=O)c2ccc(NNC(=O)c3ccc(CN4CCN(c5...
# 16   NC(=O)c1nn(CCCCNC(=O)c2ccc(NC(=O)c3cc(-c4ccccn...
# 21   CC(=O)N(c1ccc(C(=O)N=Cc2ccc3c(c2)nc(-c2ccccc2)...
# ..                                                 ...
# 476  NC(=O)c1nc2nccc(-c3ccc(NC(=O)c4ccc(N5C(=O)CCc6...
# 482  CCN1CCN(c2ccc(C=NC(=O)C(=O)c3c(O)cc(-c4cc(N)c(...
# 484  CN(C(=O)c1ccc(NNC(=O)C2CCC3NCC(C=NNc4ccccc4)C3...
# 491  COc1cc([N+](=O)O)c(N)cc1OCOc1ccc(C(=O)NCc2cccc...
# 492  N#Cc1cc(NC(=O)c2ccc(C(=O)NCc3ccc4oc(-c5ccccc5C...
#
#                                                   mol  \
# 9    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4c80>
# 13   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c66c0>
# 15   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c76f0>
# 16   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5f50>
# 21   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4a50>
# ..                                                ...
# 476  <rdkit.Chem.rdchem.Mol object at 0x7d26fccedee0>
# 482  <rdkit.Chem.rdchem.Mol object at 0x7d26fccecf90>
# 484  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee650>
# 491  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefdf0>
# 492  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee420>
#
#                                            ring_sytems  \
# 9    [c1ccc2cnncc2c1, c1ccccc1, c1ccccc1, c1ccc2[nH...
# 13       [c1ccccc1, c1ccc2c(c1)CNc1ccccc1-2, c1cnccn1]
# 15   [c1ccccc1, c1ccccc1, c1ccncc1, C1CNCCN1, c1ccn...
# 16     [c1ccc2[nH]ncc2c1, c1ccccc1, c1cnoc1, c1ccncc1]
# 21   [c1ccccc1, c1ccc2[nH]cnc2c1, c1ccccc1, O=C1CNc...
# ..                                                 ...
# 476  [c1cnc2ncnn2c1, c1ccccc1, c1ccccc1, O=C1CCc2cc...
# 482           [C1CNCCN1, c1ccccc1, c1ccccc1, c1ccccc1]
# 484      [c1ccccc1, C1CCC2NCCC2C1, c1ccccc1, c1ccncc1]
# 491  [c1ccccc1, c1ccccc1, c1ccccc1, O=c1[nH]cnc2ccc...
# 492       [c1ccccc1, c1ccoc1, c1ccc2ocnc2c1, c1ccccc1]
#
#                     min_ring min_freq  \
# 9             c1ccc2cnncc2c1     1930
# 13   c1ccc2c(c1)CNc1ccccc1-2      107
# 15                  C1CNCCN1   161505
# 16          c1ccc2[nH]ncc2c1    18855
# 21          O=C1CNc2ccccc2N1     1468
# ..                       ...      ...
# 476         O=C1CCc2ccccc2N1     2407
# 482                 C1CNCCN1   161505
# 484            C1CCC2NCCC2C1      267
# 491      O=c1[nH]cnc2ccccc12    13851
# 492            c1ccc2ocnc2c1    10264
#
#                                                  inchi
# 9    InChI=1S/C33H31N7O3/c34-14-13-28-24-3-1-2-4-25...
# 13   InChI=1S/C33H33N7O3/c1-3-8-27(34)33(43)38-23-1...
# 15   InChI=1S/C30H31N9O3/c31-28-16-25(9-10-27(28)29...
# 16   InChI=1S/C28H25N7O4/c29-26(36)25-20-7-1-2-9-23...
# 21   InChI=1S/C33H25N7O3/c1-21(41)40(26-12-13-27-28...
# ..                                                 ...
# 476  InChI=1S/C29H25N9O3/c30-25(31)19-5-11-22-18(15...
# 482  InChI=1S/C29H32N6O6/c1-4-34-7-9-35(10-8-34)22-...
# 484  InChI=1S/C29H32N8O4/c1-36(27-14-12-24(18-31-27...
# 491  InChI=1S/C30H24ClN5O7/c1-41-26-14-25(36(39)40)...
# 492  InChI=1S/C28H18N6O7/c29-13-16-12-17(6-7-21(16)...
#
# [95 rows x 6 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#     rule_set_name description
# 0              ok          ok
# 1              ok          ok
# 2              ok          ok
# 3              ok          ok
# 4              ok          ok
# ..            ...         ...
# 495            ok          ok
# 496            ok          ok
# 497            ok          ok
# 498            ok          ok
# 499            ok          ok
#
# [500 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi rule_set_name  \
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...            ok
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...            ok
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...            ok
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...            ok
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...            ok
# ..                                                 ...           ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...            ok
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...            ok
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...            ok
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...            ok
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...            ok
#
#     description
# 0            ok
# 1            ok
# 2            ok
# 3            ok
# 4            ok
# ..          ...
# 495          ok
# 496          ok
# 497          ok
# 498          ok
# 499          ok
#
# [475 rows x 8 columns]

# %% [markdown]
# Test all filters from rd filters

# %%
rd_filters = ['Glaxo', 'Dundee', 'BMS', 'SureChEMBL', 'MLSMR', 'Inpharmatica', 'LINT']
for filter in rd_filters:
    reos.set_active_rule_sets([filter])
    new_df = reos.pandas_mols(df.mol)
    print(filter, len(new_df[new_df.description == "ok"])/len(new_df), reos.get_active_rule_sets(), len(new_df[new_df.description == "ok"]))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Glaxo 0.684 ['Glaxo'] 342
#   0%|          | 0/500 [00:00<?, ?it/s]
# Dundee 0.206 ['Dundee'] 103
#   0%|          | 0/500 [00:00<?, ?it/s]
# BMS 0.642 ['BMS'] 321
#   0%|          | 0/500 [00:00<?, ?it/s]
# SureChEMBL 0.394 ['SureChEMBL'] 197
#   0%|          | 0/500 [00:00<?, ?it/s]
# MLSMR 0.392 ['MLSMR'] 196
#   0%|          | 0/500 [00:00<?, ?it/s]
# Inpharmatica 0.426 ['Inpharmatica'] 213
#   0%|          | 0/500 [00:00<?, ?it/s]
# LINT 0.26 ['LINT'] 130

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi  Reymond
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...    False
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...     True
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...     True
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...     True
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...     True
# ..                                                 ...      ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...     True
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...     True
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...     True
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...    False
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...    False
#
# [500 rows x 7 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                                 SMILES  \
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# 5    Nc1c(CO)cccc1NC(=O)c1cccc(C=NNC(=O)c2ccc(C(=O)...
# ..                                                 ...
# 493  N=c1[nH]c(-c2ccc(NNC(=O)c3ccc(S(=O)(=O)N4Cc5nc...
# 494  CN(CC1NC2CCCNC2N1)C(=O)c1ccc(C=NC(=O)c2ccc3c(c...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
#
#                                                   mol  \
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# 5    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5ee0>
# ..                                                ...
# 493  <rdkit.Chem.rdchem.Mol object at 0x7d26fccec580>
# 494  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeff0>
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
#
#                                            ring_sytems  \
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# 5     [c1ccccc1, c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# ..                                                 ...
# 493  [N=c1[nH]cnc2ccccc12, c1ccccc1, c1ccccc1, c1cn...
# 494  [C1CNC2NCNC2C1, c1ccccc1, c1ccc2c(c1)C1CNCCN21...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
#
#                                     min_ring min_freq  \
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# 5                           O=C1CNC2CCCCC2N1       40
# ..                                       ...      ...
# 493                     c1cnc2c(c1)nc1n2CNC1        0
# 494                            C1CNC2NCNC2C1        0
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
#
#                                                  inchi  Reymond
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...     True
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...     True
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...     True
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...     True
# 5    InChI=1S/C32H35N7O5/c33-28-23(18-40)7-4-10-26(...     True
# ..                                                 ...      ...
# 493  InChI=1S/C29H23N9O3S/c30-26-22-4-1-2-5-23(22)3...     True
# 494  InChI=1S/C31H35N9O2/c1-38(19-27-36-24-4-2-11-3...     True
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...     True
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...     True
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...     True
#
# [484 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                              N=c1cncc[nH]1        2
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        3
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...    False     False
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...     True     False
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...     True     False
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...     True     False
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...     True     False
# ..                                                 ...      ...       ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...     True     False
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...     True     False
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...     True     False
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...    False     False
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...    False     False
#
# [500 rows x 8 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
# Empty DataFrame
# Columns: [SMILES, mol, ring_sytems, min_ring, min_freq, inchi, Reymond, Lipinski]
# Index: []

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC22 database druglike molecules

# %%
ring_system_lookup_ZINC22 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC22_rings_system.csv")
res_zinc22 = df.mol.apply(ring_system_lookup_ZINC22.process_mol)
res_zinc22
# Out:
# 0      [(c1ccccc1, 21243538754), (O=C1NC(=O)c2ccccc21...
# 1      [(N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, 0),...
# 2      [(N=c1cncc[nH]1, 22033632), (O=C1c2ccccc2C2CNC...
# 3      [(c1ccccc1, 21243538754), (c1ccncc1, 997562007...
# 4      [(c1ccccc1, 21243538754), (O=C1NC(=O)c2ncccc21...
#                              ...
# 495    [(C1=Nc2ccccc2C=Nc2ccccc21, 0), (c1ccncc1, 997...
# 496    [(c1ccccc1, 21243538754), (c1ccccc1, 212435387...
# 497    [(c1ccccc1, 21243538754), (c1cc2c3c(ccnc3c1)CN...
# 498    [(c1cnc2ncnn2c1, 58667110), (c1ccccc1, 2124353...
# 499    [(c1cncnc1, 2861731550), (c1ccccc1, 2124353875...
# Name: mol, Length: 500, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc22.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                      O=C1c2ccccc2C2CNCCN12        0
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        0
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...    False     False
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...     True     False
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...     True     False
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...     True     False
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...     True     False
# ..                                                 ...      ...       ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...     True     False
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...     True     False
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...     True     False
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...    False     False
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...    False     False
#
# [500 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 5    Nc1c(CO)cccc1NC(=O)c1cccc(C=NNC(=O)c2ccc(C(=O)...
# 9    NCCc1nnc(-c2ccc(NC(=O)c3ccc(-n4c(O)cc5cc(C(N)C...
# 13   CCCC(N)C(=O)Nc1cccc(C=NNC(=O)c2ccc3c(c2)N(CC)C...
# 15   NC(=O)c1ccc(N(C=O)c2ccc(NNC(=O)c3ccc(CN4CCN(c5...
# 16   NC(=O)c1nn(CCCCNC(=O)c2ccc(NC(=O)c3cc(-c4ccccn...
# ..                                                 ...
# 483  CCN(Cc1ccc([N+](=O)O)c(NO)c1)c1ccc(C(=O)NN=CC2...
# 484  CN(C(=O)c1ccc(NNC(=O)C2CCC3NCC(C=NNc4ccccc4)C3...
# 489  Cc1cc(=N)n(C(=O)Nc2cccc(C=CC(=O)NNc3ccc(Cn4nnn...
# 491  COc1cc([N+](=O)O)c(N)cc1OCOc1ccc(C(=O)NCc2cccc...
# 492  N#Cc1cc(NC(=O)c2ccc(C(=O)NCc3ccc4oc(-c5ccccc5C...
#
#                                                   mol  \
# 5    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5ee0>
# 9    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4c80>
# 13   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c66c0>
# 15   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c76f0>
# 16   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5f50>
# ..                                                ...
# 483  <rdkit.Chem.rdchem.Mol object at 0x7d26fccef140>
# 484  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee650>
# 489  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefb50>
# 491  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefdf0>
# 492  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee420>
#
#                                            ring_sytems  \
# 5     [c1ccccc1, c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# 9    [c1ccc2cnncc2c1, c1ccccc1, c1ccccc1, c1ccc2[nH...
# 13       [c1ccccc1, c1ccc2c(c1)CNc1ccccc1-2, c1cnccn1]
# 15   [c1ccccc1, c1ccccc1, c1ccncc1, C1CNCCN1, c1ccn...
# 16     [c1ccc2[nH]ncc2c1, c1ccccc1, c1cnoc1, c1ccncc1]
# ..                                                 ...
# 483             [c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# 484      [c1ccccc1, C1CCC2NCCC2C1, c1ccccc1, c1ccncc1]
# 489  [N=c1cc[nH][nH]1, c1ccccc1, c1ccccc1, c1nnn[nH...
# 491  [c1ccccc1, c1ccccc1, c1ccccc1, O=c1[nH]cnc2ccc...
# 492       [c1ccccc1, c1ccoc1, c1ccc2ocnc2c1, c1ccccc1]
#
#                     min_ring    min_freq  \
# 5           O=C1CNC2CCCCC2N1        5692
# 9             c1ccc2cnncc2c1     8443484
# 13   c1ccc2c(c1)CNc1ccccc1-2       70486
# 15                  C1CNCCN1  2428718326
# 16          c1ccc2[nH]ncc2c1   328393980
# ..                       ...         ...
# 483         O=C1CNC2CCCCC2N1        5692
# 484            C1CCC2NCCC2C1       32318
# 489          N=c1cc[nH][nH]1   212718130
# 491      O=c1[nH]cnc2ccccc12    10102592
# 492            c1ccc2ocnc2c1   107382650
#
#                                                  inchi  Reymond  Lipinski
# 5    InChI=1S/C32H35N7O5/c33-28-23(18-40)7-4-10-26(...     True     False
# 9    InChI=1S/C33H31N7O3/c34-14-13-28-24-3-1-2-4-25...     True     False
# 13   InChI=1S/C33H33N7O3/c1-3-8-27(34)33(43)38-23-1...     True     False
# 15   InChI=1S/C30H31N9O3/c31-28-16-25(9-10-27(28)29...     True     False
# 16   InChI=1S/C28H25N7O4/c29-26(36)25-20-7-1-2-9-23...     True     False
# ..                                                 ...      ...       ...
# 483  InChI=1S/C27H36N8O5/c1-3-34(15-18-5-11-24(35(3...     True     False
# 484  InChI=1S/C29H32N8O4/c1-36(27-14-12-24(18-31-27...     True     False
# 489  InChI=1S/C28H26N10O2/c1-19-16-25(29)38(34-19)2...     True     False
# 491  InChI=1S/C30H24ClN5O7/c1-41-26-14-25(36(39)40)...     True     False
# 492  InChI=1S/C28H18N6O7/c29-13-16-12-17(6-7-21(16)...     True     False
#
# [139 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 0) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 5    Nc1c(CO)cccc1NC(=O)c1cccc(C=NNC(=O)c2ccc(C(=O)...
# 9    NCCc1nnc(-c2ccc(NC(=O)c3ccc(-n4c(O)cc5cc(C(N)C...
# 13   CCCC(N)C(=O)Nc1cccc(C=NNC(=O)c2ccc3c(c2)N(CC)C...
# 15   NC(=O)c1ccc(N(C=O)c2ccc(NNC(=O)c3ccc(CN4CCN(c5...
# 16   NC(=O)c1nn(CCCCNC(=O)c2ccc(NC(=O)c3cc(-c4ccccn...
# ..                                                 ...
# 483  CCN(Cc1ccc([N+](=O)O)c(NO)c1)c1ccc(C(=O)NN=CC2...
# 484  CN(C(=O)c1ccc(NNC(=O)C2CCC3NCC(C=NNc4ccccc4)C3...
# 489  Cc1cc(=N)n(C(=O)Nc2cccc(C=CC(=O)NNc3ccc(Cn4nnn...
# 491  COc1cc([N+](=O)O)c(N)cc1OCOc1ccc(C(=O)NCc2cccc...
# 492  N#Cc1cc(NC(=O)c2ccc(C(=O)NCc3ccc4oc(-c5ccccc5C...
#
#                                                   mol  \
# 5    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5ee0>
# 9    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4c80>
# 13   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c66c0>
# 15   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c76f0>
# 16   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5f50>
# ..                                                ...
# 483  <rdkit.Chem.rdchem.Mol object at 0x7d26fccef140>
# 484  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee650>
# 489  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefb50>
# 491  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefdf0>
# 492  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee420>
#
#                                            ring_sytems  \
# 5     [c1ccccc1, c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# 9    [c1ccc2cnncc2c1, c1ccccc1, c1ccccc1, c1ccc2[nH...
# 13       [c1ccccc1, c1ccc2c(c1)CNc1ccccc1-2, c1cnccn1]
# 15   [c1ccccc1, c1ccccc1, c1ccncc1, C1CNCCN1, c1ccn...
# 16     [c1ccc2[nH]ncc2c1, c1ccccc1, c1cnoc1, c1ccncc1]
# ..                                                 ...
# 483             [c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# 484      [c1ccccc1, C1CCC2NCCC2C1, c1ccccc1, c1ccncc1]
# 489  [N=c1cc[nH][nH]1, c1ccccc1, c1ccccc1, c1nnn[nH...
# 491  [c1ccccc1, c1ccccc1, c1ccccc1, O=c1[nH]cnc2ccc...
# 492       [c1ccccc1, c1ccoc1, c1ccc2ocnc2c1, c1ccccc1]
#
#                     min_ring    min_freq  \
# 5           O=C1CNC2CCCCC2N1        5692
# 9             c1ccc2cnncc2c1     8443484
# 13   c1ccc2c(c1)CNc1ccccc1-2       70486
# 15                  C1CNCCN1  2428718326
# 16          c1ccc2[nH]ncc2c1   328393980
# ..                       ...         ...
# 483         O=C1CNC2CCCCC2N1        5692
# 484            C1CCC2NCCC2C1       32318
# 489          N=c1cc[nH][nH]1   212718130
# 491      O=c1[nH]cnc2ccccc12    10102592
# 492            c1ccc2ocnc2c1   107382650
#
#                                                  inchi  Reymond  Lipinski
# 5    InChI=1S/C32H35N7O5/c33-28-23(18-40)7-4-10-26(...     True     False
# 9    InChI=1S/C33H31N7O3/c34-14-13-28-24-3-1-2-4-25...     True     False
# 13   InChI=1S/C33H33N7O3/c1-3-8-27(34)33(43)38-23-1...     True     False
# 15   InChI=1S/C30H31N9O3/c31-28-16-25(9-10-27(28)29...     True     False
# 16   InChI=1S/C28H25N7O4/c29-26(36)25-20-7-1-2-9-23...     True     False
# ..                                                 ...      ...       ...
# 483  InChI=1S/C27H36N8O5/c1-3-34(15-18-5-11-24(35(3...     True     False
# 484  InChI=1S/C29H32N8O4/c1-36(27-14-12-24(18-31-27...     True     False
# 489  InChI=1S/C28H26N10O2/c1-19-16-25(29)38(34-19)2...     True     False
# 491  InChI=1S/C30H24ClN5O7/c1-41-26-14-25(36(39)40)...     True     False
# 492  InChI=1S/C28H18N6O7/c29-13-16-12-17(6-7-21(16)...     True     False
#
# [175 rows x 8 columns]

# %%
filtered_df_ring_freq = df[(df.min_freq > 10) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 5    Nc1c(CO)cccc1NC(=O)c1cccc(C=NNC(=O)c2ccc(C(=O)...
# 9    NCCc1nnc(-c2ccc(NC(=O)c3ccc(-n4c(O)cc5cc(C(N)C...
# 13   CCCC(N)C(=O)Nc1cccc(C=NNC(=O)c2ccc3c(c2)N(CC)C...
# 15   NC(=O)c1ccc(N(C=O)c2ccc(NNC(=O)c3ccc(CN4CCN(c5...
# 16   NC(=O)c1nn(CCCCNC(=O)c2ccc(NC(=O)c3cc(-c4ccccn...
# ..                                                 ...
# 483  CCN(Cc1ccc([N+](=O)O)c(NO)c1)c1ccc(C(=O)NN=CC2...
# 484  CN(C(=O)c1ccc(NNC(=O)C2CCC3NCC(C=NNc4ccccc4)C3...
# 489  Cc1cc(=N)n(C(=O)Nc2cccc(C=CC(=O)NNc3ccc(Cn4nnn...
# 491  COc1cc([N+](=O)O)c(N)cc1OCOc1ccc(C(=O)NCc2cccc...
# 492  N#Cc1cc(NC(=O)c2ccc(C(=O)NCc3ccc4oc(-c5ccccc5C...
#
#                                                   mol  \
# 5    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5ee0>
# 9    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4c80>
# 13   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c66c0>
# 15   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c76f0>
# 16   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5f50>
# ..                                                ...
# 483  <rdkit.Chem.rdchem.Mol object at 0x7d26fccef140>
# 484  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee650>
# 489  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefb50>
# 491  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefdf0>
# 492  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee420>
#
#                                            ring_sytems  \
# 5     [c1ccccc1, c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# 9    [c1ccc2cnncc2c1, c1ccccc1, c1ccccc1, c1ccc2[nH...
# 13       [c1ccccc1, c1ccc2c(c1)CNc1ccccc1-2, c1cnccn1]
# 15   [c1ccccc1, c1ccccc1, c1ccncc1, C1CNCCN1, c1ccn...
# 16     [c1ccc2[nH]ncc2c1, c1ccccc1, c1cnoc1, c1ccncc1]
# ..                                                 ...
# 483             [c1ccccc1, c1ccccc1, O=C1CNC2CCCCC2N1]
# 484      [c1ccccc1, C1CCC2NCCC2C1, c1ccccc1, c1ccncc1]
# 489  [N=c1cc[nH][nH]1, c1ccccc1, c1ccccc1, c1nnn[nH...
# 491  [c1ccccc1, c1ccccc1, c1ccccc1, O=c1[nH]cnc2ccc...
# 492       [c1ccccc1, c1ccoc1, c1ccc2ocnc2c1, c1ccccc1]
#
#                     min_ring    min_freq  \
# 5           O=C1CNC2CCCCC2N1        5692
# 9             c1ccc2cnncc2c1     8443484
# 13   c1ccc2c(c1)CNc1ccccc1-2       70486
# 15                  C1CNCCN1  2428718326
# 16          c1ccc2[nH]ncc2c1   328393980
# ..                       ...         ...
# 483         O=C1CNC2CCCCC2N1        5692
# 484            C1CCC2NCCC2C1       32318
# 489          N=c1cc[nH][nH]1   212718130
# 491      O=c1[nH]cnc2ccccc12    10102592
# 492            c1ccc2ocnc2c1   107382650
#
#                                                  inchi  Reymond  Lipinski
# 5    InChI=1S/C32H35N7O5/c33-28-23(18-40)7-4-10-26(...     True     False
# 9    InChI=1S/C33H31N7O3/c34-14-13-28-24-3-1-2-4-25...     True     False
# 13   InChI=1S/C33H33N7O3/c1-3-8-27(34)33(43)38-23-1...     True     False
# 15   InChI=1S/C30H31N9O3/c31-28-16-25(9-10-27(28)29...     True     False
# 16   InChI=1S/C28H25N7O4/c29-26(36)25-20-7-1-2-9-23...     True     False
# ..                                                 ...      ...       ...
# 483  InChI=1S/C27H36N8O5/c1-3-34(15-18-5-11-24(35(3...     True     False
# 484  InChI=1S/C29H32N8O4/c1-36(27-14-12-24(18-31-27...     True     False
# 489  InChI=1S/C28H26N10O2/c1-19-16-25(29)38(34-19)2...     True     False
# 491  InChI=1S/C30H24ClN5O7/c1-41-26-14-25(36(39)40)...     True     False
# 492  InChI=1S/C28H18N6O7/c29-13-16-12-17(6-7-21(16)...     True     False
#
# [145 rows x 8 columns]

# %% [markdown]
# ### Molecules' performance in ring systems from ZINC20 database druglike molecules

# %%
ring_system_lookup_ZINC20 = uru.RingSystemLookup(ring_file="/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/data/ZINC20_rings_ststem.csv")
res_zinc20 = df.mol.apply(ring_system_lookup_ZINC20.process_mol)
res_zinc20
# Out:
# 0      [(c1ccccc1, 503413992), (O=C1NC(=O)c2ccccc21, ...
# 1      [(N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, 0),...
# 2      [(N=c1cncc[nH]1, 31730), (O=C1c2ccccc2C2CNCCN1...
# 3      [(c1ccccc1, 503413992), (c1ccncc1, 110130832),...
# 4      [(c1ccccc1, 503413992), (O=C1NC(=O)c2ncccc21, ...
#                              ...
# 495    [(C1=Nc2ccccc2C=Nc2ccccc21, 2), (c1ccncc1, 110...
# 496    [(c1ccccc1, 503413992), (c1ccccc1, 503413992),...
# 497    [(c1ccccc1, 503413992), (c1cc2c3c(ccnc3c1)CN2,...
# 498    [(c1cnc2ncnn2c1, 1029122), (c1ccccc1, 50341399...
# 499    [(c1cncnc1, 30067373), (c1ccccc1, 503413992), ...
# Name: mol, Length: 500, dtype: object

# %%
df[['min_ring','min_freq']] = res_zinc20.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                 SMILES  \
# 0    CN(c1ccc(NC(=O)c2ccc3c(c2)C(=O)N(C2CC4=NC4C(NC...
# 1    N=c1nc2c3cc(C(=O)NN=CC4CCC5C(=CCC(N)=O)CCCCC5C...
# 2    N=c1[nH]ccnc1N1CCN2C(=O)c3ccc(C(=O)Nc4cccc(N5C...
# 3    Nc1ccc(NC(=O)c2ccc(C(=O)NC3CCC4C(C3)NC3NC(N)NC...
# 4    O=C(NCc1ccc(N2C(=O)c3cccnc3C2=O)cc1)c1ccc(OC2C...
# ..                                                 ...
# 495  Cc1cccc2c1N=Cc1cc(NC(=O)c3ccc(S(=O)(=O)Nc4cc(N...
# 496  CCN(C(=O)c1ccc(NC(=O)c2cccc(-n3c(O)c4n(c3=O)CC...
# 497  COc1ccc(C=NNC(=O)c2cc3c4c(cccc4n2)N(c2cncc([N+...
# 498  NC(=O)c1nc2nccc(-c3ccc(NC(=O)C45CC6C7CC(c8cc(N...
# 499  O=C(CCc1ncccn1)Nc1ccc(NC(=O)c2ccc(C(=O)N=C3C=C...
#
#                                                   mol  \
# 0    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c69d0>
# 1    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4270>
# 2    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c6650>
# 3    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c45f0>
# 4    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4040>
# ..                                                ...
# 495  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced0e0>
# 496  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceeb20>
# 497  <rdkit.Chem.rdchem.Mol object at 0x7d26fcced000>
# 498  <rdkit.Chem.rdchem.Mol object at 0x7d26fcceccf0>
# 499  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee260>
#
#                                            ring_sytems  \
# 0    [c1ccccc1, O=C1NC(=O)c2ccccc21, C1CCC2N=C2C1, ...
# 1    [N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43, C=C1...
# 2    [N=c1cncc[nH]1, O=C1c2ccccc2C2CNCCN12, c1ccccc...
# 3    [c1ccccc1, c1ccncc1, C1CCC2C(C1)NCNC1NC3CCCCC3...
# 4    [c1ccccc1, O=C1NC(=O)c2ncccc21, c1ccccc1, C1CC...
# ..                                                 ...
# 495  [C1=Nc2ccccc2C=Nc2ccccc21, c1ccncc1, O=C1Nc2cc...
# 496  [c1ccccc1, c1ccccc1, O=C1NC23C(=O)NC1C2Cn1c3c[...
# 497  [c1ccccc1, c1cc2c3c(ccnc3c1)CN2, c1ccncc1, c1n...
# 498  [c1cnc2ncnn2c1, c1ccccc1, C1CC2C3C1C1CC4C3C43C...
# 499  [c1cncnc1, c1ccccc1, c1ccccc1, N=C1C=CC2N=C2C1...
#
#                                     min_ring min_freq  \
# 0                               C1CCC2N=C2C1        0
# 1    N=c1nc2c3cccc4cccc(c5ncnc([nH]1)c52)c43        0
# 2                      O=C1c2ccccc2C2CNCCN12        0
# 3               C1CCC2C(C1)NCNC1NC3CCCCC3N12        0
# 4                      C1CCC2C(C1)NC1CCCNC12        0
# ..                                       ...      ...
# 495                 C1=Nc2ccccc2C=Nc2ccccc21        2
# 496         O=C1NC23C(=O)NC1C2Cn1c3c[nH]c1=O        0
# 497                     c1cc2c3c(ccnc3c1)CN2        0
# 498                 C1CC2C3C1C1CC4C3C43C1C23        0
# 499                          N=C1C=CC2N=C2C1        0
#
#                                                  inchi  Reymond  Lipinski
# 0    InChI=1S/C28H23N7O6/c1-33(24-9-7-18(13-29-24)3...    False     False
# 1    InChI=1S/C32H32N8O2/c33-25(41)11-9-18-4-1-2-5-...     True     False
# 2    InChI=1S/C30H29N9O2/c31-27-28(34-11-10-33-27)3...     True     False
# 3    InChI=1S/C28H38N10O3/c29-18-8-6-16(11-21(18)32...     True     False
# 4    InChI=1S/C32H33N5O4/c38-30(35-18-19-5-9-21(10-...     True     False
# ..                                                 ...      ...       ...
# 495  InChI=1S/C28H21N7O4S/c1-15-3-2-4-16-12-30-22-7...     True     False
# 496  InChI=1S/C28H23N7O6S/c1-2-33(19-12-42-13-29-19...     True     False
# 497  InChI=1S/C28H22N10O4/c1-42-24-6-5-16(7-20(24)2...     True     False
# 498  InChI=1S/C31H26N8O4/c32-17-7-12(8-18(38-43)24(...    False     False
# 499  InChI=1S/C31H29N7O3/c39-28(13-12-27-33-17-2-18...    False     False
#
# [500 rows x 8 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %%
filtered_df_ring_freq = df[(df.min_freq > 100) & (df.min_freq != -1)]
filtered_df_ring_freq
# Out:
#                                                 SMILES  \
# 9    NCCc1nnc(-c2ccc(NC(=O)c3ccc(-n4c(O)cc5cc(C(N)C...
# 13   CCCC(N)C(=O)Nc1cccc(C=NNC(=O)c2ccc3c(c2)N(CC)C...
# 15   NC(=O)c1ccc(N(C=O)c2ccc(NNC(=O)c3ccc(CN4CCN(c5...
# 16   NC(=O)c1nn(CCCCNC(=O)c2ccc(NC(=O)c3cc(-c4ccccn...
# 21   CC(=O)N(c1ccc(C(=O)N=Cc2ccc3c(c2)nc(-c2ccccc2)...
# ..                                                 ...
# 476  NC(=O)c1nc2nccc(-c3ccc(NC(=O)c4ccc(N5C(=O)CCc6...
# 482  CCN1CCN(c2ccc(C=NC(=O)C(=O)c3c(O)cc(-c4cc(N)c(...
# 489  Cc1cc(=N)n(C(=O)Nc2cccc(C=CC(=O)NNc3ccc(Cn4nnn...
# 491  COc1cc([N+](=O)O)c(N)cc1OCOc1ccc(C(=O)NCc2cccc...
# 492  N#Cc1cc(NC(=O)c2ccc(C(=O)NCc3ccc4oc(-c5ccccc5C...
#
#                                                   mol  \
# 9    <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4c80>
# 13   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c66c0>
# 15   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c76f0>
# 16   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c5f50>
# 21   <rdkit.Chem.rdchem.Mol object at 0x7d26fd7c4a50>
# ..                                                ...
# 476  <rdkit.Chem.rdchem.Mol object at 0x7d26fccedee0>
# 482  <rdkit.Chem.rdchem.Mol object at 0x7d26fccecf90>
# 489  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefb50>
# 491  <rdkit.Chem.rdchem.Mol object at 0x7d26fccefdf0>
# 492  <rdkit.Chem.rdchem.Mol object at 0x7d26fccee420>
#
#                                            ring_sytems  \
# 9    [c1ccc2cnncc2c1, c1ccccc1, c1ccccc1, c1ccc2[nH...
# 13       [c1ccccc1, c1ccc2c(c1)CNc1ccccc1-2, c1cnccn1]
# 15   [c1ccccc1, c1ccccc1, c1ccncc1, C1CNCCN1, c1ccn...
# 16     [c1ccc2[nH]ncc2c1, c1ccccc1, c1cnoc1, c1ccncc1]
# 21   [c1ccccc1, c1ccc2[nH]cnc2c1, c1ccccc1, O=C1CNc...
# ..                                                 ...
# 476  [c1cnc2ncnn2c1, c1ccccc1, c1ccccc1, O=C1CCc2cc...
# 482           [C1CNCCN1, c1ccccc1, c1ccccc1, c1ccccc1]
# 489  [N=c1cc[nH][nH]1, c1ccccc1, c1ccccc1, c1nnn[nH...
# 491  [c1ccccc1, c1ccccc1, c1ccccc1, O=c1[nH]cnc2ccc...
# 492       [c1ccccc1, c1ccoc1, c1ccc2ocnc2c1, c1ccccc1]
#
#                     min_ring  min_freq  \
# 9             c1ccc2cnncc2c1    215945
# 13   c1ccc2c(c1)CNc1ccccc1-2      6852
# 15                  C1CNCCN1  35074701
# 16          c1ccc2[nH]ncc2c1   3722533
# 21          O=C1CNc2ccccc2N1    260176
# ..                       ...       ...
# 476            c1cnc2ncnn2c1   1029122
# 482                 C1CNCCN1  35074701
# 489          N=c1cc[nH][nH]1    465348
# 491      O=c1[nH]cnc2ccccc12    864191
# 492            c1ccc2ocnc2c1   2599428
#
#                                                  inchi  Reymond  Lipinski
# 9    InChI=1S/C33H31N7O3/c34-14-13-28-24-3-1-2-4-25...     True     False
# 13   InChI=1S/C33H33N7O3/c1-3-8-27(34)33(43)38-23-1...     True     False
# 15   InChI=1S/C30H31N9O3/c31-28-16-25(9-10-27(28)29...     True     False
# 16   InChI=1S/C28H25N7O4/c29-26(36)25-20-7-1-2-9-23...     True     False
# 21   InChI=1S/C33H25N7O3/c1-21(41)40(26-12-13-27-28...     True     False
# ..                                                 ...      ...       ...
# 476  InChI=1S/C29H25N9O3/c30-25(31)19-5-11-22-18(15...     True     False
# 482  InChI=1S/C29H32N6O6/c1-4-34-7-9-35(10-8-34)22-...     True     False
# 489  InChI=1S/C28H26N10O2/c1-19-16-25(29)38(34-19)2...     True     False
# 491  InChI=1S/C30H24ClN5O7/c1-41-26-14-25(36(39)40)...     True     False
# 492  InChI=1S/C28H18N6O7/c29-13-16-12-17(6-7-21(16)...     True     False
#
# [103 rows x 8 columns]
