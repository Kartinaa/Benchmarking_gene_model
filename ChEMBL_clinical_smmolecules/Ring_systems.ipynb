# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/ChEMBL_clinical_smmolecules
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model

# %% [markdown]
# Set the default image size

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# ### Reading the data from ChEMBL

# %%
sdf_files = glob.glob('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/ChEMBL_clinical_smmolecules/*.sdf')

# %%
# Initialize an empty list to store SMILES and file names
data = []
counts = 0
# Loop over each SDF file
for sdf_file in sdf_files:
    # Read the SDF file
    supplier = Chem.SDMolSupplier(sdf_file)
    
    # Extract SMILES from each molecule in the SDF file
    for mol in supplier:
        counts += 1
        if mol is not None:  # Ensure the molecule is valid
            smiles = Chem.MolToSmiles(mol)
            # Append the SMILES and the filename to the data list
            data.append({"File Name": sdf_file, "SMILES": smiles})

### Make sure 1000 molecules are generated and calculated
print(counts)
len(data)
# Out:
# [15:10:49] WARNING: not removing hydrogen atom without neighbors
# [15:10:49] WARNING: not removing hydrogen atom without neighbors
# [15:10:49] WARNING: not removing hydrogen atom without neighbors
# [15:10:50] WARNING: not removing hydrogen atom without neighbors
# 8236
# 8236

# %%
smi_list = [x['SMILES'] for x in data]
with open('ChEMBL_clinical_smmolecules.smi', 'w') as f:
    for item in smi_list:
        f.write("%s\n" % item)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(data)
df
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 8231  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8232  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8233  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8234  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8235  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 8231                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 8232  CCC[C@H](C)OC(=O)[C@H](C)NP(=O)(OC[C@H]1OC[C@@...
# 8233            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 8234  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 8235  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
# [8236 rows x 2 columns]

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)
# Out:
# [15:10:51] WARNING: not removing hydrogen atom without neighbors
# [15:10:51] WARNING: not removing hydrogen atom without neighbors
# [15:10:51] WARNING: not removing hydrogen atom without neighbors
# [15:10:51] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0                          [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                           [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                            [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                              [c1ccccc1]
# 4       [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
#                               ...
# 8231                                           [c1ccccc1]
# 8232                   [C1COCO1, O=c1nccc[nH]1, c1ccccc1]
# 8233                           [c1ccc2c(c1)ncc1nc[nH]c12]
# 8234    [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 8235    [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
# Name: ring_sytems, Length: 8236, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['C1CCCCC1', 'c1ccccc1', 'c1ccccc1']),
#        list(['c1cnoc1', 'c1ccccc1', 'C1CCCCC1']),
#        list(['O=C1NC(=O)C2CC12', 'c1ccccc1']), ...,
#        list(['c1ccc2c(c1)ncc1nc[nH]c12']),
#        list(['c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@@]21C[C@H]43']),
#        list(['c1ccc2[nH]ccc2c1', 'c1ccncc1', 'C1CCCC1', 'C1CCC1', 'c1ccccc1'])],
#       dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                                 SMILES  Count
# 1                             c1ccccc1   6379
# 21                            c1ccncc1    814
# 30                            C1CCNCC1    604
# 51                            C1CNCCN1    481
# 67                            C1CCOCC1    345
# ...                                ...    ...
# 1671                   c1cnc2c(c1)NCC2      1
# 1672  O=C1CCCCCc2cc(ccn2)-c2[nH]ncc2N1      1
# 1673                     c1ncc2occc2n1      1
# 1674                   c1cnc2c(c1)CCN2      1
# 1675         O=c1c2ccccc2[nH]c2ccccc12      1
#
# [1716 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup.default()
res = df.mol.apply(ring_system_lookup.process_mol)

# %%
res
# Out:
# 0       [(C1CCCCC1, 77480), (c1ccccc1, 2260082), (c1cc...
# 1       [(c1cnoc1, 28864), (c1ccccc1, 2260082), (C1CCC...
# 2           [(O=C1NC(=O)C2CC12, 43), (c1ccccc1, 2260082)]
# 3                                   [(c1ccccc1, 2260082)]
# 4       [(c1ccc2[nH]ccc2c1, 93446), (C1=C[C@H]2CC[C@@H...
#                               ...
# 8231                                [(c1ccccc1, 2260082)]
# 8232    [(C1COCO1, 2415), (O=c1nccc[nH]1, 5676), (c1cc...
# 8233                    [(c1ccc2c(c1)ncc1nc[nH]c12, 538)]
# 8234    [(c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[...
# 8235    [(c1ccc2[nH]ccc2c1, 93446), (c1ccncc1, 231698)...
# Name: mol, Length: 8236, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 8231  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8232  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8233  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8234  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 8235  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 8231                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 8232  CCC[C@H](C)OC(=O)[C@H](C)NP(=O)(OC[C@H]1OC[C@@...
# 8233            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 8234  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 8235  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 8231  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 8232  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72ce0>
# 8233  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 8234  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 8235  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 8231                                         [c1ccccc1]
# 8232                 [C1COCO1, O=c1nccc[nH]1, c1ccccc1]
# 8233                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 8234  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 8235  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 8231                                           c1ccccc1  2260082
# 8232                                            C1COCO1     2415
# 8233                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 8234  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 8235                                             C1CCC1    12595
#
# [8236 rows x 6 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Proton(s) added/removed
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:07] WARNING: Charges were rearranged
#
# [15:11:07] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Metal was disconnected
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Accepted unusual valence(s): O(1); Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Charges were rearranged
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Omitted undefined stereo
#
# [15:11:08] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Charges were rearranged
#
# [15:11:09] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Omitted undefined stereo
#
# [15:11:09] WARNING: Proton(s) added/removed
#
# ...
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Accepted unusual valence(s): O(4)
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged; Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Charges were rearranged
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Proton(s) added/removed
#
# [15:11:10] WARNING: Omitted undefined stereo
#
# [15:11:10] WARNING: Omitted undefined stereo
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 7699                                             C1CCC1    12595
#
#                                                   inchi
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...
# 4     InChI=1S/C56H68N6O9/c1-7-52(67)28-33-29-55(51(...
# ...                                                 ...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...
#
# [7700 rows x 7 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 7699                                             C1CCC1    12595
#
#                                                   inchi
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...
# 4     InChI=1S/C56H68N6O9/c1-7-52(67)28-33-29-55(51(...
# ...                                                 ...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...
#
# [7261 rows x 7 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 5     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 6     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7693  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 5     C/C(=C(\CCOC(=O)c1ccccc1)SS/C(CCOC(=O)c1ccccc1...
# 6     CC(=O)[C@@]1(Br)CC[C@H]2[C@@H]3C[C@H](F)C4=CC(...
# ...                                                 ...
# 7693  NC(=O)NC[C@@H]1CCCc2cc(S(=O)(=O)c3cccc(F)c3)ccc21
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 5     <rdkit.Chem.rdchem.Mol object at 0x7c303a790350>
# 6     <rdkit.Chem.rdchem.Mol object at 0x7c303a7903c0>
# ...                                                ...
# 7693  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72b20>
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 3                                            [c1ccccc1]
# 5              [c1ccccc1, c1ccccc1, c1cncnc1, c1cncnc1]
# 6     [O=C1C=C2CC[C@H]3[C@@H]4CCC[C@H]4CC[C@@H]3[C@H...
# ...                                                 ...
# 7693                       [c1ccc2c(c1)CCCC2, c1ccccc1]
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 3                                              c1ccccc1  2260082
# 5                                              c1cncnc1    81465
# 6     O=C1C=C2CC[C@H]3[C@@H]4CCC[C@H]4CC[C@@H]3[C@H]...      494
# ...                                                 ...      ...
# 7693                                   c1ccc2c(c1)CCCC2     8799
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7699                                             C1CCC1    12595
#
#                                                   inchi
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...
# 5     InChI=1S/C38H42N8O6S2/c1-25(45(23-47)21-31-19-...
# 6     InChI=1S/C21H28BrFO2/c1-12(24)21(22)9-6-16-14-...
# ...                                                 ...
# 7693  InChI=1S/C18H19FN2O3S/c19-14-5-2-6-15(10-14)25...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...
#
# [6110 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/7700 [00:00<?, ?it/s]
#      rule_set_name description
# 0               ok          ok
# 1               ok          ok
# 2               ok          ok
# 3               ok          ok
# 4               ok          ok
# ...            ...         ...
# 7695            ok          ok
# 7696            ok          ok
# 7697            ok          ok
# 7698            ok          ok
# 7699            ok          ok
#
# [7700 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/7700 [00:00<?, ?it/s]
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 7699                                             C1CCC1    12595
#
#                                                   inchi rule_set_name  \
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...            ok
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...            ok
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...            ok
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...            ok
# 4     InChI=1S/C56H68N6O9/c1-7-52(67)28-33-29-55(51(...            ok
# ...                                                 ...           ...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...            ok
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...            ok
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...            ok
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...            ok
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...            ok
#
#      description
# 0             ok
# 1             ok
# 2             ok
# 3             ok
# 4             ok
# ...          ...
# 7695          ok
# 7696          ok
# 7697          ok
# 7698          ok
# 7699          ok
#
# [7390 rows x 9 columns]

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 7699                                             C1CCC1    12595
#
#                                                   inchi  Reymond
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...     True
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...     True
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...     True
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...     True
# 4     InChI=1S/C56H68N6O9/c1-7-52(67)28-33-29-55(51(...     True
# ...                                                 ...      ...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...     True
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...     True
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...     True
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...     True
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...     True
#
# [7700 rows x 8 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 7699                                             C1CCC1    12595
#
#                                                   inchi  Reymond
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...     True
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...     True
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...     True
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...     True
# 4     InChI=1S/C56H68N6O9/c1-7-52(67)28-33-29-55(51(...     True
# ...                                                 ...      ...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...     True
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...     True
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...     True
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...     True
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...     True
#
# [7693 rows x 8 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
# [15:12:04] WARNING: not removing hydrogen atom without neighbors
# [15:12:04] WARNING: not removing hydrogen atom without neighbors
# [15:12:04] WARNING: not removing hydrogen atom without neighbors
# [15:12:06] WARNING: not removing hydrogen atom without neighbors
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 4     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7699  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 4     CCOC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@]1(O...
# ...                                                 ...
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 7699  Cn1c(-c2ccccn2)c(C2CCCC2)c2ccc(C(=O)NC3(C(=O)N...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 4     <rdkit.Chem.rdchem.Mol object at 0x7c303a7902e0>
# ...                                                ...
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
# 7699  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72e30>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 4     [c1ccc2[nH]ccc2c1, C1=C[C@H]2CC[C@@H]3Nc4ccccc...
# ...                                                 ...
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
# 7699  [c1ccc2[nH]ccc2c1, c1ccncc1, C1CCCC1, C1CCC1, ...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 4               c1ccc2c3c([nH]c2c1)CC[C@@H]1CCCN(CC3)C1       80
# ...                                                 ...      ...
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
# 7699                                             C1CCC1    12595
#
#                                                   inchi  Reymond  Lipinski
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...     True      True
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...     True      True
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...     True      True
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...     True      True
# 4     InChI=1S/C56H68N6O9/c1-7-52(67)28-33-29-55(51(...     True     False
# ...                                                 ...      ...       ...
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...     True      True
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...     True      True
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...     True      True
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...     True      True
# 7699  InChI=1S/C34H34N4O4/c1-38-28-21-24(13-16-26(28...     True     False
#
# [7700 rows x 9 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
#                                               File Name  \
# 0     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 1     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 2     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 3     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7     /home/yang2531/Documents/Bo_toolbox/PatWalters...
# ...                                                 ...
# 7694  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7695  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7696  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7697  /home/yang2531/Documents/Bo_toolbox/PatWalters...
# 7698  /home/yang2531/Documents/Bo_toolbox/PatWalters...
#
#                                                  SMILES  \
# 0            CN(C)CC1CCCCC1(O)c1cccc(OC(=O)c2ccccc2O)c1
# 1     Cc1cc(C(=O)NCCc2ccc(S(=O)(=O)NC(=O)NC3CCCCC3)c...
# 2                        O=C1NC(=O)C2(c3ccc(Cl)cc3)CC12
# 3      CC(C)C(=O)Oc1cc(OC(=O)C(C)C)cc(C(O)CNC(C)(C)C)c1
# 7                        O=C(O)CCCCc1ccc(CCCc2ccccc2)s1
# ...                                                 ...
# 7694                                     O=[Se](=O)(O)O
# 7695          CC(C)Cc1ccc([C@@H](C)C(=O)NS(C)(=O)=O)cc1
# 7696                     CC(C)(C)NCC(O)COc1cc(Cl)ccc1Cl
# 7697            CCc1nc2c(N)nc3ccccc3c2n1CCCCNS(C)(=O)=O
# 7698  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
#
#                                                    mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x7c303a790120>
# 1     <rdkit.Chem.rdchem.Mol object at 0x7c303a790190>
# 2     <rdkit.Chem.rdchem.Mol object at 0x7c303a790200>
# 3     <rdkit.Chem.rdchem.Mol object at 0x7c303a790270>
# 7     <rdkit.Chem.rdchem.Mol object at 0x7c303a790430>
# ...                                                ...
# 7694  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72b90>
# 7695  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c00>
# 7696  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72c70>
# 7697  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72d50>
# 7698  <rdkit.Chem.rdchem.Mol object at 0x7c3037d72dc0>
#
#                                             ring_sytems  \
# 0                        [C1CCCCC1, c1ccccc1, c1ccccc1]
# 1                         [c1cnoc1, c1ccccc1, C1CCCCC1]
# 2                          [O=C1NC(=O)C2CC12, c1ccccc1]
# 3                                            [c1ccccc1]
# 7                                   [c1ccsc1, c1ccccc1]
# ...                                                 ...
# 7694                                                 []
# 7695                                         [c1ccccc1]
# 7696                                         [c1ccccc1]
# 7697                         [c1ccc2c(c1)ncc1nc[nH]c12]
# 7698  [c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C...
#
#                                                min_ring min_freq  \
# 0                                              C1CCCCC1    77480
# 1                                               c1cnoc1    28864
# 2                                      O=C1NC(=O)C2CC12       43
# 3                                              c1ccccc1  2260082
# 7                                               c1ccsc1    68146
# ...                                                 ...      ...
# 7694                                                          -1
# 7695                                           c1ccccc1  2260082
# 7696                                           c1ccccc1  2260082
# 7697                           c1ccc2c(c1)ncc1nc[nH]c12      538
# 7698  c1ccc2c(c1)N[C@H]1[C@@H]3C[C@H]4CCN3[C@H]3C[C@...        0
#
#                                                   inchi  Reymond  Lipinski
# 0     InChI=1S/C22H27NO4/c1-23(2)15-17-8-5-6-13-22(1...     True      True
# 1     InChI=1S/C20H26N4O5S/c1-14-13-18(23-29-14)19(2...     True      True
# 2     InChI=1S/C11H8ClNO2/c12-7-3-1-6(2-4-7)11-5-8(1...     True      True
# 3     InChI=1S/C20H31NO5/c1-12(2)18(23)25-15-8-14(17...     True      True
# 7     InChI=1S/C18H22O2S/c19-18(20)12-5-4-10-16-13-1...     True      True
# ...                                                 ...      ...       ...
# 7694           InChI=1S/H2O4Se/c1-5(2,3)4/h(H2,1,2,3,4)     True      True
# 7695  InChI=1S/C14H21NO3S/c1-10(2)9-12-5-7-13(8-6-12...     True      True
# 7696  InChI=1S/C13H19Cl2NO2/c1-13(2,3)16-7-10(17)8-1...     True      True
# 7697  InChI=1S/C17H23N5O2S/c1-3-14-21-15-16(12-8-4-5...     True      True
# 7698  InChI=1S/C20H26N2O2/c1-3-10-11-8-14-17-20(12-6...     True      True
#
# [5526 rows x 9 columns]

# %% [markdown]
# ### Check the properties of generated compounds

# %% [markdown]
# The aim is to see if we could find specific charateristics of each algorithm

# %% [markdown]
# Calculate the molecular weight and then visualize the distribution:

# %%
def calculate_molecular_weights(smiles_list):
    """Calculate molecular weights for a list of SMILES strings."""
    molecular_weights = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            mw = Descriptors.MolWt(mol)
            molecular_weights.append(mw)
    return molecular_weights

def plot_molecular_weight_distribution(molecular_weights, bins=30):
    """Plot the distribution of molecular weights as a histogram."""
    plt.hist(molecular_weights, bins=bins, color='skyblue', edgecolor='black')
    plt.title("Distribution of Molecular Weights ChEMBL Clinical Molecules")
    plt.xlabel("Molecular Weight")
    plt.ylabel("Frequency")
    plt.show()
    
molecular_weights = calculate_molecular_weights(df.SMILES.tolist())
plot_molecular_weight_distribution(molecular_weights)
# Out:
# [15:12:07] WARNING: not removing hydrogen atom without neighbors
# [15:12:07] WARNING: not removing hydrogen atom without neighbors
# [15:12:07] WARNING: not removing hydrogen atom without neighbors
# [15:12:08] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Number of heavy atoms:

# %%
def calculate_heavy_atom_counts(smiles_list):
    """Calculate heavy atom counts for a list of SMILES strings."""
    heavy_atom_counts = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            heavy_atom_count = mol.GetNumHeavyAtoms()
            heavy_atom_counts.append(heavy_atom_count)
    return heavy_atom_counts

def plot_heavy_atom_distribution(heavy_atom_counts, bins=20):
    """Plot the distribution of heavy atom counts as a histogram with frequency on the y-axis."""
    plt.hist(heavy_atom_counts, bins=bins, color='lightcoral', edgecolor='black', density=False)
    plt.title("Distribution of Heavy Atom Counts 3D_generative_SBDD")
    plt.xlabel("Number of Heavy Atoms")
    plt.ylabel("Frequency (Count of Molecules)")
    plt.show()
    
heavy_atom_counts = calculate_heavy_atom_counts(df.SMILES.tolist())
plot_heavy_atom_distribution(heavy_atom_counts)
# Out:
# [15:12:08] WARNING: not removing hydrogen atom without neighbors
# [15:12:08] WARNING: not removing hydrogen atom without neighbors
# [15:12:08] WARNING: not removing hydrogen atom without neighbors
# [15:12:09] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Number of hetero atoms:

# %%
def calculate_heteroatom_counts(smiles_list):
    """Calculate the number of heteroatoms for each SMILES string in the list."""
    heteroatom_counts = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            # Count atoms that are not C or H
            heteroatom_count = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() not in {1, 6})
            heteroatom_counts.append(heteroatom_count)
    return heteroatom_counts

def plot_heteroatom_distribution(heteroatom_counts, bins=12):
    """Plot the distribution of heteroatom counts as a histogram with frequency on the y-axis."""
    plt.hist(heteroatom_counts, bins=bins, color='skyblue', edgecolor='black', density=False)
    plt.xlabel("Number of Heteroatoms")
    plt.ylabel("Frequency")
    plt.title("Distribution of Heteroatoms in Molecules 3D_generative_SBDD")
    plt.show()

heteroatom_counts = calculate_heteroatom_counts(df.SMILES.tolist())
plot_heteroatom_distribution(heteroatom_counts)
# Out:
# [15:12:10] WARNING: not removing hydrogen atom without neighbors
# [15:12:10] WARNING: not removing hydrogen atom without neighbors
# [15:12:10] WARNING: not removing hydrogen atom without neighbors
# [15:12:10] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Ratio of hetero atoms over heavy atoms:

# %%
def calculate_heteroatom_ratio(smiles_list):
    """Calculate the ratio of heteroatoms to heavy atoms for each molecule in the SMILES list."""
    heteroatom_ratios = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            # Count heavy atoms (all atoms except hydrogen)
            heavy_atom_count = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 1)
            # Count heteroatoms (atoms other than C and H)
            heteroatom_count = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() not in {1, 6})
            # Calculate ratio if heavy_atom_count is non-zero
            if heavy_atom_count > 0:
                ratio = heteroatom_count / heavy_atom_count
                heteroatom_ratios.append(ratio)
    return heteroatom_ratios

def plot_heteroatom_ratio_distribution(heteroatom_ratios, bins=20):
    """Plot the distribution of heteroatom-to-heavy atom ratios as a histogram with frequency on the y-axis."""
    plt.hist(heteroatom_ratios, bins=bins, color='skyblue', edgecolor='black', density=False)
    plt.xlabel("Heteroatom to Heavy Atom Ratio")
    plt.ylabel("Frequency")
    plt.title("Distribution of Heteroatom to Heavy Atom Ratio in Molecules 3D_generative_SBDD")
    plt.show()
    
heteroatom_ratios = calculate_heteroatom_ratio(df.SMILES.tolist())
plot_heteroatom_ratio_distribution(heteroatom_ratios)
# Out:
# [15:12:11] WARNING: not removing hydrogen atom without neighbors
# [15:12:11] WARNING: not removing hydrogen atom without neighbors
# [15:12:11] WARNING: not removing hydrogen atom without neighbors
# [15:12:12] WARNING: not removing hydrogen atom without neighbors
