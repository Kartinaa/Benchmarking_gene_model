# %%
from rdkit import Chem
import sys
import os
import useful_rdkit_utils as uru
from rdkit.Chem.Draw import MolsToGridImage
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
import matplotlib.pyplot as plt
import itertools
import pandas as pd
from collections import Counter
import mols2grid
from tdc.single_pred import ADME
from Filtering_functions import filter_molecules
import glob

# %%
# Get the current working directory
current_dir = os.getcwd()
print(current_dir)
# Get the parent directory
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
print(parent_dir)
# Add the parent directory to sys.path
sys.path.append(parent_dir)
# Out:
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/Crossdock_datasets
# /home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model

# %% [markdown]
# Reading data from crossdock dataset

# %%
# # Function to read all SDF files and convert to mol objects
# def read_sdf_files_from_folders(main_folder):
#     mol_list = []

#     # Traverse the main folder and subfolders
#     for root, dirs, files in os.walk(main_folder):
#         for file in files:
#             # Check if the file is a .sdf file
#             if file.endswith(".sdf"):
#                 sdf_path = os.path.join(root, file)
                
#                 # Use RDKit to read the .sdf file
#                 supplier = Chem.SDMolSupplier(sdf_path)
                
#                 # Add each mol from the .sdf file to the list
#                 for mol in supplier:
#                     if mol is not None:  # Ensure mol is valid
#                         mol_list.append(mol)
    
#     return mol_list

# # Example usage
# main_folder = '/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/Crossdock_datasets'  # Replace with your folder path
# molecules = read_sdf_files_from_folders(main_folder)

# # You can now work with the list of mol objects
# print(f"Number of molecules read: {len(molecules)}")

# %%
smi_list = []
with open('/home/yang2531/Documents/Bo_toolbox/PatWalters/Benchmarking_gene_model/Crossdock_datasets/crossdock_ligand_smi.smi') as f:
    for smi in f:
        smi_list.append(smi.strip())
standardized_smiles_list = []
for smi in smi_list:
    mol = Chem.MolFromSmiles(smi)
    if mol:
        standardized_smiles_list.append(Chem.MolToSmiles(mol))

print(len(smi_list))
len(standardized_smiles_list)
# Out:
# 11602
# 11602

# %% [markdown]
# Set the default image size

# %%
uru.rd_set_image_size(300,300)

# %% [markdown]
# Convert SMILES and name of them to a dataframe

# %%
df = pd.DataFrame(standardized_smiles_list, columns=['SMILES'])
df
# Out:
#                                                   SMILES
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
# [11602 rows x 1 columns]

# %% [markdown]
# Remove repeated molecules

# %%
df = df.drop_duplicates(['SMILES'])
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                                   SMILES
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
# [11602 rows x 1 columns]

# %% [markdown]
# Save the smi file for further use

# %%
smi_export_list = df['SMILES'].tolist()
with open('crossdock_ligand_smi.smi', 'w') as f:
    for item in smi_export_list:
        f.write("%s\n" % item)

# %% [markdown]
# Add an RDKit molecule to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Strip salts from the molecule

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)
df.mol[0]

# %% [markdown]
# Instantiate a RingSystemFinder object and find ring systems for the molecules in df

# %%
ring_system_finder = uru.RingSystemFinder()
df['ring_sytems'] = df.mol.apply(ring_system_finder.find_ring_systems)
df.ring_sytems
# Out:
# 0                    [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                              [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                              [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                              [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4        [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
#                                ...
# 11597                                         [O=C1C=CCS1]
# 11598                                           [c1ccccc1]
# 11599                                          [C1=NC=NC1]
# 11600               [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601               [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
# Name: ring_sytems, Length: 11602, dtype: object

# %%
df.ring_sytems.values
# Out:
# array([list(['c1cc2[nH]cnc2cn1', 'c1cnon1', 'C1CCNCC1']),
#        list(['c1ncc2nc[nH]c2n1', 'C1CCOC1']),
#        list(['c1ncc2nc[nH]c2n1', 'C1CCOC1']), ..., list(['C1=NC=NC1']),
#        list(['c1ncc2nc[nH]c2n1', 'C1CCOC1', 'C1=NCN=C1']),
#        list(['c1ncc2nc[nH]c2n1', 'C1CCOC1', 'C1=NC=NC1'])], dtype=object)

# %% [markdown]
# See how many times each ring system occurs

# %%
ring_system_list = list(itertools.chain.from_iterable(df.ring_sytems.values))
ring_count_df = pd.DataFrame(Counter(ring_system_list).items(),columns=["SMILES","Count"]) ### Convert a dictionary to a DataFrame.
ring_count_df.sort_values("Count",ascending=False,inplace=True)
ring_count_df
# Out:
#                                                 SMILES  Count
# 7                                             c1ccccc1   8908
# 9                                             c1ccncc1   1195
# 4                                              C1CCOC1    685
# 2                                             C1CCNCC1    633
# 8                                             C1CCOCC1    532
# ..                                                 ...    ...
# 832                               O=c1nc[nH]c2c1=NCN=2      1
# 834  O=C1CCNC(=O)CNC(=O)[C@@H]2CS[C@@H](N2)c2csc(n2...      1
# 835    O=C1CCNC(=O)CNC(=O)[C@@H]2CSC(=N2)c2cccc(n2)CN1      1
# 836     O=C1CCNC(=O)CNC(=O)[C@@H]2CSC(N2)c2ccnc(c2)CN1      1
# 885                         C1=CC2=Nc3ccccc3N[C@H]2CC1      1
#
# [2109 rows x 2 columns]

# %% [markdown]
# View the ring system frequencies

# %%
mols2grid.display(ring_count_df,subset=["img","Count"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# The RingSystemLookup object has a dictionary of how many times each ring system occurs in the ChEMBL database.  We can use this object to evaluate the molecules in df.

# %%
ring_system_lookup = uru.RingSystemLookup.default()
res = df.mol.apply(ring_system_lookup.process_mol)
# Out:
# [15:35:21] bond type above 3 (17) is treated as unspecified!
# [15:35:21] Invalid InChI prefix in generating InChI Key
# [15:35:23] unrecognized chirality tag (8) on atom 10 is ignored.
# [15:35:27] unrecognized chirality tag (8) on atom 12 is ignored.
# [15:35:28] unrecognized chirality tag (8) on atom 12 is ignored.
# [15:35:28] unrecognized chirality tag (8) on atom 2 is ignored.
# [15:35:28] unrecognized chirality tag (8) on atom 12 is ignored.
# [15:35:28] unrecognized chirality tag (8) on atom 3 is ignored.
# [15:35:30] unrecognized chirality tag (6) on atom 7 is ignored.
# [15:35:31] unrecognized chirality tag (6) on atom 2 is ignored.

# %%
res
# Out:
# 0        [(c1cc2[nH]cnc2cn1, 2525), (c1cnon1, 2243), (C...
# 1            [(c1ncc2nc[nH]c2n1, 24411), (C1CCOC1, 47269)]
# 2            [(c1ncc2nc[nH]c2n1, 24411), (C1CCOC1, 47269)]
# 3            [(c1ncc2nc[nH]c2n1, 24411), (C1CCOC1, 47269)]
# 4        [(O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H...
#                                ...
# 11597                                  [(O=C1C=CCS1, 222)]
# 11598                                [(c1ccccc1, 2260082)]
# 11599                                    [(C1=NC=NC1, 26)]
# 11600    [(c1ncc2nc[nH]c2n1, 24411), (C1CCOC1, 47269), ...
# 11601    [(c1ncc2nc[nH]c2n1, 24411), (C1CCOC1, 47269), ...
# Name: mol, Length: 11602, dtype: object

# %%
df[['min_ring','min_freq']] = res.apply(uru.get_min_ring_frequency).tolist()
df
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# ...                                                 ...
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# ...                                                  ...
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
# 11600             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
#
#                                                 min_ring min_freq
# 0                                                c1cnon1     2243
# 1                                       c1ncc2nc[nH]c2n1    24411
# 2                                       c1ncc2nc[nH]c2n1    24411
# 3                                       c1ncc2nc[nH]c2n1    24411
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# ...                                                  ...      ...
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
# 11600                                          C1=NCN=C1       61
# 11601                                          C1=NC=NC1       26
#
# [11602 rows x 5 columns]

# %%
mols2grid.display(df.sort_values("min_freq"),mol_col="mol",subset=["img","min_freq"])
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ### Check how many molecules are unique the ring frequency of them

# %% [markdown]
# How many molecules are unique using inChI?

# %%
df['inchi'] = df.mol.apply(Chem.MolToInchi)
df = df.drop_duplicates("inchi", keep="first", ignore_index=True)
df
# Out:
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Charges were rearranged
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:31] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Metal was disconnected
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] bond type above 3 (17) is treated as unspecified!
# [15:35:32] ERROR: Unrecognized bond type: 0
#
# [15:35:32] WARNING: Accepted unusual valence(s): Au(4); Metal was disconnected; Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3); Metal was disconnected; Proton(s) added/removed
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] unrecognized chirality tag (6) on atom 18 is ignored.
# [15:35:32] WARNING: Metal was disconnected
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Metal was disconnected
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] unrecognized chirality tag (8) on atom 23 is ignored.
# [15:35:32] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Salt was disconnected; Proton(s) added/removed
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): S(3); Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:32] unrecognized chirality tag (8) on atom 12 is ignored.
# [15:35:32] WARNING: Accepted unusual valence(s): S(3); Metal was disconnected; Proton(s) added/removed
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Accepted unusual valence(s): Sc(4); Metal was disconnected; Proton(s) added/removed
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:32] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:32] WARNING: Omitted undefined stereo
#
# [15:35:32] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] unrecognized chirality tag (8) on atom 13 is ignored.
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Metal was disconnected
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] unrecognized chirality tag (7) on atom 1 is ignored.
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Metal was disconnected
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] unrecognized chirality tag (8) on atom 19 is ignored.
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3); Metal was disconnected; Omitted undefined stereo
#
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged; Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Accepted unusual valence(s): S(3); Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] unrecognized chirality tag (6) on atom 1 is ignored.
# [15:35:33] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Accepted unusual valence(s): Au(4); Metal was disconnected
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:33] WARNING: Omitted undefined stereo
#
# [15:35:33] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] unrecognized chirality tag (8) on atom 9 is ignored.
# [15:35:34] unrecognized chirality tag (8) on atom 9 is ignored.
# [15:35:34] unrecognized chirality tag (8) on atom 9 is ignored.
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] unrecognized chirality tag (8) on atom 45 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] unrecognized chirality tag (7) on atom 1 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Accepted unusual valence(s): Fe(1); Metal was disconnected
#
# [15:35:34] WARNING: Accepted unusual valence(s): Fe(1); Metal was disconnected
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Metal was disconnected; Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Accepted unusual valence(s): Al(4); Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] unrecognized chirality tag (8) on atom 13 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] unrecognized chirality tag (8) on atom 13 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] unrecognized chirality tag (8) on atom 13 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] unrecognized chirality tag (8) on atom 13 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed
#
# [15:35:34] unrecognized chirality tag (6) on atom 12 is ignored.
# [15:35:34] WARNING: Metal was disconnected; Proton(s) added/removed; Omitted undefined stereo
#
# [15:35:34] WARNING: Charges were rearranged
#
# [15:35:34] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] unrecognized chirality tag (6) on atom 2 is ignored.
# [15:35:35] WARNING: Accepted unusual valence(s): S(3)
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Omitted undefined stereo
#
# [15:35:35] WARNING: Charges were rearranged
#
# [15:35:35] WARNING: Charges were rearranged
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# ...                                                 ...
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# ...                                                  ...
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
# 11600             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
#
#                                                 min_ring min_freq  \
# 0                                                c1cnon1     2243
# 1                                       c1ncc2nc[nH]c2n1    24411
# 2                                       c1ncc2nc[nH]c2n1    24411
# 3                                       c1ncc2nc[nH]c2n1    24411
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# ...                                                  ...      ...
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
# 11600                                          C1=NCN=C1       61
# 11601                                          C1=NC=NC1       26
#
#                                                    inchi
# 0      InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...
# 1      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 2      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 3      InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...
# 4      InChI=1S/C27H19N3O5/c1-26-27(33,25(32)34-2)11-...
# ...                                                  ...
# 11597  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...
# 11598  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
# 11599  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...
# 11600  InChI=1S/C16H23N9O7S/c17-8(1-7-2-19-4-20-7)15(...
# 11601  InChI=1S/C16H21N8O8P/c17-8(1-7-2-19-4-20-7)16(...
#
# [11602 rows x 6 columns]

# %% [markdown]
# How many of them have ring system?

# %%
df_ring = df[df.min_freq != -1]
df_ring
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# ...                                                 ...
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# ...                                                  ...
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
# 11600             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
#
#                                                 min_ring min_freq  \
# 0                                                c1cnon1     2243
# 1                                       c1ncc2nc[nH]c2n1    24411
# 2                                       c1ncc2nc[nH]c2n1    24411
# 3                                       c1ncc2nc[nH]c2n1    24411
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# ...                                                  ...      ...
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
# 11600                                          C1=NCN=C1       61
# 11601                                          C1=NC=NC1       26
#
#                                                    inchi
# 0      InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...
# 1      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 2      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 3      InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...
# 4      InChI=1S/C27H19N3O5/c1-26-27(33,25(32)34-2)11-...
# ...                                                  ...
# 11597  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...
# 11598  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
# 11599  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...
# 11600  InChI=1S/C16H23N9O7S/c17-8(1-7-2-19-4-20-7)15(...
# 11601  InChI=1S/C16H21N8O8P/c17-8(1-7-2-19-4-20-7)16(...
#
# [10881 rows x 6 columns]

# %%
filtered_df_ring_freq = df[df.min_freq > 100]
filtered_df_ring_freq
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 5          O=C1c2cccc3c(NCCO)ccc(c23)C(=O)N1c1cccc(Br)c1
# ...                                                  ...
# 11585  Nc1ncnc2c1nc(Br)n2[C@@H]1O[C@H](CO[P@@](=O)(O)...
# 11595         CN(CCCCc1ccccc1)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 11596                          CC(=O)c1sc(Nc2ccccc2)nc1C
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 5      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ff0>
# ...                                                 ...
# 11585  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36260>
# 11595  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f366c0>
# 11596  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36730>
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
#
#                                  ring_sytems                   min_ring  \
# 0      [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]                    c1cnon1
# 1                [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 2                [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 3                [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 5      [O=C1NC(=O)c2cccc3cccc1c23, c1ccccc1]  O=C1NC(=O)c2cccc3cccc1c23
# ...                                      ...                        ...
# 11585            [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 11595                             [c1ccccc1]                   c1ccccc1
# 11596                    [c1cscn1, c1ccccc1]                    c1cscn1
# 11597                           [O=C1C=CCS1]                 O=C1C=CCS1
# 11598                             [c1ccccc1]                   c1ccccc1
#
#       min_freq                                              inchi
# 0         2243  InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...
# 1        24411  InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 2        24411  InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 3        24411  InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...
# 5         1897  InChI=1S/C20H15BrN2O3/c21-12-3-1-4-13(11-12)23...
# ...        ...                                                ...
# 11585    24411  InChI=1S/C10H14BrN5O10P2/c11-10-15-4-7(12)13-2...
# 11595  2260082  InChI=1S/C14H25NO7P2/c1-15(11-6-5-9-13-7-3-2-4...
# 11596    61036  InChI=1S/C12H12N2OS/c1-8-11(9(2)15)16-12(13-8)...
# 11597      222  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...
# 11598  2260082  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...
#
# [8023 rows x 6 columns]

# %% [markdown]
# ### How many of them could pass PAINS filter?

# %% [markdown]
# Get a list of rules

# %%
reos = uru.REOS()
reos.get_available_rule_sets()
# Out:
# array(['Glaxo', 'Dundee', 'BMS', 'PAINS', 'SureChEMBL', 'MLSMR',
#        'Inpharmatica', 'LINT'], dtype=object)

# %% [markdown]
# Get the currently active rule sets

# %%
reos.get_active_rule_sets()
# Out:
# array(['Glaxo'], dtype=object)

# %% [markdown]
# Set active rule set to PAINS

# %%
reos.set_active_rule_sets(['PAINS'])
reos.get_active_rule_sets()
# Out:
# array(['PAINS'], dtype=object)

# %% [markdown]
# Apply PAINS filter to unique mols

# %%
reos.pandas_mols(df.mol)
# Out:
#   0%|          | 0/11602 [00:00<?, ?it/s]
#       rule_set_name     description
# 0                ok              ok
# 1                ok              ok
# 2                ok              ok
# 3                ok              ok
# 4             PAINS      dyes5A(27)
# ...             ...             ...
# 11597            ok              ok
# 11598         PAINS  catechol_A(92)
# 11599            ok              ok
# 11600            ok              ok
# 11601            ok              ok
#
# [11602 rows x 2 columns]

# %%
df_PAINS_filter = pd.concat([df, reos.pandas_mols(df.mol)], axis=1)
df_PAINS_filter = df_PAINS_filter[df_PAINS_filter.description == 'ok']
df_PAINS_filter
# Out:
#   0%|          | 0/11602 [00:00<?, ?it/s]
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 5          O=C1c2cccc3c(NCCO)ccc(c23)C(=O)N1c1cccc(Br)c1
# ...                                                  ...
# 11596                          CC(=O)c1sc(Nc2ccccc2)nc1C
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 5      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ff0>
# ...                                                 ...
# 11596  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36730>
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                   ring_sytems                   min_ring  \
# 0       [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]                    c1cnon1
# 1                 [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 2                 [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 3                 [c1ncc2nc[nH]c2n1, C1CCOC1]           c1ncc2nc[nH]c2n1
# 5       [O=C1NC(=O)c2cccc3cccc1c23, c1ccccc1]  O=C1NC(=O)c2cccc3cccc1c23
# ...                                       ...                        ...
# 11596                     [c1cscn1, c1ccccc1]                    c1cscn1
# 11597                            [O=C1C=CCS1]                 O=C1C=CCS1
# 11599                             [C1=NC=NC1]                  C1=NC=NC1
# 11600  [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]                  C1=NCN=C1
# 11601  [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]                  C1=NC=NC1
#
#       min_freq                                              inchi  \
# 0         2243  InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...
# 1        24411  InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 2        24411  InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...
# 3        24411  InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...
# 5         1897  InChI=1S/C20H15BrN2O3/c21-12-3-1-4-13(11-12)23...
# ...        ...                                                ...
# 11596    61036  InChI=1S/C12H12N2OS/c1-8-11(9(2)15)16-12(13-8)...
# 11597      222  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...
# 11599       26  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...
# 11600       61  InChI=1S/C16H23N9O7S/c17-8(1-7-2-19-4-20-7)15(...
# 11601       26  InChI=1S/C16H21N8O8P/c17-8(1-7-2-19-4-20-7)16(...
#
#       rule_set_name description
# 0                ok          ok
# 1                ok          ok
# 2                ok          ok
# 3                ok          ok
# 5                ok          ok
# ...             ...         ...
# 11596            ok          ok
# 11597            ok          ok
# 11599            ok          ok
# 11600            ok          ok
# 11601            ok          ok
#
# [11178 rows x 8 columns]

# %% [markdown]
# ### How many of them could pass filters suggested by Dr.Reymond?

# %%
df['Reymond'] = df.mol.apply(filter_molecules)
df
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# ...                                                 ...
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# ...                                                  ...
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
# 11600             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
#
#                                                 min_ring min_freq  \
# 0                                                c1cnon1     2243
# 1                                       c1ncc2nc[nH]c2n1    24411
# 2                                       c1ncc2nc[nH]c2n1    24411
# 3                                       c1ncc2nc[nH]c2n1    24411
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# ...                                                  ...      ...
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
# 11600                                          C1=NCN=C1       61
# 11601                                          C1=NC=NC1       26
#
#                                                    inchi  Reymond
# 0      InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...     True
# 1      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...     True
# 2      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...     True
# 3      InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...     True
# 4      InChI=1S/C27H19N3O5/c1-26-27(33,25(32)34-2)11-...     True
# ...                                                  ...      ...
# 11597  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...     True
# 11598  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...     True
# 11599  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...     True
# 11600  InChI=1S/C16H23N9O7S/c17-8(1-7-2-19-4-20-7)15(...     True
# 11601  InChI=1S/C16H21N8O8P/c17-8(1-7-2-19-4-20-7)16(...     True
#
# [11602 rows x 7 columns]

# %%
df_Reymond_filter = df[df.Reymond == True]
df_Reymond_filter
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# ...                                                 ...
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# ...                                                  ...
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
# 11600             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
#
#                                                 min_ring min_freq  \
# 0                                                c1cnon1     2243
# 1                                       c1ncc2nc[nH]c2n1    24411
# 2                                       c1ncc2nc[nH]c2n1    24411
# 3                                       c1ncc2nc[nH]c2n1    24411
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# ...                                                  ...      ...
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
# 11600                                          C1=NCN=C1       61
# 11601                                          C1=NC=NC1       26
#
#                                                    inchi  Reymond
# 0      InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...     True
# 1      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...     True
# 2      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...     True
# 3      InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...     True
# 4      InChI=1S/C27H19N3O5/c1-26-27(33,25(32)34-2)11-...     True
# ...                                                  ...      ...
# 11597  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...     True
# 11598  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...     True
# 11599  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...     True
# 11600  InChI=1S/C16H23N9O7S/c17-8(1-7-2-19-4-20-7)15(...     True
# 11601  InChI=1S/C16H21N8O8P/c17-8(1-7-2-19-4-20-7)16(...     True
#
# [11582 rows x 7 columns]

# %% [markdown]
# ### How many of them could pass RO5?

# %%
def passes_rule_of_five(smiles):
    """Determine if a molecule passes Lipinski's Rule of Five."""
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        hbd = Descriptors.NumHDonors(mol)  # Hydrogen bond donors
        hba = Descriptors.NumHAcceptors(mol)  # Hydrogen bond acceptors
        mw = Descriptors.MolWt(mol)  # Molecular weight
        logp = Descriptors.MolLogP(mol)  # LogP
        
        # Check Lipinski's Rule of Five criteria
        if hbd <= 5 and hba <= 10 and mw <= 500 and logp <= 5:
            return True
    return False

df['Lipinski'] = df.SMILES.apply(passes_rule_of_five)
df
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 1      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 2      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@](=O)(O)O[P@@...
# 3      Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OP(=...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# ...                                                  ...
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
# 11600  Nc1ncnc2c1ncn2[C@@H]1O[C@H](COS(O)(O)NC(=O)[C@...
# 11601  Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO[P@@](=O)(O)OC(=...
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 1      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6e30>
# 2      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ea0>
# 3      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f10>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# ...                                                 ...
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
# 11600  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f368f0>
# 11601  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36960>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 1                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 2                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 3                            [c1ncc2nc[nH]c2n1, C1CCOC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# ...                                                  ...
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
# 11600             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NCN=C1]
# 11601             [c1ncc2nc[nH]c2n1, C1CCOC1, C1=NC=NC1]
#
#                                                 min_ring min_freq  \
# 0                                                c1cnon1     2243
# 1                                       c1ncc2nc[nH]c2n1    24411
# 2                                       c1ncc2nc[nH]c2n1    24411
# 3                                       c1ncc2nc[nH]c2n1    24411
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# ...                                                  ...      ...
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
# 11600                                          C1=NCN=C1       61
# 11601                                          C1=NC=NC1       26
#
#                                                    inchi  Reymond  Lipinski
# 0      InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...     True      True
# 1      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...     True     False
# 2      InChI=1S/C10H16N5O12P3S/c11-8-5-9(13-2-12-8)15...     True     False
# 3      InChI=1S/C10H15N5O10P2/c11-8-5-9(13-2-12-8)15(...     True     False
# 4      InChI=1S/C27H19N3O5/c1-26-27(33,25(32)34-2)11-...     True      True
# ...                                                  ...      ...       ...
# 11597  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...     True      True
# 11598  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...     True      True
# 11599  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...     True      True
# 11600  InChI=1S/C16H23N9O7S/c17-8(1-7-2-19-4-20-7)15(...     True     False
# 11601  InChI=1S/C16H21N8O8P/c17-8(1-7-2-19-4-20-7)16(...     True     False
#
# [11602 rows x 8 columns]

# %%
df_Lipinski_filter = df[df.Lipinski == True]
df_Lipinski_filter
# Out:
#                                                   SMILES  \
# 0      CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC[C@H]3C...
# 4      COC(=O)[C@@]1(O)C[C@H]2O[C@]1(C)n1c3ccccc3c3c4...
# 5          O=C1c2cccc3c(NCCO)ccc(c23)C(=O)N1c1cccc(Br)c1
# 6      O=[N+]([O-])c1ccc(O[C@@H]2O[C@H](CO)[C@@H](O)[...
# 7      CC(=O)N[C@H]1[C@H](Oc2ccc([N+](=O)[O-])cc2)O[C...
# ...                                                  ...
# 11595         CN(CCCCc1ccccc1)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 11596                          CC(=O)c1sc(Nc2ccccc2)nc1C
# 11597                    C=C/C=C/[C@@]1(C)SC(=O)C(C)=C1O
# 11598                          NC[C@@H](O)c1ccc(O)c(O)c1
# 11599                              N[C@H](C=O)CC1=NC=NC1
#
#                                                     mol  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6dc0>
# 4      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6f80>
# 5      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f6ff0>
# 6      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f7060>
# 7      <rdkit.Chem.rdchem.Mol object at 0x7fceae3f70d0>
# ...                                                 ...
# 11595  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f366c0>
# 11596  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36730>
# 11597  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f367a0>
# 11598  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36810>
# 11599  <rdkit.Chem.rdchem.Mol object at 0x7fcea6f36880>
#
#                                              ring_sytems  \
# 0                  [c1cc2[nH]cnc2cn1, c1cnon1, C1CCNCC1]
# 4      [O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]...
# 5                  [O=C1NC(=O)c2cccc3cccc1c23, c1ccccc1]
# 6                                   [c1ccccc1, C1CCOCC1]
# 7                                   [C1CCOCC1, c1ccccc1]
# ...                                                  ...
# 11595                                         [c1ccccc1]
# 11596                                [c1cscn1, c1ccccc1]
# 11597                                       [O=C1C=CCS1]
# 11598                                         [c1ccccc1]
# 11599                                        [C1=NC=NC1]
#
#                                                 min_ring min_freq  \
# 0                                                c1cnon1     2243
# 4      O=C1N=Cc2c1c1c3ccccc3n3c1c1c2c2ccccc2n1[C@@H]1...        0
# 5                              O=C1NC(=O)c2cccc3cccc1c23     1897
# 6                                               C1CCOCC1    64272
# 7                                               C1CCOCC1    64272
# ...                                                  ...      ...
# 11595                                           c1ccccc1  2260082
# 11596                                            c1cscn1    61036
# 11597                                         O=C1C=CCS1      222
# 11598                                           c1ccccc1  2260082
# 11599                                          C1=NC=NC1       26
#
#                                                    inchi  Reymond  Lipinski
# 0      InChI=1S/C21H27N7O3/c1-4-28-18-15(30-12-13-6-5...     True      True
# 4      InChI=1S/C27H19N3O5/c1-26-27(33,25(32)34-2)11-...     True      True
# 5      InChI=1S/C20H15BrN2O3/c21-12-3-1-4-13(11-12)23...     True      True
# 6      InChI=1S/C12H15NO8/c14-5-8-9(15)10(16)11(17)12...     True      True
# 7      InChI=1S/C14H18N2O8/c1-7(18)15-11-13(20)12(19)...     True      True
# ...                                                  ...      ...       ...
# 11595  InChI=1S/C14H25NO7P2/c1-15(11-6-5-9-13-7-3-2-4...     True      True
# 11596  InChI=1S/C12H12N2OS/c1-8-11(9(2)15)16-12(13-8)...     True      True
# 11597  InChI=1S/C10H12O2S/c1-4-5-6-10(3)8(11)7(2)9(12...     True      True
# 11598  InChI=1S/C8H11NO3/c9-4-8(12)5-1-2-6(10)7(11)3-...     True      True
# 11599  InChI=1S/C6H9N3O/c7-5(3-10)1-6-2-8-4-9-6/h3-5H...     True      True
#
# [8560 rows x 8 columns]

# %% [markdown]
# ### Check the properties of generated compounds

# %% [markdown]
# The aim is to see if we could find specific charateristics of each algorithm

# %% [markdown]
# Calculate the molecular weight and then visualize the distribution:

# %%
def calculate_molecular_weights(smiles_list):
    """Calculate molecular weights for a list of SMILES strings."""
    molecular_weights = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            mw = Descriptors.MolWt(mol)
            molecular_weights.append(mw)
    return molecular_weights

def plot_molecular_weight_distribution(molecular_weights, bins=30):
    """Plot the distribution of molecular weights as a histogram."""
    plt.hist(molecular_weights, bins=bins, color='skyblue', edgecolor='black')
    plt.title("Distribution of Molecular Weights Crossdock")
    plt.xlabel("Molecular Weight")
    plt.ylabel("Frequency")
    plt.show()
    
molecular_weights = calculate_molecular_weights(df.SMILES.tolist())
plot_molecular_weight_distribution(molecular_weights)

# %% [markdown]
# Number of heavy atoms:

# %%
def calculate_heavy_atom_counts(smiles_list):
    """Calculate heavy atom counts for a list of SMILES strings."""
    heavy_atom_counts = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            heavy_atom_count = mol.GetNumHeavyAtoms()
            heavy_atom_counts.append(heavy_atom_count)
    return heavy_atom_counts

def plot_heavy_atom_distribution(heavy_atom_counts, bins=20):
    """Plot the distribution of heavy atom counts as a histogram with frequency on the y-axis."""
    plt.hist(heavy_atom_counts, bins=bins, color='lightcoral', edgecolor='black', density=False)
    plt.title("Distribution of Heavy Atom Counts Crossdock")
    plt.xlabel("Number of Heavy Atoms")
    plt.ylabel("Frequency (Count of Molecules)")
    plt.show()
    
heavy_atom_counts = calculate_heavy_atom_counts(df.SMILES.tolist())
plot_heavy_atom_distribution(heavy_atom_counts)

# %% [markdown]
# Number of hetero atoms:

# %%
def calculate_heteroatom_counts(smiles_list):
    """Calculate the number of heteroatoms for each SMILES string in the list."""
    heteroatom_counts = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            # Count atoms that are not C or H
            heteroatom_count = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() not in {1, 6})
            heteroatom_counts.append(heteroatom_count)
    return heteroatom_counts

def plot_heteroatom_distribution(heteroatom_counts, bins=12):
    """Plot the distribution of heteroatom counts as a histogram with frequency on the y-axis."""
    plt.hist(heteroatom_counts, bins=bins, color='skyblue', edgecolor='black', density=False)
    plt.xlabel("Number of Heteroatoms")
    plt.ylabel("Frequency")
    plt.title("Distribution of Heteroatoms in Molecules Crossdock")
    plt.show()

heteroatom_counts = calculate_heteroatom_counts(df.SMILES.tolist())
plot_heteroatom_distribution(heteroatom_counts)

# %% [markdown]
# Ratio of hetero atoms over heavy atoms:

# %%
def calculate_heteroatom_ratio(smiles_list):
    """Calculate the ratio of heteroatoms to heavy atoms for each molecule in the SMILES list."""
    heteroatom_ratios = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            # Count heavy atoms (all atoms except hydrogen)
            heavy_atom_count = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() != 1)
            # Count heteroatoms (atoms other than C and H)
            heteroatom_count = sum(1 for atom in mol.GetAtoms() if atom.GetAtomicNum() not in {1, 6})
            # Calculate ratio if heavy_atom_count is non-zero
            if heavy_atom_count > 0:
                ratio = heteroatom_count / heavy_atom_count
                heteroatom_ratios.append(ratio)
    return heteroatom_ratios

def plot_heteroatom_ratio_distribution(heteroatom_ratios, bins=20):
    """Plot the distribution of heteroatom-to-heavy atom ratios as a histogram with frequency on the y-axis."""
    plt.hist(heteroatom_ratios, bins=bins, color='skyblue', edgecolor='black', density=False)
    plt.xlabel("Heteroatom to Heavy Atom Ratio")
    plt.ylabel("Frequency")
    plt.title("Distribution of Heteroatom to Heavy Atom Ratio in Molecules 3D_generative_SBDD")
    plt.show()
    
heteroatom_ratios = calculate_heteroatom_ratio(df.SMILES.tolist())
plot_heteroatom_ratio_distribution(heteroatom_ratios)
